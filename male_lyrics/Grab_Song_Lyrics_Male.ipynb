# %%
import lyricsgenius
genius = lyricsgenius.Genius("xe3uAhIb2OUZrYdBh9liV0IcFMzJOg7fCs4tmAaX4h9akRvwDtDwf_nJFsgrKjzc")
print (genius)
artist = genius.search_artist("Tyler, The Creator", max_songs=10, sort="title")
print(artist.songs)
# Out:
# <lyricsgenius.api.Genius object at 0x1105a8e10>
# Searching for songs by Tyler, The Creator...
#
# Song 1: "2SEATER"
# "2SEATER (Instrumental)" is not valid. Skipping.
# Song 2: "435"
# Song 3: "48"
# Song 4: "911 / Mr. Lonely"
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-31314d0e729f> in <module>
#       2 genius = lyricsgenius.Genius("xe3uAhIb2OUZrYdBh9liV0IcFMzJOg7fCs4tmAaX4h9akRvwDtDwf_nJFsgrKjzc")
#       3 print (genius)
# ----> 4 artist = genius.search_artist("Tyler, The Creator", max_songs=10, sort="title")
#       5 print(artist.songs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/lyricsgenius/api.py in search_artist(self, artist_name, max_songs, sort, per_page, get_full_info, allow_name_change, artist_id)
#     348
#     349                 # Create the Song object from lyrics and metadata
# --> 350                 lyrics = self._scrape_song_lyrics_from_url(song_info['url'])
#     351                 if get_full_info:
#     352                     info = self.get_song(song_info['id'])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/lyricsgenius/api.py in _scrape_song_lyrics_from_url(self, url)
#     161         :param url: URL for the web page to scrape lyrics from
#     162         """
# --> 163         page = requests.get(url)
#     164         if page.status_code == 404:
#     165             return None
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1334         try:
#    1335             try:
# -> 1336                 response.begin()
#    1337             except ConnectionError:
#    1338                 self.close()
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# ~/opt/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     295     def recv_into(self, *args, **kwargs):
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#     299             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1819             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1820         else:
# -> 1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# KeyboardInterrupt:

# %%
song = genius.search_song("Thinkin Bout You", artist.name)
print(song.lyrics)
# Out:
# Searching for "Thinkin Bout You" by Frank Ocean...
# Done.
# [Verse 1]
# A tornado flew around my room before you came
# Excuse the mess it made, it usually doesn't rain in
# Southern California, much like Arizona
# My eyes don't shed tears, but boy, they pour when
#
# [Pre-Chorus]
# I'm thinkin' 'bout you, ooh no, no, no
# I've been thinkin' bout you, you know, know, know
# I've been thinkin' bout you, do you think about me still?
# Do ya, do ya?
#
# [Chorus]
# Or do you not think so far ahead?
# 'Cause I been thinkin' bout forever, ooh
# Or do you not think so far ahead?
# 'Cause I been thinkin' bout forever, ooh
#
# [Verse 2]
# No, I don't like you, I just thought you were cool enough to kick it
# Got a beach house I could sell you in Idaho
# Since you think I don't love you, I just thought you were cute
# That's why I kissed you
# Got a fighter jet, I don't get to fly it though, I'm lying down
#
# [Pre-Chorus]
# Thinkin' 'bout you, ooh no, no, no
# I've been thinkin' bout you, you know, know, know
# I've been thinkin' bout you, do you think about me still?
# Do ya, do ya?
#
# [Chorus]
# Or do you not think so far ahead?
# 'Cause I been thinkin' bout forever, ooh
# Or do you not think so far ahead?
# 'Cause I been thinkin' bout forever, ooh
#
# [Bridge]
# Yes, of course, I remember, how could I forget (How could I forget?) how you feel? (How you feel)
# You know you were my first time, a new feel
# It won't ever get old, not in my soul, not in my spirit, keep it alive
# We'll go down this road 'til it turns from color to black and white
#
# [Chorus]
# Or do you not think so far ahead?
# 'Cause I been thinkin' bout forever, ooh
# Or do you not think so far ahead?
# 'Cause I been thinkin' bout forever, ooh

# %%
artist.add_song(song)
# Out:
# 0

# %%
artist.save_lyrics()
# Out:
# lyrics_frankocean_4tears.json already exists. Overwrite?
# (y/n): n
# Skipping file save.
#
# lyrics_frankocean_abracadabra.json already exists. Overwrite?
# (y/n): n
# Skipping file save.
#
# lyrics_frankocean_acertainway.json already exists. Overwrite?
# (y/n): n
# Skipping file save.
#
# lyrics_frankocean_closetoyou.json already exists. Overwrite?
# (y/n): n
# Skipping file save.
#
# Wrote Thinkin Bout You to lyrics_frankocean_thinkinboutyou.json.

# %%
import requests
from bs4 import BeautifulSoup


page = requests.get('https://web.archive.org/web/20121007172955/https://www.nga.gov/collection/anZ1.htm')

# Create a BeautifulSoup object
soup = BeautifulSoup(page.text, 'html.parser')

# %%
# https://github.com/Hugo-Nattagh/2017-Hip-Hop/blob/master/api.py
import sys
from urllib.request import Request, urlopen, quote
import os
import re
import requests
import socket
import json
from bs4 import BeautifulSoup
from string import punctuation
import time
from warnings import warn

from lyricsgenius.song import Song


class Artist(object):
    """An artist from the Genius.com database.
    Attributes:
        name: (str) Artist name.
        num_songs: (int) Total number of songs listed on Genius.com
    """

    def __init__(self, json_dict):
        """Populate the Artist object with the data from *json_dict*"""
        self._body = json_dict['artist']
        self._url = self._body['url']
        self._api_path = self._body['api_path']
        self._id = self._body['id']
        self._songs = []
        self._num_songs = len(self._songs)

    def __len__(self):
        return 1

    @property
    def name(self):
        return self._body['name']

    @property
    def image_url(self):
        try:
            return self._body['image_url']
        except:
            return None

    @property
    def songs(self):
        return self._songs

    @property
    def num_songs(self):
        return self._num_songs

    def add_song(self, newsong, verbose=True):
        """Add a Song object to the Artist object"""

        if any([song.title == newsong.title for song in self._songs]):
            if verbose:
                print('{newsong.title} already in {self.name}, not adding song.'.format(newsong=newsong, self=self))
            return 1  # Failure
        if newsong.artist == self.name:
            self._songs.append(newsong)
            self._num_songs += 1
            return 0  # Success
        else:
            self._songs.append(newsong)
            self._num_songs += 1
            print("Song by {newsong.artist} was added to {self.name}.".format(newsong=newsong, self=self))
            return 0  # Success

    def get_song(self, song_name):
        """Search Genius.com for *song_name* and add it to artist"""
        raise NotImplementedError("I need to figure out how to allow Artist() to access search_song().")
        song = Genius.search_song(song_name, self.name)
        self.add_song(song)
        return

    # TODO: define an export_to_json() method

    def save_lyrics(self, format='json', filename=None,
                    overwrite=False, skip_duplicates=True, verbose=True,album="Tyler"):
        """Allows user to save all lyrics within an Artist obejct to a .json or .txt file."""
        if format[0] == '.':
            format = format[1:]
        assert (format == 'json') or (format == 'txt'), "Format must be json or txt"

        # We want to reject songs that have already been added to artist collection
        def songsAreSame(s1, s2):
            from difflib import SequenceMatcher as sm  # For comparing similarity of lyrics
            # Idea credit: https://bigishdata.com/2016/10/25/talkin-bout-trucks-beer-and-love-in-country-songs-analyzing-genius-lyrics/
            seqA = sm(None, s1.lyrics, s2['lyrics'])
            seqB = sm(None, s2['lyrics'], s1.lyrics)
            return seqA.ratio() > 0.5 or seqB.ratio() > 0.5

        def songInArtist(new_song):
            # artist_lyrics is global (works in Jupyter notebook)
            for song in lyrics_to_write['songs']:
                if songsAreSame(new_song, song):
                    return True
            return False

        # Determine the filename
        if filename is None:
            filename = "Lyrics_{}{{.{}".format(self.name.replace(" ", ""),album, format)
        else:
            if filename.rfind('.') != -1:
                filename = filename[filename.rfind('.'):] + '.' + format
            else:
                filename = filename + '.' + format

        # Check if file already exists
        write_file = False
        if not os.path.isfile(filename):
            write_file = True
        elif overwrite:
            write_file = True
        else:
            if input("{} already exists. Overwrite?\n(y/n): ".format(filename)).lower() == 'y':
                write_file = True

        # Format lyrics in either .txt or .json format
        if format == 'json':
            lyrics_to_write = {'songs': [], 'artist': self.name}
            for song in self.songs:
                if skip_duplicates is False or not songInArtist(song):  # This takes way too long! It's basically O(n^2), can I do better?
                    lyrics_to_write['songs'].append({})
                    lyrics_to_write['songs'][-1]['title'] = song.title
                    lyrics_to_write['songs'][-1]['album'] = song.album
                    lyrics_to_write['songs'][-1]['year'] = song.year
                    lyrics_to_write['songs'][-1]['lyrics'] = song.lyrics
                    lyrics_to_write['songs'][-1]['image'] = song.song_art_image_url
                    lyrics_to_write['songs'][-1]['artist'] = self.name
                    lyrics_to_write['songs'][-1]['raw'] = song._body
                else:
                    if verbose:
                        print("SKIPPING \"{}\" -- already found in artist collection.".format(song.title))
        else:
            lyrics_to_write = " ".join([s.lyrics + 5 * '\n' for s in self.songs])

        # Write the lyrics to either a .json or .txt file
        if write_file:
            with open(filename, 'w') as lyrics_file:
                if format == 'json':
                    json.dump(lyrics_to_write, lyrics_file)
                else:
                    lyrics_file.write(lyrics_to_write)
            if verbose:
                print('Wrote {} songs to {}.'.format(self.num_songs, filename))
        else:
            if verbose:
                print('Skipping file save.\n')
        return lyrics_to_write

    def __str__(self):
        """Return a string representation of the Artist object."""
        if self._num_songs == 1:
            return '{0}, {1} song'.format(self.name, self._num_songs)
        else:
            return '{0}, {1} songs'.format(self.name, self._num_songs)

    def __repr__(self):
        return repr((self.name, '{0} songs'.format(self._num_songs)))


class _API(object):
    # This is a superclass that Genius() inherits from. Not sure if this makes any sense, but it
    # seemed like a good idea to have this class (more removed from user) handle the lower-level
    # interaction with the Genius API, and then Genius() has the more user-friendly search
    # functions
    """Interface with the Genius.com API
    Attributes:
        base_url: (str) Top-most URL to access the Genius.com API with
    Methods:
        _load_credentials()
            OUTPUT: client_id, client_secret, client_access_token
        _make_api_request()
            INPUT:
            OUTPUT:
    """

    # Genius API constants
    _API_URL = "https://api.genius.com/"
    _API_REQUEST_TYPES =\
        {'song': 'songs/', 'artist': 'artists/',
            'artist-songs': 'artists/songs/', 'search': 'search?q='}

    def __init__(self, client_access_token, client_secret='', client_id=''):
        self._CLIENT_ACCESS_TOKEN = client_access_token
        self._HEADER_AUTHORIZATION = 'Bearer ' + self._CLIENT_ACCESS_TOKEN

    def _make_api_request(self, request_term_and_type, page=1):
        """Send a request (song, artist, or search) to the Genius API, returning a json object
        INPUT:
            request_term_and_type: (tuple) (request_term, request_type)
        *request term* is a string. If *request_type* is 'search', then *request_term* is just
        what you'd type into the search box on Genius.com. If you have an song ID or an artist ID,
        you'd do this: self._make_api_request('2236','song')
        Returns a json object.
        """

        # TODO: This should maybe be a generator

        # The API request URL must be formatted according to the desired
        # request type"""
        api_request = self._format_api_request(
            request_term_and_type, page=page)

        # Add the necessary headers to the request
        request = Request(api_request)
        request.add_header("Authorization", self._HEADER_AUTHORIZATION)
        request.add_header("User-Agent", "LyricsGenius")
        while True:
            try:
                # timeout set to 4 seconds; automatically retries if times out
                response = urlopen(request, timeout=4)
                raw = response.read().decode('utf-8')
            except socket.timeout:
                print("Timeout raised and caught")
                continue
            break

        return json.loads(raw)['response']

    def _format_api_request(self, term_and_type, page=1):
        """Format the request URL depending on the type of request"""

        request_term, request_type = str(term_and_type[0]), term_and_type[1]
        assert request_type in self._API_REQUEST_TYPES, "Unknown API request type"

        # TODO - Clean this up (might not need separate returns)
        if request_type == 'artist-songs':
            return self._API_URL + 'artists/' + quote(request_term) + '/songs?per_page=50&page=' + str(page)
        else:
            return self._API_URL + self._API_REQUEST_TYPES[request_type] + quote(request_term)

    def _scrape_song_lyrics_from_url(self, URL, remove_section_headers=False):
        """Use BeautifulSoup to scrape song info off of a Genius song URL"""
        page = requests.get(URL)
        html = BeautifulSoup(page.text, "html.parser")

        # Scrape the song lyrics from the HTML
        lyrics = html.find("div", class_="lyrics").get_text()
        if remove_section_headers:
            # Remove [Verse] and [Bridge] stuff
            lyrics = re.sub('(\[.*?\])*', '', lyrics)
            # Remove gaps between verses
            lyrics = re.sub('\n{2}', '\n', lyrics)

        return lyrics.strip('\n')

    def _clean_str(self, s):
        return s.translate(str.maketrans('', '', punctuation)).replace('\u200b', " ").strip().lower()

    def _result_is_lyrics(self, song_title):
        """Returns False if result from Genius is not actually song lyrics"""
        regex = re.compile(
            r"(tracklist)|(track list)|(album art(work)?)|(liner notes)|(booklet)|(credits)", re.IGNORECASE)
        return not regex.search(song_title)


class Genius(_API):
    """User-level interface with the Genius.com API. User can search for songs (getting lyrics) and artists (getting songs)"""

    def search_song(self, song_title, artist_name="", take_first_result=False, verbose=True, remove_section_headers=True, remove_non_songs=True):
        # TODO: Should search_song() be a @classmethod?
        """Search Genius.com for *song_title* by *artist_name*"""
#         print (song_title,artist_name)
        # Perform a Genius API search for the song
        if verbose:
            if artist_name != "":
                print('Searching for "{0}" by {1}...'.format(
                    song_title, artist_name))
            else:
                print('Searching for "{0}"...'.format(song_title))
                
        search_term = "{} {}".format(song_title, artist_name)
        print ("search",search_term)
        json_search = self._make_api_request((search_term, 'search'))

        # Loop through search results, stopping as soon as title and artist of
        # result match request
        n_hits = min(10, len(json_search['hits']))
        for i in range(n_hits):
            search_hit = json_search['hits'][i]['result']
            found_song = self._clean_str(search_hit['title'])
            found_artist = self._clean_str(
                search_hit['primary_artist']['name'])

            # Download song from Genius.com if title and artist match the request
            if take_first_result or found_song == self._clean_str(song_title) and found_artist == self._clean_str(artist_name) or artist_name == "":

                # Remove non-song results (e.g. Linear Notes, Tracklists, etc.)
                song_is_valid = self._result_is_lyrics(found_song) if remove_non_songs else True
                if song_is_valid:
                    # Found correct song, accessing API ID
                    json_song = self._make_api_request((search_hit['id'], 'song'))

                    # Scrape the song's HTML for lyrics
                    lyrics = self._scrape_song_lyrics_from_url(json_song['song']['url'], remove_section_headers)

                    # Create the Song object
                    song = Song(json_song, lyrics)

                    if verbose:
                        print('Done.')
                    return song
                else:
                    if verbose:
                        print('Specified song does not contain lyrics. Rejecting.')
                    return None

        if verbose:
            print('Specified song was not first result :(')
        return None

    def search_artist(self, artist_name, verbose=True, max_songs=None, take_first_result=False, get_full_song_info=True, remove_section_headers=False, remove_non_songs=True):
        """Allow user to search for an artist on the Genius.com database by supplying an artist name.
        Returns an Artist() object containing all songs for that particular artist."""

        if verbose:
            print('Searching for songs by {0}...\n'.format(artist_name))

        # Perform a Genius API search for the artist
        json_search = self._make_api_request((artist_name, 'search'))
        first_result, artist_id = None, None
        for hit in json_search['hits']:
            found_artist = hit['result']['primary_artist']
            if first_result is None:
                first_result = found_artist
            artist_id = found_artist['id']
            if take_first_result or self._clean_str(found_artist['name'].lower()) == self._clean_str(artist_name.lower()):
                artist_name = found_artist['name']
                break
            else:
                # check for searched name in alternate artist names
                json_artist = self._make_api_request((artist_id, 'artist'))['artist']
                if artist_name.lower() in [s.lower() for s in json_artist['alternate_names']]:
                    if verbose:
                        print("Found alternate name. Changing name to {}.".format(json_artist['name']))
                    artist_name = json_artist['name']
                    break
                artist_id = None

        if first_result is not None and artist_id is None and verbose:
            if input("Couldn't find {}. Did you mean {}? (y/n): ".format(artist_name, first_result['name'])).lower() == 'y':
                artist_name, artist_id = first_result['name'], first_result['id']
        assert (not isinstance(artist_id, type(None))), "Could not find artist. Check spelling?"

        # Make Genius API request for the determined artist ID
        json_artist = self._make_api_request((artist_id, 'artist'))
        # Create the Artist object
        artist = Artist(json_artist)

        if max_songs is None or max_songs > 0:
            # Access the api_path found by searching
            artist_search_results = self._make_api_request((artist_id, 'artist-songs'))

            # Download each song by artist, store as Song objects in Artist object
            keep_searching = True
            next_page = 0
            n = 0
            while keep_searching:
                for json_song in artist_search_results['songs']:
                    # TODO: Shouldn't I use self.search_song() here?

                    # Songs must have a title
                    if 'title' not in json_song:
                        json_song['title'] = 'MISSING TITLE'

                    # Remove non-song results (e.g. Linear Notes, Tracklists, etc.)
                    song_is_valid = self._result_is_lyrics(json_song['title']) if remove_non_songs else True

                    if song_is_valid:
                        # Scrape song lyrics from the song's HTML
                        lyrics = self._scrape_song_lyrics_from_url(json_song['url'], remove_section_headers)

                        # Create song object for current song
                        if get_full_song_info:
                            song = Song(self._make_api_request((json_song['id'], 'song')), lyrics)
                        else:
                            song = Song({'song': json_song}, lyrics)  # Faster, less info from API

                        # Add song to the Artist object
                        if artist.add_song(song, verbose=False) == 0:
                            # print("Add song: {}".format(song.title))
                            n += 1
                            if verbose:
                                print('Song {0}: "{1}"'.format(n, song.title))

                    else:  # Song does not contain lyrics
                        if verbose:
                            print('"{title}" does not contain lyrics. Rejecting.'.format(title=json_song['title']))

                    # Check if user specified a max number of songs for the artist
                    if not isinstance(max_songs, type(None)):
                        if artist.num_songs >= max_songs:
                            keep_searching = False
                            if verbose:
                                print('\nReached user-specified song limit ({0}).'.format(max_songs))
                            break

                # Move on to next page of search results
                next_page = artist_search_results['next_page']
                if next_page == None:
                    break
                else:  # Get next page of artist song results
                    artist_search_results = self._make_api_request((artist_id, 'artist-songs'), page=next_page)

            if verbose:
                print('Found {n_songs} songs.'.format(n_songs=artist.num_songs))

        if verbose:
            print('Done.')

        return artist

    def search_album(self, artist_name, album_title):
        """Get all lyrics from an album and save them in a json file"""

        # genius finds the artist
        artist = self.search_artist(artist_name, max_songs=0)
        # modify artist_name and album_title so that they will lead us to the album page on Genius.com
        artist_name = artist._body['name']
        for ch in [',', "/", " ", '$', ';', ':', '(', ')', '[', ']', '----', '---', '--']:
            if ch in artist_name:
                artist_name = artist_name.replace(ch, "-")
            if ch in album_title:
                album_title = album_title.replace(ch, "-")
        for ch in ['.', "\"", "'"]:
            if ch in artist_name:
                artist_name = artist_name.replace(ch, "")
            if ch in album_title:
                album_title = album_title.replace(ch, "-")
        for ch in ['é', 'è', 'ê', 'ë']:
            if ch in artist_name:
                artist_name = artist_name.replace(ch, "e")
            if ch in album_title:
                album_title = album_title.replace(ch, "e")

        artist_name = artist_name.replace("&", "and")
        album_title = album_title.replace("&", "").replace("#", "").replace("--", "-")

        while artist_name[-1] == '-':
            artist_name = artist_name[:-1]
        while album_title[-1] == '-':
            album_title = album_title[:-1]
        # create index
        index = []
        # get the album page on Genius.com
        r = requests.get('https://genius.com/albums/' + artist_name + "/" + album_title)
        soup = BeautifulSoup(r.text, 'html.parser')
        # get the html section indicating if the album isn't found
        not_found = soup.find('h1', attrs={'class': 'render_404-headline'})
        if not_found != None and "Page not found" in not_found.text:
            print("Album not found.")
            return None
        # get the html section indicating if the song is missing lyrics
        missing = soup.find_all('div', attrs={'class': 'chart_row-metadata_element chart_row-metadata_element--large'})
        miss_nb = 0
        # count the number of songs without lyrics
        for miss in missing:
            if miss.text.find("(Missing Lyrics)") >= 0 or miss.text.find("(Unreleased)") >= 0:
                miss_nb += 1
        divi = soup.find_all('div', attrs={'class': 'column_layout-column_span column_layout-column_span--primary'})
        for div in divi:
            var = 0
            # get the html section indicating the track numbers (this will be to eliminate sections similar to those of songs but are actually of tracklist or credits of the album)
            mdiv = div.find_all('span', attrs={'class': 'chart_row-number_container-number chart_row-number_container-number--gray'})
            for mindiv in mdiv:
                nb = mindiv.text.replace("\n", "")
                if nb != "":
                    index.append(nb)
            # create a list holding the tracks' titles
            df = []
            ndiv = div.find_all('h3', attrs={'class': 'chart_row-content-title'})
            for mindiv in ndiv:
                tt = mindiv.text.replace("\n", "").strip()
                # getting rid of the featurings in the title
                if tt.find("(Ft") >= 0:
                    tt = tt.split(" (Ft.", 1)[0]
                else:
                    # getting ride of "lyrics" at the end of the title
                    tt = tt.rsplit(" ", 1)[0].strip()
                df.append(tt)
                var += 1
                if var == len(index):
                    break
        # loop to add song with title from the list
        for track in df:
            # search the song
#             print ("track",track)
            song = self.search_song(track, artist.name,take_first_result=True)
#             print (song) 
            # if the song was found, it's added to artist
            if song != None:
                artist.add_song(song)
            # if the song wasn't found, it might be because it's formatted in this way : "title by other artist"
            elif track.find("by") >= 0:
                s_artist_name = track.replace("\xa0", " ").rsplit(" by ", 1)[1]
                s_artist = self.search_artist(s_artist_name, max_songs=0)
                track = track.replace("\xa0", " ").rsplit(" by ", 1)[0].strip()
                # look for song with other artist
                song = self.search_song(track, s_artist.name)
                if song != None:
                    # add song to the album's main artist
                    artist.add_song(song)
                else:
                    print("Missing lyrics")
            else:
                print("Missing lyrics")
        artist.save_lyrics("json",album=album_title)
        if miss_nb == 1:
            print("{} song was ignored due to missing lyrics.".format(miss_nb))
        elif miss_nb > 1:
            print("{} songs were ignored due to missing lyrics.".format(miss_nb))

    def save_artists(self, artists, filename="artist_lyrics", overwrite=False):
        """Pass a list of Artist objects to save multiple artists"""
        if isinstance(artists, Artist):
            artists = [artists]
        assert isinstance(artists, list), "Must pass in list of Artist objects."

        # Create a temporary directory for lyrics
        start = time.time()
        tmp_dir = 'tmp_lyrics'
        if not os.path.isdir(tmp_dir):
            os.mkdir(tmp_dir)
            tmp_count = 0
        else:
            tmp_count = len(os.listdir('./' + tmp_dir))

        # Check if file already exists
        write_file = False
        if not os.path.isfile(filename + ".json"):
            pass
        elif overwrite:
            pass
        else:
            if input("{} already exists. Overwrite?\n(y/n): ".format(filename)).lower() != 'y':
                print("Leaving file in place. Exiting.")
                os.rmdir(tmp_dir)
                return

        # Extract each artist's lyrics in json format
        all_lyrics = {'artists': []}
        for n, artist in enumerate(artists):
            if isinstance(artist, Artist):
                all_lyrics['artists'].append({})
                tmp_file = "./{dir}/tmp_{num}_{name}".format(dir=tmp_dir, num=n + tmp_count, name=artist.name.replace(" ", ""))
                print(tmp_file)
                all_lyrics['artists'][-1] = artist.save_lyrics(filename=tmp_file, overwrite=True,album=album_title)
            else:
                warn("Item #{} was not of type Artist. Skipping.".format(n))

        # Save all of the lyrics
        with open(filename + '.json', 'w') as outfile:
            json.dump(all_lyrics, outfile)

        end = time.time()

# To get an album's lyrics:
#
# Get the token by signing in on the Genius website https://genius.com/api-clients
# client_access_token = 'YOUR_TOKEN_HERE'
# api = Genius(client_access_token)
# Genius.search_album(api, "DJ Khaled", "Grateful")

# %%
client_access_token = 'xe3uAhIb2OUZrYdBh9liV0IcFMzJOg7fCs4tmAaX4h9akRvwDtDwf_nJFsgrKjzc'
api = Genius(client_access_token)
Genius.search_album(api, "Tyler, The Creator", "Igor")
# Out:
# Searching for songs by Tyler, The Creator...
#
# Done.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-23c7801c67bd> in <module>
#       1 client_access_token = 'xe3uAhIb2OUZrYdBh9liV0IcFMzJOg7fCs4tmAaX4h9akRvwDtDwf_nJFsgrKjzc'
#       2 api = Genius(client_access_token)
# ----> 3 Genius.search_album(api, "Tyler, The Creator", "Igor")
#
# <ipython-input-8-afc81b9d53d5> in search_album(self, artist_name, album_title)
#     448         index = []
#     449         # get the album page on Genius.com
# --> 450         r = requests.get('https://genius.com/albums/' + artist_name + "/" + album_title)
#     451         soup = BeautifulSoup(r.text, 'html.parser')
#     452         # get the html section indicating if the album isn't found
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1334         try:
#    1335             try:
# -> 1336                 response.begin()
#    1337             except ConnectionError:
#    1338                 self.close()
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# ~/opt/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     295     def recv_into(self, *args, **kwargs):
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#     299             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1819             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1820         else:
# -> 1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# KeyboardInterrupt:

# %%
with open('Lyrics_Tyler,TheCreator.json') as json_file:
    data = json.load(json_file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-333b30972561> in <module>
# ----> 1 with open('Lyrics_Tyler,TheCreator.json') as json_file:
#       2     data = json.load(json_file)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Lyrics_Tyler,TheCreator.json'

# %%
data["songs"][0]["lyrics"].splitlines()
# Out:
# ['For real, for real this time',
#  'For real, for real, for real this time',
#  'Bitch, I cannot fall short',
#  'For real, for real, for real this time (Yeah, yeah)',
#  'For real, for real, for real this time',
#  '',
#  "'Cause you make my earth quake",
#  'Oh, you make my earth quake',
#  'Riding around, your love be shakin’ me up',
#  "And it's making my heart break",
#  "'Cause you make my earth quake",
#  'Oh, you make my earth quake (Earthquake, ooh)',
#  'Riding around, your love be shakin’ me up',
#  "And it's making my heart break",
#  '',
#  "Don't leave, it's my fault",
#  "Don't leave, it's my fault",
#  "Don't leave, it's my fault (Girl)",
#  '’Cause when it all comes crashing down I’ll need you',
#  '',
#  "'Cause you make my earth quake",
#  'Oh, you make my earth quake',
#  'Riding around, you’re telling me something is bad',
#  "And it's making my heart break",
#  "'Cause you make my earth quake, oh, you make my earth quake",
#  '(Earth quake, yeah)',
#  "Riding around, your love be shakin' me up",
#  'And it’s making my heart break (You already know)',
#  '',
#  "We ain't gotta ball, D. Rose, huh",
#  "I don't give a fuck 'bout none', huh",
#  "Beamin' like fuck my lungs, huh",
#  'Just might call my lawyer, huh',
#  "Plug gon' set me up, huh (Yeah)",
#  "Bih', don't set me up (Okay)",
#  "I'm with Tyler, yuh (Slime)",
#  'He ride like the car, huh',
#  'And she wicked, huh, yuh',
#  'Like Woah Vicky, huh, yeah (Like Woah Vicky)',
#  'Oh, my God, hold up, um',
#  'Diamonds not Tiffany, huh, yeah (Woah, woah)',
#  'So in love',
#  'So in love',
#  '',
#  "Don't leave, it's my fault (Fault)",
#  "Don't leave, it's my fault",
#  "Don't leave, it's my fault (Ayy)",
#  "'Cause when it all comes crashing down I'll need you (Ayy, ayy)",
#  '',
#  "'Cause you make my earth quake",
#  "I don't want no confrontation, no",
#  "You don't want my conversation (I don't want no conversation)",
#  'I just need some confirmation on how you feel (For real)',
#  "You don't want no complication, no",
#  "I don't want no side information (I don't want no side information)",
#  "I just need to know what's happening",
#  "'cause I'm for real (For real)",
#  '',
#  "I said don't leave, it's my fault (One)",
#  "I said don't leave, it's my fault (Two, two)",
#  "Don't leave, it's, it's my fault, girl (Three, three, three)",
#  "Don't, do-do-do-do-do, I need-"]

# %%
client_access_token = 'xe3uAhIb2OUZrYdBh9liV0IcFMzJOg7fCs4tmAaX4h9akRvwDtDwf_nJFsgrKjzc'
api = Genius(client_access_token)

for album in ["Wolf"]:
    Genius.search_album(api, "Tyler, The Creator", album)
# Out:
# Searching for songs by Tyler, The Creator...
#
# Done.
# Done.
# "Blow" by Tyler, The Creator:
#     If this was a game, I already know that I would come out winner
#     And I'm not bragging, I'ma be in her...
# Searching for "Pigs Fly" by Tyler, The Creator...
# search Pigs Fly Tyler, The Creator
# Done.
# "Pigs Fly" by Tyler, The Creator:
#     Ayy, ayy, uh
#
#     I was taught to act my shoe size, never my age
#     I always judge a book by the cover, nev...
# Searching for "Parade" by Tyler, The Creator...
# search Parade Tyler, The Creator
# Done.
# "Parade" by Tyler, The Creator:
#     Odd (I'm not yet a man)
#     Future (Still not of a boy)
#     Wolf (This my only joy)
#     Gang (Now let's parade i...
# Searching for "Slow It Down" by Tyler, The Creator...
# search Slow It Down Tyler, The Creator
# Done.
# "Slow It Down" by Tyler, The Creator:
#     Ace, the Creator
#     Hodgy Beats
#     OF (Drop it)
#
#     We come through throbbing like thunder storms
#     Make their ...
# Searching for "AssMilk" by Tyler, The Creator...
# search AssMilk Tyler, The Creator
# Done.
# "AssMilk" by Tyler, The Creator:
#     Uh, addicts arise when I arrive
#     In this cracked crack fag back slab in disguise
#     Fat sack of knives i...
# Searching for "VCR / Wheels" by Tyler, The Creator...
# search VCR / Wheels Tyler, The Creator
# Done.
# "VCR / Wheels" by Tyler, The Creator:
#     Part 1 - VCR
#
#     I don't want to play you
#     I just want to tape you undressing
#     And I'll lay you down and ...
# Searching for "Session" by Tyler, The Creator...
# search Session Tyler, The Creator
# Done.
# "Session" by Tyler, The Creator:
#     I'm Tyler, Mr. Green Hat
#     Pro-abortion, anti-clean rap
#     Fuck your blog opinion and your feedback
#     My se...
# Searching for "Sarah" by Tyler, The Creator...
# search Sarah Tyler, The Creator
# Done.
# "Sarah" by Tyler, The Creator:
#     I like my girls skinny with brains
#     I like my hoodies fucked with Lame
#     I like my friends imaginary wi...
# Searching for "Jack and the Beanstalk" by Tyler, The Creator...
# search Jack and the Beanstalk Tyler, The Creator
# Done.
# "Jack and the Beanstalk" by Tyler, The Creator:
#     They don't paint pictures, they just trace me
#
#     Odd Future, I'm your mothafucking sergeant
#     Nigga, I'm...
# Searching for "Tina" by Tyler, The Creator...
# search Tina Tyler, The Creator
# Done.
# "Tina" by Tyler, The Creator:
#     So, do you party?
#     Nah, I just do ignorant hoodrat shit with me and my niggas in the fucking mall, Od...
# Searching for "Inglorious" by Tyler, The Creator...
# search Inglorious Tyler, The Creator
# Done.
# "Inglorious" by Tyler, The Creator:
#     Well, Tyler...
#     Uh, it's about that time
#     I mean you're a good kid, just misguided
#     Okay, so is there a...
# Wrote 15 songs to Lyrics_Tyler,TheCreator{.Bastard.
# Searching for songs by Tyler, The Creator...
#
# Done.
# Searching for "Goblin" by Tyler, The Creator...
# search Goblin Tyler, The Creator
# Done.
# "Goblin" by Tyler, The Creator:
#     You wouldn't do that Tyler, kill yourself or anyone. You don't even have the balls to begin with. Wh...
# Searching for "Yonkers" by Tyler, The Creator...
# search Yonkers Tyler, The Creator
# Done.
# "Yonkers" by Tyler, The Creator:
#     Odd, Wolf Haley, Golf Wang
#
#     I'm a fuckin' walkin' paradox — no, I'm not
#     Threesomes with a fuckin' tr...
# Searching for "Radicals" by Tyler, The Creator...
# search Radicals Tyler, The Creator
# Done.
# "Radicals" by Tyler, The Creator:
#     Random disclaimer!
#     Hey, don't do anything that I say in this song, okay?
#     It's fucking fiction
#     If any...
# Searching for "She" by Tyler, The Creator...
# search She Tyler, The Creator
# Done.
# "She" by Tyler, The Creator:
#     Golden rubbers in these denim pockets
#     On my waist, there's a black Glock
#     New girl moved on the block...
# Searching for "Transylvania" by Tyler, The Creator...
# search Transylvania Tyler, The Creator
# Done.
# "Transylvania" by Tyler, The Creator:
#     Left Brain, Wolf Haley
#     Golf Wang, Free Earl, uh
#
#     Goddamn I love women
#     Daydream about penis being in ...
# Searching for "Nightmare" by Tyler, The Creator...
# search Nightmare Tyler, The Creator
# Done.
# "Nightmare" by Tyler, The Creator:
#     So, you tell me that everything just isn't going well
#     Well, first off...
#
#     My only problem is death
#     F...
# Searching for "Tron Cat" by Tyler, The Creator...
# search Tron Cat Tyler, The Creator
# Done.
# "Tron Cat" by Tyler, The Creator:
#     La, la, la, la, la, la, la
#     AAAAHHH!
#
#     Satan's getting jealous of the wolves, the demons say they pref...
# Searching for "Her" by Tyler, The Creator...
# search Her Tyler, The Creator
# Done.
# "Her" by Tyler, The Creator:
#     Oh I don't need the metronome bro
#     (Ey)
#     When you wanna be, ahh
#     When you eat all the cheese in the sto...
# Searching for "Sandwitches" by Tyler, The Creator...
# search Sandwitches Tyler, The Creator
# Done.
# "Sandwitches" by Tyler, The Creator:
#     Nigga had the fucking nerve to call me immature
#     Fuck you think I made Odd Future for?
#     To wear fuckin...
# Searching for "Fish / Boppin' Bitch" by Tyler, The Creator...
# search Fish / Boppin' Bitch Tyler, The Creator
# Done.
# "Fish / Boppin’ Bitch" by Tyler, The Creator:
#     Slip it in her drink, and in the blink of an eye
#     I can make a white girl look chink
#     Don't know what ...
# Searching for "Analog" by Tyler, The Creator...
# search Analog Tyler, The Creator
# Done.
# "Analog" by Tyler, The Creator:
#     I can grab the fireworks, and soda, all the cookies we can eat
#     Make you nauseous, but be cautious, t...
# Searching for "Bitch Suck Dick" by Tyler, The Creator...
# search Bitch Suck Dick Tyler, The Creator
# Done.
# "Bitch Suck Dick" by Tyler, The Creator:
#     Oh, shit (Swag)
#     Three icy ass niggas from Odd Future doin' some crazy shit (Bitch)
#     By the way, we do...
# Searching for "Window" by Tyler, The Creator...
# search Window Tyler, The Creator
# Done.
# "Window" by Tyler, The Creator:
#     Tyler, we, ah, I know it's short notice but I brought all your friends here
#     For some reason I couldn...
# Searching for "AU79" by Tyler, The Creator...
# search AU79 Tyler, The Creator
# Done.
# "AU79" by Tyler, The Creator:
#
# Searching for "Golden" by Tyler, The Creator...
# search Golden Tyler, The Creator
# Done.
# "Golden" by Tyler, The Creator:
#     "Tyler, you... obviously have some fucking problems...
#     And, this is... this is the end of this sessi...
# Searching for "Burger" by Tyler, The Creator...
# search Burger Tyler, The Creator
# Done.
# "Burger" by Tyler, The Creator:
#     Uh, Jesus, heheh
#
#     Nigga this is my cup
#     Drink the cyanide up
#     Dope as fuck
#     So I would really shoot a g...
# Searching for "Untitled 63" by Tyler, The Creator...
# search Untitled 63 Tyler, The Creator
# Done.
# "Untitled 63" by Tyler, The Creator:
#
# Searching for "Steak Sauce" by Tyler, The Creator...
# search Steak Sauce Tyler, The Creator
# Done.
# "Steak Sauce" by Tyler, The Creator:
#     Rollin' in a golden Tacoma, the shit's stolen
#     If that bitch tell on me, I'mma do a fuckin' drive-by ...
# SKIPPING "Untitled 63" -- already found in artist collection.
# Wrote 18 songs to Lyrics_Tyler,TheCreator{.Goblin.
# Searching for songs by Tyler, The Creator...
#
# Done.
# Searching for "DEATHCAMP" by Tyler, The Creator...
# search DEATHCAMP Tyler, The Creator
# Done.
# "DEATHCAMP" by Tyler, The Creator:
#     Um, excuse me mister, but can you please turn down the lights?
#     I don't really like all these cameras...
# Searching for "BUFFALO" by Tyler, The Creator...
# search BUFFALO Tyler, The Creator
# Done.
# "BUFFALO" by Tyler, The Creator:
#     "Yeah!"
#     "You feel alright?"
#     "Yeah!"
#
#     God, goodness gracious
#     I can't wait to see the look on y'all ni...
# Searching for "PILOT" by Tyler, The Creator...
# search PILOT Tyler, The Creator
# Done.
# "PILOT" by Tyler, The Creator:
#     Fly with the birds in the wind
#     Where you wanna go, who, what, why, when? Uh
#     On a scale of nine to te...
# Searching for "RUN" by Tyler, The Creator...
# search RUN Tyler, The Creator
# Done.
# "RUN" by Tyler, The Creator:
#     Fuck you running for nigga?
#     Aye nigga, come here nigga
#     Let me try that hat on
#     I told you come over h...
# Searching for "FIND YOUR WINGS" by Tyler, The Creator...
# search FIND YOUR WINGS Tyler, The Creator
# Done.
# "FIND YOUR WINGS" by Tyler, The Creator:
#     Find your wings (You're supposed to fly)
#     Find your wings (Find your wings)
#
#     Hey you, whatcha doin' a...
# Searching for "CHERRY BOMB" by Tyler, The Creator...
# search CHERRY BOMB Tyler, The Creator
# Done.
# "CHERRY BOMB" by Tyler, The Creator:
#     I really made this song just so I could perform it
#     I don't even know what it mean
#     It means something...
# Searching for "BLOW MY LOAD" by Tyler, The Creator...
# search BLOW MY LOAD Tyler, The Creator
# Done.
# "BLOW MY LOAD" by Tyler, The Creator:
#     I don't want you thinking I love you 'cause I stay
#     Girl I really like you and happy we got laid
#     I th...
# Searching for "2SEATER" by Tyler, The Creator...
# search 2SEATER Tyler, The Creator
# Done.
# "2SEATER" by Tyler, The Creator:
#     We can speed in my 2 seater
#     Girl I got a 2 seater
#     Speed in my 2 seater
#     In my 2 seater
#
#     About a hundr...
# Searching for "THE BROWN STAINS OF DARKEESE LATIFAH PART 6-12 (Remix)" by Tyler, The Creator...
# search THE BROWN STAINS OF DARKEESE LATIFAH PART 6-12 (Remix) Tyler, The Creator
# Done.
# "THE BROWN STAINS OF DARKEESE LATIFAH PART 6-12 (Remix)" by Tyler, The Creator:
#     Part 1 - THE BROWN STAINS OF DARKEESE LATIFAH PART 6-12 (Remix)
#
#     Oh, you the motherfucking man, huh?...
# Searching for "FUCKING YOUNG / PERFECT" by Tyler, The Creator...
# search FUCKING YOUNG / PERFECT Tyler, The Creator
# Done.
# "FUCKING YOUNG / PERFECT" by Tyler, The Creator:
#     Part 1 - FUCKING YOUNG
#
#     Day that I met you girl
#     I knew that it was something special
#     But I couldn't ...
# Searching for "SMUCKERS" by Tyler, The Creator...
# search SMUCKERS Tyler, The Creator
# Done.
# "SMUCKERS" by Tyler, The Creator:
#     Part I
#
#     For your boy, I'm watching Freaks and Geeks with the trampoline on the floor
#     I'm tryna cop t...
# Searching for "KEEP DA O'S" by Tyler, The Creator...
# search KEEP DA O'S Tyler, The Creator
# Done.
# "KEEP DA O’S" by Tyler, The Creator:
#     Got the whips, got the hoes
#     Got the ice, got the clothes
#     Niggas know that keys open doors
#     Half price...
# Searching for "OKAGA, CA" by Tyler, The Creator...
# search OKAGA, CA Tyler, The Creator
# Done.
# "OKAGA, CA" by Tyler, The Creator:
#     Let's just run away from here (cause it's not, cause it's not)
#     Working out on Earth, my dear (cause ...
# Searching for "YELLOW" by Tyler, The Creator...
# search YELLOW Tyler, The Creator
# Done.
# "YELLOW" by Tyler, The Creator:
#     Now when I first saw you
#     I could tell you was the one
#     That I've been searchin' for
#     I needed somethin...
# Wrote 14 songs to Lyrics_Tyler,TheCreator{.Cherry-Bomb.
# Searching for songs by Tyler, The Creator...
#
# Done.
# Searching for "Foreword" by Tyler, The Creator...
# search Foreword Tyler, The Creator
# Done.
# "Foreword" by Tyler, The Creator:
#     Bitch, fuck! (Uh, uh, fuck)
#     You have a question?
#
#     How many cars can I buy 'til I run outta drive?
#     Ho...
# Searching for "Where This Flower Blooms" by Tyler, The Creator...
# search Where This Flower Blooms Tyler, The Creator
# Done.
# "Where This Flower Blooms" by Tyler, The Creator:
#     Ayo
#     Let's take it back to them days
#     Counting sheep on Sadie Hannah's floor
#     Carpet was my baby mama
#     8...
# Searching for "Sometimes..." by Tyler, The Creator...
# search Sometimes... Tyler, The Creator
# Done.
# "Sometimes..." by Tyler, The Creator:
#     Sometimes, I sit in my room and think about us
#
#     "It's Golf Radio, you're on the air with Shane Power...
# Searching for "See You Again" by Tyler, The Creator...
# search See You Again Tyler, The Creator
# Done.
# "See You Again" by Tyler, The Creator:
#     Okay, okay, okay, okay
#     Okay, okay, oh
#
#     You live in my dream state
#     Relocate my fantasy
#     I stay in real...
# Searching for "Who Dat Boy" by Tyler, The Creator...
# search Who Dat Boy Tyler, The Creator
# Done.
# "Who Dat Boy" by Tyler, The Creator:
#     Yo, who dat boy? Who him is?
#     Him that ni-guh, I swear
#     Stand out guy, him don't need no chair
#     Well, w...
# Searching for "Pothole" by Tyler, The Creator...
# search Pothole Tyler, The Creator
# Done.
# "Pothole" by Tyler, The Creator:
#     Shit
#
#     My mother warned me that some niggas ain't my right hand
#     To trust her, only my heart and that ...
# Searching for "Garden Shed" by Tyler, The Creator...
# search Garden Shed Tyler, The Creator
# Done.
# "Garden Shed" by Tyler, The Creator:
#     Don't kill a rose
#     Before it could bloom
#     Fly, baby, fly
#     Out the cocoon
#
#     You don't have to hide
#     I can ...
# Searching for "Boredom" by Tyler, The Creator...
# search Boredom Tyler, The Creator
# Done.
# "Boredom" by Tyler, The Creator:
#     When you're having fun, fun
#     Time flies, time flies, time flies
#     When you're having fun (time flies)
#     O...
# Searching for "I Ain't Got Time!" by Tyler, The Creator...
# search I Ain't Got Time! Tyler, The Creator
# Done.
# "I Ain’t Got Time!" by Tyler, The Creator:
#     Right now we got some new music only here on Golf Radio!
#     (God I love this sample)
#     We're going to dan...
# Searching for "911 / Mr. Lonely" by Tyler, The Creator...
# search 911 / Mr. Lonely Tyler, The Creator
# Done.
# "911 / Mr. Lonely" by Tyler, The Creator:
#     (Call me, call me, call me) Uh
#     (Call me, call me, call me) Uh
#     (Call me, call me, call me) Uh
#     (Call m...
# Searching for "Droppin' Seeds" by Tyler, The Creator...
# search Droppin' Seeds Tyler, The Creator
# Done.
# "Droppin’ Seeds" by Tyler, The Creator:
#     Mula!
#     Like Adam in the Garden of Eve
#     My bitch got an apple bottom and she swallow my seeds
#     Follow my...
# Searching for "November" by Tyler, The Creator...
# search November Tyler, The Creator
# Done.
# "November" by Tyler, The Creator:
#     Say some more, never want to talk about it
#     Feel a way, woah
#     Feel a way, woah
#     Feel a way, woah
#
#     Take ...
# Searching for "Glitter" by Tyler, The Creator...
# search Glitter Tyler, The Creator
# Done.
# "Glitter" by Tyler, The Creator:
#     Da na na na na, da na na na na
#     Da na na na na, my baby
#     You've been on my mind (How ya feel?)
#     I'm los...
# Searching for "Enjoy Right Now, Today" by Tyler, The Creator...
# search Enjoy Right Now, Today Tyler, The Creator
# Done.
# "Enjoy Right Now, Today" by Tyler, The Creator:
#
# Wrote 14 songs to Lyrics_Tyler,TheCreator{.Flower-Boy.
# Searching for songs by Tyler, The Creator...
#
# Done.
# Searching for "IGOR'S THEME" by Tyler, The Creator...
# search IGOR'S THEME Tyler, The Creator
# Done.
# "IGOR’S THEME" by Tyler, The Creator:
#     What, what, what, what, what, what, what, what, what, what?
#     Uh!
#     Runnin', runnin’, runnin', runnin'
#     U...
# Searching for "EARFQUAKE" by Tyler, The Creator...
# search EARFQUAKE Tyler, The Creator
# Done.
# "EARFQUAKE" by Tyler, The Creator:
#     For real, for real this time
#     For real, for real, for real this time
#     Bitch, I cannot fall short
#     For r...
# Searching for "I THINK" by Tyler, The Creator...
# search I THINK Tyler, The Creator
# Done.
# "I THINK" by Tyler, The Creator:
#     (Four, four, four, four)
#     (Four, skate, four, skate, four, skate, four, skate)
#
#     I don't know where I’...
# Searching for "EXACTLY WHAT YOU RUN FROM YOU END UP CHASING" by Tyler, The Creator...
# search EXACTLY WHAT YOU RUN FROM YOU END UP CHASING Tyler, The Creator
# Done.
# "EXACTLY WHAT YOU RUN FROM YOU END UP CHASING" by Tyler, The Creator:
#     Exactly what you run from, you end up chasing. Like, you can't avoid, but just chasing it and just l...
# Searching for "RUNNING OUT OF TIME" by Tyler, The Creator...
# search RUNNING OUT OF TIME Tyler, The Creator
# Done.
# "RUNNING OUT OF TIME" by Tyler, The Creator:
#     Runnin' out of time, runnin' out of time, runnin' out of time
#     Runnin' out of time to make you love m...
# Searching for "NEW MAGIC WAND" by Tyler, The Creator...
# search NEW MAGIC WAND Tyler, The Creator
# Done.
# "NEW MAGIC WAND" by Tyler, The Creator:
#     Sometimes you gotta close a door to open a window
#
#     I saw a photo, you looked joyous
#     My eyes are gree...
# Searching for "A BOY IS A GUN*" by Tyler, The Creator...
# search A BOY IS A GUN* Tyler, The Creator
# Done.
# "A BOY IS A GUN*" by Tyler, The Creator:
#     No, don't shoot me down (Yeah)
#     No, don't shoot me down (Okay)
#     No, don't shoot me down
#
#     You so mother...
# Searching for "PUPPET" by Tyler, The Creator...
# search PUPPET Tyler, The Creator
# Done.
# "PUPPET" by Tyler, The Creator:
#     Ayo
#     I wanna talk, I wanna call you and talk
#     I wanna walk to your front door and knock
#     After I start ...
# Searching for "WHAT'S GOOD" by Tyler, The Creator...
# search WHAT'S GOOD Tyler, The Creator
# Done.
# "WHAT’S GOOD" by Tyler, The Creator:
#     Turn my lights on
#     How the fuck you quiet with the mic on?
#     I don't get anxiety, you Sam Bowie-ass nig...
# Searching for "GONE, GONE / THANK YOU" by Tyler, The Creator...
# search GONE, GONE / THANK YOU Tyler, The Creator
# Done.
# "GONE, GONE / THANK YOU" by Tyler, The Creator:
#     Comparing scars before dinner
#     Jump off the roof into the mirror
#     Felt like summer to my December
#     Was ...
# Searching for "I DON'T LOVE YOU ANYMORE" by Tyler, The Creator...
# search I DON'T LOVE YOU ANYMORE Tyler, The Creator
# Done.
# "I DON’T LOVE YOU ANYMORE" by Tyler, The Creator:
#     See, um, heavy feelings for you, yeah, yeah, it's no secret
#     You too cool for me and I ain't tryna fr...
# Searching for "ARE WE STILL FRIENDS?" by Tyler, The Creator...
# search ARE WE STILL FRIENDS? Tyler, The Creator
# Done.
# "ARE WE STILL FRIENDS?" by Tyler, The Creator:
#     Dream
#     Just dream
#     Long ago, long ago, long ago
#     Dream
#     Just dream
#
#     Are we still friends? Can we be frie...
# Wrote 12 songs to Lyrics_Tyler,TheCreator{.Igor.

# %%
client_access_token = 'xe3uAhIb2OUZrYdBh9liV0IcFMzJOg7fCs4tmAaX4h9akRvwDtDwf_nJFsgrKjzc'
api = Genius(client_access_token)

for album in ["nostalgia, ULTRA.","Channel Orange", "Endless","Blonde"]:
    Genius.search_album(api, "Frank Ocean", album)
# Out:
# Searching for songs by Frank Ocean...
#
# Done.
# Searching for "Street Fighter" by Frank Ocean...
# search Street Fighter Frank Ocean
# Done.
# "Street Fighter" by Frank Ocean:
#
# Searching for "Strawberry Swing" by Frank Ocean...
# search Strawberry Swing Frank Ocean
# Done.
# "Strawberry Swing" by Frank Ocean:
#     When we were kids, we handpainted strawberries on a swing
#     Every moment was so precious, then
#     I'm sti...
# Searching for "Novacane" by Frank Ocean...
# search Novacane Frank Ocean
# Done.
# "Novacane" by Frank Ocean:
#     I think I started something, I got what I wanted
#     Did-didn't I can't feel nothing, superhuman
#     Even wh...
# Searching for "We All Try" by Frank Ocean...
# search We All Try Frank Ocean
# Done.
# "We All Try" by Frank Ocean:
#     I believe Jehovah Jireh
#     I believe there's heaven, I believe in war
#     I believe a woman's temple
#     Gives ...
# Searching for "Bitches Talkin' (Metal Gear Solid)" by Frank Ocean...
# search Bitches Talkin' (Metal Gear Solid) Frank Ocean
# Done.
# "Bitches Talkin’ (Metal Gear Solid)" by Frank Ocean:
#     Stop! Stop! Stooooop! Let me do it!
#     (Fine)
#     No you always play what you want to play. I want to play
#     ...
# Searching for "Songs 4 Women" by Frank Ocean...
# search Songs 4 Women Frank Ocean
# Done.
# "Songs 4 Women" by Frank Ocean:
#     When I was younger I used to wonder like
#
#     If I was singing songs just to sing the songs
#     Or if I was ...
# Searching for "Lovecrimes" by Frank Ocean...
# search Lovecrimes Frank Ocean
# Done.
# "Lovecrimes" by Frank Ocean:
#     Crazy, I plead insanity
#     Crazy for you, baby
#     Crazy, na na
#
#     Talk to me and I better not hear a word
#     Do...
# Searching for "Goldeneye" by Frank Ocean...
# search Goldeneye Frank Ocean
# Done.
# "Goldeneye" by Frank Ocean:
#
# Searching for "There Will Be Tears" by Frank Ocean...
# search There Will Be Tears Frank Ocean
# Done.
# "There Will Be Tears" by Frank Ocean:
#     There will be tears, I've no doubt
#     There may be smiles but a few
#     And when those tears have run out
#     W...
# Searching for "Swim Good" by Frank Ocean...
# search Swim Good Frank Ocean
# Done.
# "Swim Good" by Frank Ocean:
#     That's a pretty big trunk on my Lincoln town car, ain't it?
#     Big enough to take these broken hearts a...
# Searching for "Dust" by Frank Ocean...
# search Dust Frank Ocean
# Done.
# "Dust" by Frank Ocean:
#     Who's that talking in the library?
#     Who's that talking in my library?
#     Is that you? No I won't put you...
# Searching for "American Wedding" by Frank Ocean...
# search American Wedding Frank Ocean
# Done.
# "American Wedding" by Frank Ocean:
#     American love, American me, American you
#     American tear, American heartbreak, oh, oh, oh
#
#     I took a wa...
# Searching for "Soul Calibur" by Frank Ocean...
# search Soul Calibur Frank Ocean
# Done.
# "Soul Calibur" by Frank Ocean:
#
# Searching for "Nature Feels" by Frank Ocean...
# search Nature Feels Frank Ocean
# Done.
# "Nature Feels" by Frank Ocean:
#     I've been meaning to fuck you in the garden
#     Been breathing so hard, we both could use the oxygen
#     Jus...
# SKIPPING "Goldeneye" -- already found in artist collection.
# SKIPPING "Soul Calibur" -- already found in artist collection.
# Wrote 14 songs to Lyrics_FrankOcean{.nostalgia-ULTRA.
# Searching for songs by Frank Ocean...
#
# Done.
# Searching for "Start" by Frank Ocean...
# search Start Frank Ocean
# Done.
# "Start" by Frank Ocean:
#     They look like twins
#     That was embarrassing
# Searching for "Thinkin Bout You" by Frank Ocean...
# search Thinkin Bout You Frank Ocean
# Done.
# "Thinkin Bout You" by Frank Ocean:
#     A tornado flew around my room before you came
#     Excuse the mess it made, it usually doesn't rain in
#     So...
# Searching for "Fertilizer" by Frank Ocean...
# search Fertilizer Frank Ocean
# Done.
# "Fertilizer" by Frank Ocean:
#     (Really, though, I think)
#     Fertilizer
#     I'll take bullshit if that's all you got
#     Some fertilizer
#     Fertil...
# Searching for "Sierra Leone" by Frank Ocean...
# search Sierra Leone Frank Ocean
# Done.
# "Sierra Leone" by Frank Ocean:
#     (We're spendin' too much time alone)
#     Spendin' too much time alone
#     (And I just ran outta Trojans)
#     Hor...
# Searching for "Sweet Life" by Frank Ocean...
# search Sweet Life Frank Ocean
# Done.
# "Sweet Life" by Frank Ocean:
#     The best song wasn't the single, but you weren't either
#     Livin' in Ladera Heights, the black Beverly ...
# Searching for "Not Just Money" by Frank Ocean...
# search Not Just Money Frank Ocean
# Done.
# "Not Just Money" by Frank Ocean:
#     Stop thinking of this as being money
#     It's just money, I'ma make more
#     No, no no no no no
#     Please decon...
# Searching for "Super Rich Kids" by Frank Ocean...
# search Super Rich Kids Frank Ocean
# Done.
# "Super Rich Kids" by Frank Ocean:
#     Too many bottles of this wine we can't pronounce
#     Too many bowls of that green, no Lucky Charms
#     The m...
# Searching for "Pilot Jones" by Frank Ocean...
# search Pilot Jones Frank Ocean
# Done.
# "Pilot Jones" by Frank Ocean:
#     We once had things in common
#     Now the only thing we share is the refrigerator
#     Ice cold, baby, I told ...
# Searching for "Crack Rock" by Frank Ocean...
# search Crack Rock Frank Ocean
# Done.
# "Crack Rock" by Frank Ocean:
#     You don't know how little you matter until you're all alone
#     In the middle of Arkansas with a little ...
# Searching for "Pyramids" by Frank Ocean...
# search Pyramids Frank Ocean
# Done.
# "Pyramids" by Frank Ocean:
#     Set the cheetahs on the loose
#     There's a thief out on the move
#     Underneath our legion's view
#     They have...
# Searching for "Lost" by Frank Ocean...
# search Lost Frank Ocean
# Done.
# "Lost" by Frank Ocean:
#     Double D
#     Big full breasts on my baby
#     (Yo we going to Florida)
#     Triple weight
#     Couldn't weigh the love ...
# Searching for "White" by Frank Ocean...
# search White Frank Ocean
# Done.
# "Pink + White" by Frank Ocean:
#     Yeah, yeah (woo!)
#     Yeah, yeah, yeah
#
#     That's the way every day goes
#     Every time we've no control
#     If the...
# Searching for "Monks" by Frank Ocean...
# search Monks Frank Ocean
# Done.
# "Monks" by Frank Ocean:
#     Mosh pits and bare chest
#     Stage diving sky diver
#     Spray the crowd with cold water
#     Now it's mosh pits a...
# Searching for "Bad Religion" by Frank Ocean...
# search Bad Religion Frank Ocean
# Done.
# "Bad Religion" by Frank Ocean:
#     Taxi driver
#     Be my shrink for the hour
#     Leave the meter running
#     It's rush hour
#     So take the streets if ...
# Searching for "Pink Matter" by Frank Ocean...
# search Pink Matter Frank Ocean
# Done.
# "Pink Matter" by Frank Ocean:
#     And the peaches and the mangos
#     That you could sell for me
#
#     What do you think my brain is made for
#     Is...
# Searching for "Forrest Gump" by Frank Ocean...
# search Forrest Gump Frank Ocean
# Done.
# "Forrest Gump" by Frank Ocean:
#     I wanna see your pom poms from the stands
#     Come on, come on
#
#     My fingertips and my lips
#     They burn from...
# Searching for "End/Golden Girl" by Frank Ocean...
# search End/Golden Girl Frank Ocean
# Done.
# "End/Golden Girl" by Frank Ocean:
#     Darker times
#     They're telling boulder heavy lies
#     Looks like all we've got is each other
#     The truth is ...
# Wrote 17 songs to Lyrics_FrankOcean{.Channel-Orange.
# Searching for songs by Frank Ocean...
#
# Done.
# Searching for "At Your Best (You Are Love)" by Frank Ocean...
# search At Your Best (You Are Love) Frank Ocean
# Done.
# "At Your Best (You Are Love)" by Frank Ocean:
#     When I feel what I feel
#     Sometimes it's hard to tell you so
#     You may not be in the mood to learn
#     What ...
# Searching for "Alabama" by Frank Ocean...
# search Alabama Frank Ocean
# Done.
# "Alabama" by Frank Ocean:
#     Yup, duplex in New Orleans east
#     I was writin' down everything
#     Things I would tell nobody
#     Some things...
# Searching for "Mine" by Frank Ocean...
# search Mine Frank Ocean
# Done.
# "Mine" by Frank Ocean:
#     How come the ecstasy always depresses me so?
#     Chemically I don't have no more new places to go
# Searching for "UNITY" by Frank Ocean...
# search UNITY Frank Ocean
# Done.
# "UNITY" by Frank Ocean:
#     U-N-I-T
#     U-N-I
#
#     My head fatiguing off the opus
#     Kept it underground to focus
#     I feel afterlife, six und...
# Searching for "A Certain Way" by Frank Ocean...
# search A Certain Way Frank Ocean
# Done.
# "A Certain Way" by Frank Ocean:
#     In a certain way
#     'Cause you are beautiful and you are young
#     You deserve to have the best in life
#     In ...
# Searching for "Comme Des Garçons" by Frank Ocean...
# search Comme Des Garçons Frank Ocean
# Done.
# "Comme Des Garçons" by Frank Ocean:
#     He came up in Dallas
#     Had no hazel in his eyes
#     Had them sailors on his thighs
#     When he's lit he show '...
# Searching for "Xenons" by Frank Ocean...
# search Xenons Frank Ocean
# Done.
# "Xenons" by Frank Ocean:
#     Oh, yes, oh, slide
#     Xenons with the blue color
#     If that's a lease, least it look cool on you
#     That's yo...
# Searching for "Honeybaby" by Frank Ocean...
# search Honeybaby Frank Ocean
# Done.
# "Honeybaby" by Frank Ocean:
#     Oh, minha honey baby! Woo!
# Searching for "Wither" by Frank Ocean...
# search Wither Frank Ocean
# Done.
# "Wither" by Frank Ocean:
#     Over where the trees burn down
#     The place where the fields went down in flames
#     We could put a hole in...
# Searching for "Hublots" by Frank Ocean...
# search Hublots Frank Ocean
# Done.
# "Hublots" by Frank Ocean:
#     Cityview turned to the mountainview
#     Find a place for a quiet one
#     Suburbia got a yard
#     All this estate...
# Searching for "In Here Somewhere" by Frank Ocean...
# search In Here Somewhere Frank Ocean
# Done.
# "In Here Somewhere" by Frank Ocean:
#     I know you're in here somewhere
#     You came with someone
#     There's something you need someone out there
#     B...
# Searching for "Slide on Me" by Frank Ocean...
# search Slide on Me Frank Ocean
# Done.
# "Slide on Me" by Frank Ocean:
#     Gotta rinse off here
#     I can't see your diamonds
#     I need a week paradise
#     I went god mode all year
#     I can...
# Searching for "Sideways" by Frank Ocean...
# search Sideways Frank Ocean
# Done.
# "Sideways" by Frank Ocean:
#     Woo! (Woo, woo)
#     Woo!
#
#     I was in all them hours in it
#     10K, tokin' mid strokes
#     Prime prime time of my l...
# Searching for "Florida" by Frank Ocean...
# search Florida Frank Ocean
# Done.
# "Florida" by Frank Ocean:
#
# Searching for "Impietas + Deathwish (ASR)" by Frank Ocean...
# search Impietas + Deathwish (ASR) Frank Ocean
# Done.
# "Impietas + Deathwish (ASR)" by Frank Ocean:
#     Are you against me or are you with me?
#     Are you with me?
#     Are you with me?
#
#
#     Is it a deathwish to doze...
# Searching for "Rushes" by Frank Ocean...
# search Rushes Frank Ocean
# Done.
# "Rushes" by Frank Ocean:
#     Gonna be somebody, oh I follow
#     Oh and it's so cloudy
#     Running showers and the mist so fly
#     Enough time...
# Searching for "Rushes To" by Frank Ocean...
# search Rushes To Frank Ocean
# Done.
# "Rushes To" by Frank Ocean:
#
# Searching for "Higgs" by Frank Ocean...
# search Higgs Frank Ocean
# Done.
# "Higgs" by Frank Ocean:
#     Saturdays involved making our entrances into life outside
#     We've been in this room too long
#     Recreatio...
# Searching for "Mitsubishi Sony" by Frank Ocean...
# search Mitsubishi Sony Frank Ocean
# Done.
# "Mitsubishi Sony" by Frank Ocean:
#     That ain't really loud
#     Couldn't raise his voice 'cause his wind gone
#     Niggas sound like Reggie
#     (Alrea...
# SKIPPING "Rushes To" -- already found in artist collection.
# Wrote 19 songs to Lyrics_FrankOcean{.Endless.
# Searching for songs by Frank Ocean...
#
# Done.
# Searching for "Nikes" by Frank Ocean...
# search Nikes Frank Ocean
# Done.
# "Nikes" by Frank Ocean:
#     These bitches want Nikes
#     They looking for a check
#     Tell 'em it ain’t likely
#     Said she need a ring like...
# Searching for "Ivy" by Frank Ocean...
# search Ivy Frank Ocean
# Done.
# "Ivy" by Frank Ocean:
#     I thought that I was dreamin' when you said you love me
#     The start of nothin', I had no chance to pre...
# Searching for "Pink + White" by Frank Ocean...
# search Pink + White Frank Ocean
# Done.
# "Pink + White" by Frank Ocean:
#     Yeah, yeah (woo!)
#     Yeah, yeah, yeah
#
#     That's the way every day goes
#     Every time we've no control
#     If the...
# Searching for "Be Yourself" by Frank Ocean...
# search Be Yourself Frank Ocean
# Done.
# "Be Yourself" by Frank Ocean:
#     Many college students have gone to college
#     And gotten hooked on drugs, marijuana, and alcohol
#     Listen...
# Searching for "Solo" by Frank Ocean...
# search Solo Frank Ocean
# Done.
# "Solo" by Frank Ocean:
#     Hand me a towel, I'm dirty dancing by myself
#     Gone off tabs of that acid
#     Form me a circle, watch my J...
# Searching for "Skyline To" by Frank Ocean...
# search Skyline To Frank Ocean
# Done.
# "Skyline To" by Frank Ocean:
#     This is joy, this is summer
#     Keep alive, stay alive
#     Got your metal on, we're alone
#     Making sweet love,...
# Searching for "Self Control" by Frank Ocean...
# search Self Control Frank Ocean
# Done.
# "Self Control" by Frank Ocean:
#     Poolside convo about your summer last night, ooh yeah
#     About your summer last night
#     Ain't give you no...
# Searching for "Good Guy" by Frank Ocean...
# search Good Guy Frank Ocean
# Done.
# "Good Guy" by Frank Ocean:
#     Here's to the good guy, he hooked it up
#     Said if I was in NY I should look you up
#     First time I'd ever...
# Searching for "Nights" by Frank Ocean...
# search Nights Frank Ocean
# Done.
# "Nights" by Frank Ocean:
#     Round your city, round the clock
#     Everybody needs you
#     No, you can't make everybody equal
#     Although you...
# Searching for "Solo (Reprise)" by Frank Ocean...
# search Solo (Reprise) Frank Ocean
# Done.
# "Solo (Reprise)" by Frank Ocean:
#     Ayy, ayy, so now I'm—
#
#     So low that I can see under the skirt of an ant
#     So low that I don't get high ...
# Searching for "Pretty Sweet" by Frank Ocean...
# search Pretty Sweet Frank Ocean
# Done.
# "Pretty Sweet" by Frank Ocean:
#     Now, to the edge I'll race
#     To the end I'll make it
#     All the risk, I'll take it
#     Head bang with my faux...
# Searching for "Facebook Story" by Frank Ocean...
# search Facebook Story Frank Ocean
# Done.
# "Facebook Story" by Frank Ocean:
#     I was just telling that I got  this girl before
#     And I was together since 3 years
#     And uhh, I was not ...
# Searching for "Close to You" by Frank Ocean...
# search Close to You Frank Ocean
# Done.
# "Close to You" by Frank Ocean:
#     I'll be honest, I wasn't devastated
#     But you could've held my hands through this, baby
#     Let my mind ru...
# Searching for "White Ferrari" by Frank Ocean...
# search White Ferrari Frank Ocean
# Done.
# "White Ferrari" by Frank Ocean:
#     Bad luck to talk on these rides
#     Mine on the road, your dilated eyes watch the clouds float
#     White Fer...
# Searching for "Seigfried" by Frank Ocean...
# search Seigfried Frank Ocean
# Done.
# "Seigfried" by Frank Ocean:
#     The markings on your surface
#     Your speckled face
#     Flawed crystals hang from your ears
#     I couldn't gauge...
# Searching for "Godspeed" by Frank Ocean...
# search Godspeed Frank Ocean
# Done.
# "Godspeed" by Frank Ocean:
#     I will always love you how I do
#     Let go of a prayer for you
#     Just a sweet word
#     The table is prepared f...
# Searching for "Futura Free" by Frank Ocean...
# search Futura Free Frank Ocean
# Done.
# "Futura Free" by Frank Ocean:
#     Alright, hold on
#
#     If I was being honest
#     I'd say long as I could fuck three times a day
#     And not skip ...
# Wrote 17 songs to Lyrics_FrankOcean{.Blonde.

# %%
client_access_token = 'xe3uAhIb2OUZrYdBh9liV0IcFMzJOg7fCs4tmAaX4h9akRvwDtDwf_nJFsgrKjzc'
api = Genius(client_access_token)

for album in ["I Am Just a Rapper","Culdesac","Camp","Because the Internet","STN MTN/Kauai","Awaken, My Love","Summer Pack"]:
    Genius.search_album(api, "Childish Gambino", album)
# Out:
# Searching for songs by Childish Gambino...
#
# Done.
# Searching for "New Prince (Crown on the Ground)" by Childish Gambino...
# search New Prince (Crown on the Ground) Childish Gambino
# Done.
# "New Prince (Crown on the Ground)" by Childish Gambino:
#     I do not talk, I am just a rapper
#     Stompin' on these niggas like a whack-a-mole with no hands
#     Get gir...
# Searching for "Bitch, Look at Me Now" by Childish Gambino...
# search Bitch, Look at Me Now Childish Gambino
# Done.
# "Bitch, Look at Me Now" by Childish Gambino:
#     I do not talk, I am just a rapper
#     Sick boi make moves like a chess piece
#     And that move real quick li...
# Searching for "49ers (Orange Shirt)" by Childish Gambino...
# search 49ers (Orange Shirt) Childish Gambino
# Done.
# "49ers (Orange Shirt)" by Childish Gambino:
#     Whoa!
#     What'd you get, amnesia?
#     I bet you wouldn't sleep on me if I was Lil' Weezy, huh?
#     Bet you woul...
# Searching for "My Girls" by Childish Gambino...
# search My Girls Childish Gambino
# Done.
# "My Girls" by Childish Gambino:
#     You pick up all those books that you're gonna rea...
# Searching for "Diamonds From Sierra Leone (Remix)" by Kanye West...
# search Diamonds From Sierra Leone (Remix) Kanye West
# Done.
# "Diamonds From Sierra Leone (Remix)" by Kanye West:
#     Diamonds are forever
#     They're all I need to please me
#     They can't stimulate or tease me
#     They won't lea...
# Searching for "We Major" by Kanye West...
# search We Major Kanye West
# Done.
# "We Major" by Kanye West:
#     You muh'fuckers better do your job and roll up
#     And watch how we roll up
#     An', I can't control it, I c...
# Searching for "Skit #3" by Kanye West...
# search Skit #3 Kanye West
# Done.
# "Skit #3" by Kanye West:
#     This was founded years ago
#     By broke slaves, years ago
#     Who did not have, years ago
#     By broke brothas i...
# Searching for "Hey Mama" by Kanye West...
# search Hey Mama Kanye West
# Done.
# "Hey Mama" by Kanye West:
#     (Hey Mama)
#     I wanna scream so loud for you, 'cause I'm so proud of you
#     Let me tell you what I'm about...
# Searching for "Celebration" by Kanye West...
# search Celebration Kanye West
# Done.
# "Celebration" by Kanye West:
#     Yeah, you know what this is
#     It's a celebration, bitches!
#     Grab a drink, grab a glass
#     After that I gra...
# Searching for "Skit #4" by Kanye West...
# search Skit #4 Kanye West
# Done.
# "Skit #4" by Kanye West:
#     Broke, broke, broke phi broke (we ain't got it)
#     Broke, broke, broke phi broke (we ain't got it)
#     Brok...
# Searching for "Gone" by Kanye West...
# search Gone Kanye West
# Done.
# "Gone" by Kanye West:
#     Wished I had told ooh was (the) only one (uh oh!)
#     But it's too late, it's too late he's gone
#
#     You sw...
# Searching for "Diamonds from Sierra Leone" by Kanye West...
# search Diamonds from Sierra Leone Kanye West
# Done.
# "Diamonds from Sierra Leone" by Kanye West:
#     Diamonds are forever
#     They won't leave in the night
#     I've no fear that they might
#     Desert me
#
#     Diamonds ...
# Searching for "Late" by Kanye West...
# search Late Kanye West
# Done.
# "Late" by Kanye West:
#     Little girl (A-ha-ha-ha-ha...)
#     Please stop your crying
#
#     I'll be late for that, baby, I'll wait for t...
# Searching for "Back to Basics" by Kanye West...
# search Back to Basics Kanye West
# Done.
# "Back to Basics" by Kanye West:
#     Uh, uh, let's take it back to basics
#     When shit gets worse, we converse
#     How we need a new balance
#     Bef...
# Searching for "We Can Make It Better" by Kanye West...
# search We Can Make It Better Kanye West
# Done.
# "We Can Make It Better" by Kanye West:
#     ("Breaking up") We can make it better
#     ("Breaking up") We can make it better
#     ("Breaking up") We can m...
# Wrote 23 songs to Lyrics_KanyeWest{.Late-Registration.
# Searching for songs by Kanye West...
#
# Done.
# Searching for "Good Morning" by Kanye West...
# search Good Morning Kanye West
# Done.
# "Good Morning" by Kanye West:
#     Uhh.. uhh
#     Uhh.. uhh
#
#     Good morning!
#     Good morning!
#     Good morning!
#     Good morning!
#
#     Wake up Mr. West, Mr. ...
# Searching for "Champion" by Kanye West...
# search Champion Kanye West
# Done.
# "Champion" by Kanye West:
#     Did you realize
#     That you were a champion in their eyes?
#
#     Yes I did
#     So I packed it up and brought it ...
# Searching for "Stronger" by Kanye West...
# search Stronger Kanye West
# Done.
# "Stronger" by Kanye West:
#     Work it, make it, do it, makes us
#     Harder, better, faster, stronger
#
#     N-now th-that that don't kill me...
# Searching for "I Wonder" by Kanye West...
# search I Wonder Kanye West
# Done.
# "I Wonder" by Kanye West:
#     Find your dreams come true
#     And I wonder if you know
#     What it means, what it means
#
#     And I wonder if yo...
# Searching for "Good Life" by Kanye West...
# search Good Life Kanye West
# Done.
# "Good Life" by Kanye West:
#     Like we always do at this time
#     I go for mine, I gots to shine
#     (Now throw yo hands up in the sky)
#     I, ...
# Searching for "Can't Tell Me Nothing" by Kanye West...
# search Can't Tell Me Nothing Kanye West
# Done.
# "Can’t Tell Me Nothing" by Kanye West:
#     La, la, la la (Yeah)
#     Wait 'til I get my money right
#
#     I had a dream I could buy my way to heaven
#     When...
# Searching for "Barry Bonds" by Kanye West...
# search Barry Bonds Kanye West
# Done.
# "Barry Bonds" by Kanye West:
#     It's what ya all been waitin' fo', ain't it?
#     What people pay paper fo', damn it
#     They can't stand it,...
# Searching for "Drunk and Hot Girls" by Kanye West...
# search Drunk and Hot Girls Kanye West
# Done.
# "Drunk and Hot Girls" by Kanye West:
#     La-da-da da-da da-da da-da da-da da
#     Blap!
#
#     We go through too much bullshit
#     Just to mess with these d...
# Searching for "Flashing Lights" by Kanye West...
# search Flashing Lights Kanye West
# Done.
# "Flashing Lights" by Kanye West:
#     Flashing lights (lights, lights)
#     Flashing lights (lights, lights)
#     Flashing lights (lights, lights)
#     F...
# Searching for "Everything I Am" by Kanye West...
# search Everything I Am Kanye West
# Done.
# "Everything I Am" by Kanye West:
#     Damn, here we go again
#     Common passed on this beat, I made it to a jam
#     Now everything I'm not made me...
# Searching for "The Glory" by Kanye West...
# search The Glory Kanye West
# Done.
# "The Glory" by Kanye West:
#     In my soul
#     Gonna take you to the glory
#     Goal, in my mind I can't study war, yeah my
#     I can't study war...
# Searching for "Homecoming" by Kanye West...
# search Homecoming Kanye West
# Done.
# "Homecoming" by Kanye West:
#     Yeah
#     And you say Chi city!
#     Chi city! Chi city!
#
#     I'm comin' home again
#     Do you think about me now and ...
# Searching for "Big Brother" by Kanye West...
# search Big Brother Kanye West
# Done.
# "Big Brother" by Kanye West:
#     Stadium status
#
#     My big brother was B.I.G.'s brother
#     Used to be Dame and Biggs' brother
#     Who was Hip H...
# Searching for "Good Night" by Kanye West...
# search Good Night Kanye West
# Done.
# "Good Night" by Kanye West:
#     I'm not sure anymore, more
#     Who is knocking at my door, door
#     All the faces that I know
#     Ja make them s...
# Searching for "Bittersweet Poetry" by Kanye West...
# search Bittersweet Poetry Kanye West
# Done.
# "Bittersweet Poetry" by Kanye West:
#     Bittersweet
#     You're gonna be the death of me
#     I don't want you, but I need you
#     I love you and hate you...
# Wrote 15 songs to Lyrics_KanyeWest{.Graduation.
# Searching for songs by Kanye West...
#
# Done.
# Searching for "Say You Will" by Kanye West...
# search Say You Will Kanye West
# Done.
# "Say You Will" by Kanye West:
#     Why would she make calls out the blue?
#     Now I'm awake, sleep (Less in June) or (Missing you)
#
#     Hey, he...
#     High lights
#     Te...
# Searching for "Freestyle 4" by Kanye West...
# search Freestyle 4 Kanye West
# Done.
# "Freestyle 4" by Kanye West:
#     This that rap god shit nigga
#     I rip every one of these mothafuckas down, ayy
#     Rah, rah, rah
#     Rah, rah
#
#     ...
# Searching for "I Love Kanye" by Kanye West...
# search I Love Kanye Kanye West
# Done.
# "I Love Kanye" by Kanye West:
#     I miss the old Kanye, straight from the Go Kanye
#     Chop up the soul Kanye, set on his goals Kanye
#     I ha...
# Searching for "Waves" by Kanye West...
# search Waves Kanye West
# Done.
# "Waves" by Kanye West:
#     Turn me up!
#
#     Step up in this bitch like (Turn me up!)
#     I'm the one your bitch like
#     Yeah I'm the one y...
# Searching for "FML" by Kanye West...
# search FML Kanye West
# Done.
# "FML" by Kanye West:
#     I been waiting for a minute
#     For my lady
#     So I can't jeopardize that for one of these hoes
#     I been livi...
# Searching for "Real Friends" by Kanye West...
# search Real Friends Kanye West
# Done.
# "Real Friends" by Kanye West:
#     Real friends, how many of us?
#     How many of us, how many jealous? Real friends
#     It's not many of us, we...
# Searching for "Wolves" by Kanye West...
# search Wolves Kanye West
# Done.
# "Wolves" by Kanye West:
#     Lost out, beat up
#     Dancin', down there
#     I found you, somewhere out
#     'Round 'round there, right right th...
# Searching for "Frank's Track" by Kanye West...
# search Frank's Track Kanye West
# Done.
# "Frank’s Track" by Kanye West:
#     The rings all ringed out
#     Burn out, cave in
#     Blackened to dark out
#     I'm mixed now, fleshed out
#     There's ...
# Searching for "Siiiiiiiiilver Surffffeeeeer Intermission" by Kanye West...
# search Siiiiiiiiilver Surffffeeeeer Intermission Kanye West
# Done.
# "Siiiiiiiiilver Surffffeeeeer Intermission" by Kanye West:
#     Yeezy, Yeezy, what's good?
#     It's your boy Max B, what's going on?
#     Just checking in on you
#     Appreciate ...
# Searching for "30 Hours" by Kanye West...
# search 30 Hours Kanye West
# Done.
# "30 Hours" by Kanye West:
#     Baby lion goes
#     Where the islands go
#
#     You say you never saw this comin', well you're not alone
#     Millio...
# Searching for "No More Parties in LA" by Kanye West...
# search No More Parties in LA Kanye West
# Done.
# "No More Parties in LA" by Kanye West:
#     La-di-da-da-a, da-a (I like this flavor)
#     La-da-da-da-di-da-da-a, la-a (La-a, la-a, la-a)
#     Let me tell...
# Searching for "Facts (Charlie Heat Version)" by Kanye West...
# search Facts (Charlie Heat Version) Kanye West
# Done.
# "Facts (Charlie Heat Version)" by Kanye West:
#     Dirt and grime and filth inside
#     The story of my lifetime
#     Of cheating, stealing, never feeling
#     Pain o...
# Searching for "Fade" by Kanye West...
# search Fade Kanye West
# Done.
# "Fade" by Kanye West:
#     Your love is fadin'
#     Your love is fadin'
#     Your love is fadin'
#     I feel it's fadin'
#
#     When no one ain't ar...
# Searching for "Saint Pablo" by Kanye West...
# search Saint Pablo Kanye West
# Done.
# "Saint Pablo" by Kanye West:
#     Yeah, 9:08 L.A. time
#     Back in the lab and shit
#
#     My wife said, "I can't say no to nobody"
#     And at this ...
# Wrote 20 songs to Lyrics_KanyeWest{.The-Life-of-Pablo.
#     This is your stat...
# track ​m.A.A.d city
# Searching for "​m.A.A.d city" by Kendrick Lamar...
# Done.
# "​m.A.A.d city" by Kendrick Lamar:
#     If Pirus and Crips all got along
#     They'd probably gun me down by the end of this song
#     Seem like the w...
# track Swimming Pools (Drank)
# Searching for "Swimming Pools (Drank)" by Kendrick Lamar...
# Done.
# "Swimming Pools (Drank)" by Kendrick Lamar:
#     Pour up (Drank), head shot (Drank)
#     Sit down (Drank), stand up (Drank)
#     Pass out (Drank), wake up (Dra...
# track Sing About Me, I'm Dying of Thirst
# Searching for "Sing About Me, I'm Dying of Thirst" by Kendrick Lamar...
# Done.
# "Sing About Me, I’m Dying of Thirst" by Kendrick Lamar:
#     When the lights shut off and it's my turn
#     To settle down, my main concern
#     Promise that you will sing...
# track Real
# Searching for "Real" by Kendrick Lamar...
# Done.
# "Real" by Kendrick Lamar:
#     I do what I wanna do
#     I say what I wanna say, when I feel, and I
#     Look in the mirror and know I'm ther...
# track Compton
# Searching for "Compton" by Kendrick Lamar...
# Done.
# "Compton" by Kendrick Lamar:
#     Now everybody serenade the new faith of Kendrick Lamar
#     This is King Kendrick Lamar
#     King Kendrick and...
# Lyrics_KendrickLamar{.good-kid-m-A-A-d-city already exists. Overwrite?
# (y/n): y
# Wrote 12 songs to Lyrics_KendrickLamar{.good-kid-m-A-A-d-city.
# Searching for songs by Kendrick Lamar...
#
# Done.
# track The Heart Pt. 2
# Searching for "The Heart Pt. 2" by Kendrick Lamar...
# Done.
# "The Heart Pt. 2" by Kendrick Lamar:
#     "I’ll tell you what I don’t believe in, can I do that? All right, I don’t believe in laws, or the sy...
# track Growing Apart (To Get Closer)
# Searching for "Growing Apart (To Get Closer)" by Kendrick Lamar...
# Done.
# "Growing Apart (To Get Closer)" by Kendrick Lamar:
#     Where are we going, why are we slowing down
#     Where are you going, we should be growing now
#     (Smoke to ...
# track Night of the Living Junkies
# Searching for "Night of the Living Junkies" by Kendrick Lamar...
# Done.
# "Night of the Living Junkies" by Kendrick Lamar:
#     I remember, uhh
#     When my uncles
#     Served smokers
#     On Alondra
#     In front of our building, they was my heroe...
# track P&P 1.5
# Searching for "P&P 1.5" by Kendrick Lamar...
# Done.
# "P&P 1.5" by Kendrick Lamar:
#     "Gina, baby, I don't have no money, I don't have no ends
#     Gina, I'm ass-out"
#     "I'm going through somet...
# track Alien Girl (Today With Her)
# Searching for "Alien Girl (Today With Her)" by Kendrick Lamar...
# Done.
# "Alien Girl (Today With Her)" by Kendrick Lamar:
#     She looks better than Beyonce, Alicia Keys, Halle Berry, Miss Jolie
#     Where's she from? No I.D. (That ...
# track Opposites Attract (Tomorrow W/O Her)
# Searching for "Opposites Attract (Tomorrow W/O Her)" by Kendrick Lamar...
# Done.
# "Opposites Attract (Tomorrow W/O Her)" by Kendrick Lamar:
#     We hurt people that love us, love people that hurt us
#     Hurt people that love us, love people
#     I'm insp...
# track Michael Jordan
# Searching for "Michael Jordan" by Kendrick Lamar...
# Done.
# "Michael Jordan" by Kendrick Lamar:
#     I used to wanna be like Michael Jordan
#     Figure I would make the NBA and make me a fortune
#
#     Uh, every ...
# track Ignorance is Bliss
# Searching for "Ignorance is Bliss" by Kendrick Lamar...
# Done.
# "Ignorance is Bliss" by Kendrick Lamar:
#     Lord forgive me
#
#     Kill him where he stand and stand over him
#     Shake his hand then jump back in that mi...
# track R.O.T.C (Interlude)
# Searching for "R.O.T.C (Interlude)" by Kendrick Lamar...
# Done.
# "R.O.T.C (Interlude)" by Kendrick Lamar:
#     This is me thinking at 4:43 AM, June 6th
#
#     Sometimes I wanna say fuck rapping, I need money now
#     Like ...
# track Barbed Wire
# Searching for "Barbed Wire" by Kendrick Lamar...
# Done.
# "Barbed Wire" by Kendrick Lamar:
#     One time
#     Reporting live
#     Compton, California
#
#     Have you ever felt like, like you never get life?
#     Like ...
# track Average Joe
# Searching for "Average Joe" by Kendrick Lamar...
# Done.
# "Average Joe" by Kendrick Lamar:
#     The hardest thing for me to do
#     Is to get you, to know me, within sixteen bars
#     That's the hardest thi...
# track H.O.C.
# Searching for "H.O.C." by Kendrick Lamar...
# Done.
# "H.O.C." by Kendrick Lamar:
#     H.O.C., H.O.C
#     All the real smokers get me H.O.C
#     All the real smokers get me H.O.C
#     H.O.C., H.O.C
#     All ...
# track Cut You Off (To Grow Closer)
# Searching for "Cut You Off (To Grow Closer)" by Kendrick Lamar...
# Done.
# "Cut You Off (To Grow Closer)" by Kendrick Lamar:
#     Ali, you thirsty on Twitter!
#     You boo-boo, you T'd
#     You turned down, you thirsty
#     You boo-boo!
#
#     Uh, I'm...
# track Heaven and Hell
# Searching for "Heaven and Hell" by Kendrick Lamar...
# Done.
# "Heaven and Hell" by Kendrick Lamar:
#     My nigga, what it look like?
#
#     Niggas hatin', bitches hatin', babies dyin'
#     Bullets flyin', helicopter...
# track She Needs Me (Remix)
# Searching for "She Needs Me (Remix)" by Kendrick Lamar...
# Done.
# "She Needs Me (Remix)" by Kendrick Lamar:
#     I miss you (I miss you, I miss you)
#     Where you been? (Where you been?)
#     It's been months and I haven't...
# track I Do This (Remix)
# Searching for "I Do This (Remix)" by Kendrick Lamar...
# Done.
# "I Do This (Remix)" by Kendrick Lamar:
#     The homies say I'm the truest
#     The bitches think I'm the cutest
#     The definition what cool is
#     Boy, I th...
# Wrote 16 songs to Lyrics_KendrickLamar{.Overly-Dedicated.
# Searching for songs by Kendrick Lamar...
#
# Done.
# track Fuck Your Ethnicity
# Searching for "Fuck Your Ethnicity" by Kendrick Lamar...
# Done.
# "Fuck Your Ethnicity" by Kendrick Lamar:
#     Gather around. I'm glad everybody came out tonight. As we stand on our neighborhood corner, know tha...
# track Hol' Up
# Searching for "Hol' Up" by Kendrick Lamar...
# Done.
# "Hol’ Up" by Kendrick Lamar:
#     I wrote this record while thirty-thousand feet in the air
#     Stewardess complimenting me on my nappy ha...
# track A.D.H.D
# Searching for "A.D.H.D" by Kendrick Lamar...
# Done.
# "A.D.H.D" by Kendrick Lamar:
#     Uh-uh, fuck that (fuck that)
#
#     Eight doobies to the face, fuck that
#     12 bottles in the case, nigga, fu...
# track No Makeup (Her Vice)
# Searching for "No Makeup (Her Vice)" by Kendrick Lamar...
# Done.
# "No Makeup (Her Vice)" by Kendrick Lamar:
#     I love the way you put it on your eyes
#     The roses on your face light up the sky
#     Those lips are colorf...
# track Tammy's Song (Her Evils)
# Searching for "Tammy's Song (Her Evils)" by Kendrick Lamar...
# Done.
# "Tammy’s Song (Her Evils)" by Kendrick Lamar:
#     Don't judge me
#
#     I know this girl, she a real good girl and she be low-key
#     Looking like a star, with ...
# track Chapter Six
# Searching for "Chapter Six" by Kendrick Lamar...
# Done.
# "Chapter Six" by Kendrick Lamar:
#     Ridin' with them boys and girls and we're high
#     All we want to do is have a good time
#     Young, wild, an...
# track Ronald Reagan Era (His Evils)
# Searching for "Ronald Reagan Era (His Evils)" by Kendrick Lamar...
# Done.
# "Ronald Reagan Era (His Evils)" by Kendrick Lamar:
#     We're far from good, not good from far
#     90 miles per hour down Compton Boulevard
#     With the top down, s...
# track Poe Man's Dreams (His Vice)
# Searching for "Poe Man's Dreams (His Vice)" by Kendrick Lamar...
# Done.
# "Poe Man’s Dreams (His Vice)" by Kendrick Lamar:
#     Smoke good, eat good, live good
#     Smoke good, eat good, live good
#     Smoke good, eat good, live good
#     Smok...
# track The Spiteful Chant
# Searching for "The Spiteful Chant" by Kendrick Lamar...
# Done.
# "The Spiteful Chant" by Kendrick Lamar:
#     I know a lot of people that smile in my face
#     But talk behind my back every time I'm gone
#     So when the...
# track Chapter Ten
# Searching for "Chapter Ten" by Kendrick Lamar...
# Done.
# "Chapter Ten" by Kendrick Lamar:
#     In time you'll learn this is about you
#     In time you'll learn this is about you
#     In time you'll learn t...
# track Keisha's Song (Her Pain)
# Searching for "Keisha's Song (Her Pain)" by Kendrick Lamar...
# Done.
# "Keisha’s Song (Her Pain)" by Kendrick Lamar:
#     Fancy girls on Long Beach Boulevard
#     Flagging down all of these flashy cars
#
#     Uh, and Lord knows she's...
# track Rigamortis
# Searching for "Rigamortis" by Kendrick Lamar...
# Done.
# "Rigamortis" by Kendrick Lamar:
#     Alright, here we go, third take
#     Real quick, Ali, mm
#
#     Got me breathing with dragons
#     I'll crack the eg...
# track Kush & Corinthians (His Pain)
# Searching for "Kush & Corinthians (His Pain)" by Kendrick Lamar...
# Done.
# "Kush & Corinthians (His Pain)" by Kendrick Lamar:
#     Check, check, check, check, check
#     It go...
#
#     Ride to it, ride to it, 'cause you never know
#     When a bul...
# track Blow My High (Members Only)
# Searching for "Blow My High (Members Only)" by Kendrick Lamar...
# Done.
# "Blow My High (Members Only)" by Kendrick Lamar:
#     Smoking out, pouring up, keep that lean up in my cup
#     All my car got leather and wood in my hood we c...
# track Ab-Soul's Outro
# Searching for "Ab-Soul's Outro" by Kendrick Lamar...
# Done.
# "Ab-Soul’s Outro" by Kendrick Lamar:
#     What's your life about? Enlighten me
#     Is you gon' live on your knees or die on your feet?
#     It's fire i...
# track HiiiPoWeR
# Searching for "HiiiPoWeR" by Kendrick Lamar...
# Done.
# "HiiiPoWeR" by Kendrick Lamar:
#     Everybody put three fingers in the air
#     The sky is falling, the wind is calling
#     Stand for something, ...
# Wrote 16 songs to Lyrics_KendrickLamar{.Section-80.
# Searching for songs by Kendrick Lamar...
#
# Done.
# track Wesley's Theory
# Searching for "Wesley's Theory" by Kendrick Lamar...
# Done.
# "Wesley’s Theory" by Kendrick Lamar:
#     Every nigga is a star, ayy, every nigga is a star
#     Every nigga is a star, ayy, every nigga is a star
#     ...
# track For Free? (Interlude)
# Searching for "For Free? (Interlude)" by Kendrick Lamar...
# Done.
# "For Free? (Interlude)" by Kendrick Lamar:
#     Fuck you, motherfucker, you a ho-ass nigga
#     I don't know why you trying to go big, nigga, you ain't s...
# track King Kunta
# Searching for "King Kunta" by Kendrick Lamar...
# Done.
# "King Kunta" by Kendrick Lamar:
#     I got a bone to pick
#     I don't want you monkey-mouth motherfuckers
#     Sittin' in my throne again
#     Ayy, ayy...
# track Institutionalized
# Searching for "Institutionalized" by Kendrick Lamar...
# Done.
# "Institutionalized" by Kendrick Lamar:
#     What money got to do with it
#     When I don't know the full definition of a rap image?
#     I'm trapped insid...
# track These Walls
# Searching for "These Walls" by Kendrick Lamar...
# Done.
# "These Walls" by Kendrick Lamar:
#     I remember you was conflicted, misusing your influence
#     Sometimes, I did the same
#
#     (Woman moaning)
#     If...
# track ​u
# Searching for "​u" by Kendrick Lamar...
# Done.
# "​u" by Kendrick Lamar:
#     Loving you is complicated, loving you is complicated
#     Loving you is complicated, loving you is compli...
# track Alright
# Searching for "Alright" by Kendrick Lamar...
# Done.
# "Alright" by Kendrick Lamar:
#     Alls my life I has to fight, nigga
#     Alls my life I...
#     Hard times like, "Yah!"
#     Bad trips like, "Yah!"
#     ...
# track For Sale? (Interlude)
# Searching for "For Sale? (Interlude)" by Kendrick Lamar...
# Done.
# "For Sale? (Interlude)" by Kendrick Lamar:
#     Oh, oh, oh, oh, ohhhh, ohh
#     Oh, oh, oh, oh, ohhhh, ohh
#     (Breathing)
#     What's wrong, nigga?
#     I thought you...
# track Momma
# Searching for "Momma" by Kendrick Lamar...
# Done.
# "Momma" by Kendrick Lamar:
#     Oh shit! I need that
#     I need that sloppy, that sloppy
#     Like a Chevy in quicksand
#     Yeah, that sloppy
#
#     Th...
# track Hood Politics
# Searching for "Hood Politics" by Kendrick Lamar...
# Done.
# "Hood Politics" by Kendrick Lamar:
#     K-Dot, pick up the phone, nigga
#     Every time I call, it's going to voicemail
#     Don't tell me they got yo...
# track How Much a Dollar Cost
# Searching for "How Much a Dollar Cost" by Kendrick Lamar...
# Done.
# "How Much a Dollar Cost" by Kendrick Lamar:
#     How much a dollar really cost?
#     The question is detrimental, paralyzin' my thoughts
#     Parasites in my s...
# track Complexion (A Zulu Love)
# Searching for "Complexion (A Zulu Love)" by Kendrick Lamar...
# Done.
# "Complexion (A Zulu Love)" by Kendrick Lamar:
#     I'm with this
#
#     Complexion (two-step)
#     Complexion don't mean a thing (it's a Zulu love)
#     Complexion (tw...
# track The Blacker the Berry
# Searching for "The Blacker the Berry" by Kendrick Lamar...
# Done.
# "The Blacker the Berry" by Kendrick Lamar:
#     Everything black, I don't want black (They want us to bow)
#     I want everything black, I ain't need bla...
# track You Ain't Gotta Lie (Momma Said)
# Searching for "You Ain't Gotta Lie (Momma Said)" by Kendrick Lamar...
# Done.
# "You Ain’t Gotta Lie (Momma Said)" by Kendrick Lamar:
#     Study long, study wrong, nigga
#     Hey, y'all close that front door, y'all let flies in this motherfucke...
# track ​i (Album Version)
# Searching for "​i (Album Version)" by Kendrick Lamar...
# Done.
# "​i (Album Version)" by Kendrick Lamar:
#     ​​​​​​​​​​​​​​​​​​​
#
#     Is this mic on? (Hey, move this way, this way)
#     Hey, Hey! Hey! Turn the mic up, ...
# track Mortal Man
# Searching for "Mortal Man" by Kendrick Lamar...
# Done.
# "Mortal Man" by Kendrick Lamar:
#     Ohhh, ohhhh, woahhh
#     Uh, yeah
#     Uh, yeah
#     Uh
#     Yeah, uh
#
#     The ghost of Mandela, hope my flows stay propelli...
# Wrote 16 songs to Lyrics_KendrickLamar{.To-Pimp-a-Butterfly.
# Searching for songs by Kendrick Lamar...
#
# Done.
# track BLOOD.
# Searching for "BLOOD." by Kendrick Lamar...
# Done.
# "BLOOD." by Kendrick Lamar:
#     Is it wickedness?
#     Is it weakness?
#     You decide
#     Are we gonna live or die?
#
#     So I was takin' a walk the o...
# track DNA.
# Searching for "DNA." by Kendrick Lamar...
# Done.
# "DNA." by Kendrick Lamar:
#     I got, I got, I got, I got—
#     Loyalty, got royalty inside my DNA
#     Cocaine quarter piece, got war and pe...
# track YAH.
# Searching for "YAH." by Kendrick Lamar...
# Done.
# "YAH." by Kendrick Lamar:
#     New shit, new Kung Fu Kenny
#
#     I got so many theories and suspicions
#     I'm diagnosed with real nigga con...
# track ELEMENT.
# Searching for "ELEMENT." by Kendrick Lamar...
# Done.
# "ELEMENT." by Kendrick Lamar:
#     New Kung Fu Kenny
#     Ain't nobody prayin' for me
#     Y'all know, what happens on Earth stays on Earth
#     Here ...
# track FEEL.
# Searching for "FEEL." by Kendrick Lamar...
# Done.
# "FEEL." by Kendrick Lamar:
#     Ain't nobody prayin' for me
#     (Ain't nobody prayin' for me)
#     (Ain't nobody prayin' for me)
#     Ain't nobody...
# track LOYALTY.
# Searching for "LOYALTY." by Kendrick Lamar...
# Done.
# "LOYALTY." by Kendrick Lamar:
#     I said I'm geeked and I’m fired up (Fired, fire)
#     All I want tonight is just get high (High, high, hi...
# track PRIDE.
# Searching for "PRIDE." by Kendrick Lamar...
# Done.
# "PRIDE." by Kendrick Lamar:
#     Love's gonna get you killed
#     But pride’s gonna be the death of you and you and me
#     And you and you and...
# track HUMBLE.
# Searching for "HUMBLE." by Kendrick Lamar...
# Done.
# "HUMBLE." by Kendrick Lamar:
#     Nobody pray for me
#     It's been that day for me
#     Way (Yeah, yeah!)
#
#     Ayy, I remember syrup sandwiches and...
# track LUST.
# Searching for "LUST." by Kendrick Lamar...
# Done.
# "LUST." by Kendrick Lamar:
#     I need some water, somethin' came over me
#     Way too hot to simmer down might as well overheat
#     Too clos...
# track LOVE.
# Searching for "LOVE." by Kendrick Lamar...
# Done.
# "LOVE." by Kendrick Lamar:
#     Damn, love or lust
#     Damn, all of us
#
#     Give me a run for my money
#     There is nobody, no one to outrun me
#     ...
# track XXX.
# Searching for "XXX." by Kendrick Lamar...
# Done.
# "XXX." by Kendrick Lamar:
#     America, God bless you if it's good to you
#     America, please take my hand
#     Can you help me underst—
#     New...
# track FEAR.
# Searching for "FEAR." by Kendrick Lamar...
# Done.
# "FEAR." by Kendrick Lamar:
#     Poverty's paradise
#     I don’t think I could find a way to make it on this earth
#     (I've been hungry all m...
# track GOD.
# Searching for "GOD." by Kendrick Lamar...
# Done.
# "GOD." by Kendrick Lamar:
#     This what God feel like, huh, he-yeah
#     Laughin' to the bank like, "A-ha!", huh, he-yeah
#     Flex on swole...
# track DUCKWORTH.
# Searching for "DUCKWORTH." by Kendrick Lamar...
# Done.
# "DUCKWORTH." by Kendrick Lamar:
#     It was always me vs the world
#     Until I found it's me vs me
#     Why, why, why, why?
#     Why, why, why, why?
#     Ju...
# Wrote 14 songs to Lyrics_KendrickLamar{.DAMN.

# %%
for album in ["LIVE.LOVE.A$AP","AT.LONG.LAST.A$AP","LONG.LIVE.A$AP","TESTING"]:
    Genius.search_album(api, "A$AP Rocky", album)
# Out:
# Searching for songs by A$AP Rocky...
#
# Done.
# Searching for "Palace" by A$AP Rocky...
# search Palace A$AP Rocky
# Done.
# "Palace" by A$AP Rocky:
#     Goddamn, how real is this?
#     I know them Harlem niggas gon' be feeling this
#     East Coast nigga, but how ...
# Searching for "Peso" by A$AP Rocky...
# search Peso A$AP Rocky
# Done.
# "Peso" by A$AP Rocky:
#     I be that pretty mothafucka, Harlem's what I'm reppin'
#     Tell my niggas quit the bitchin', we gon' mak...
# Searching for "Bass" by A$AP Rocky...
# search Bass A$AP Rocky
# Done.
# "Bass" by A$AP Rocky:
#     So recognize that shit, you better fuckin' recognize that fuckin' name right now...
#     I recognize, I r...
# Searching for "Wassup" by A$AP Rocky...
# search Wassup A$AP Rocky
# Done.
# "Wassup" by A$AP Rocky:
#     Clams Casino, A$AP (Wassup)
#     See me in the hood the gangstas saying wassup (Wassup)
#
#     Back once again,...
# Searching for "Brand New Guy" by A$AP Rocky...
# search Brand New Guy A$AP Rocky
# Done.
# "Brand New Guy" by A$AP Rocky:
#     You know these big mouth niggas don't know how to act. I got my West Coast connection. These dead in...
# Searching for "Purple Swag: Chapter 2" by A$AP Rocky...
# search Purple Swag: Chapter 2 A$AP Rocky
# Done.
# "Purple Swag: Chapter 2" by A$AP Rocky:
#     Smoke
#     Ty Beats (Ty)
#
#     Back in this bitch mothafucka', yeah it's me
#     SpaceGhostPurrp and I put your bit...
# Searching for "Get Lit" by A$AP Rocky...
# search Get Lit A$AP Rocky
# Done.
# "Get Lit" by A$AP Rocky:
#     I get so high, I touch the sky 'til I can't even function
#     I get so high, I fuck around and wanna lea...
# Searching for "Trilla" by A$AP Rocky...
# search Trilla A$AP Rocky
# Done.
# "Trilla" by A$AP Rocky:
#     One, two, umm
#     Buckle my, umm
#
#     Pass the mothafuckin' Swisher, pour some mothafuckin' liquor
#     For my mo...
# Searching for "Keep It G" by A$AP Rocky...
# search Keep It G A$AP Rocky
# Done.
# "Keep It G" by A$AP Rocky:
#     Fuck the bullshit, my nigga. Y'all niggas started this shit. A$AP started it, y'all finish it. Don't...
# Searching for "Kissin' Pink" by A$AP Rocky...
# search Kissin' Pink A$AP Rocky
# Done.
# "Kissin’ Pink" by A$AP Rocky:
#     Faded, drinking codeine and every fuckin day straight promethazine and
#     She's all that I want
#     Gots to...
# Searching for "Houston Old Head" by A$AP Rocky...
# search Houston Old Head A$AP Rocky
# Done.
# "Houston Old Head" by A$AP Rocky:
#     Smoking rolling reefer up, I adjust the tweakers up
#     Break it, break it down, break it down so I can ...
# Searching for "Acid Drip" by A$AP Rocky...
# search Acid Drip A$AP Rocky
# Done.
# "Acid Drip" by A$AP Rocky:
#     Feeling outta place, plus it's getting kinda late
#     Tryna make it home safe and not get raped, where y...
# Searching for "Leaf" by A$AP Rocky...
# search Leaf A$AP Rocky
# Done.
# "Leaf" by A$AP Rocky:
#     "I'm so happy, you know um
#     You know I looked at the crowd and you know
#     I look at my fans, I look at ...
# Searching for "Roll One Up" by A$AP Rocky...
# search Roll One Up A$AP Rocky
# Done.
# "Roll One Up" by A$AP Rocky:
#     Let me know, know what's up
#     Before I roll, roll one up
#     Let me know, know what‘s up
#     Before I roll, ro...
# Searching for "Demons" by A$AP Rocky...
# search Demons A$AP Rocky
# Done.
# "Demons" by A$AP Rocky:
#     I just, I just live
#     I live day by day, fighting demons
#
#     I smoked away my brain, I think I’m going du...
# Searching for "Out of This World" by A$AP Rocky...
# search Out of This World A$AP Rocky
# Done.
# "Out of This World" by A$AP Rocky:
#     Get money addict, I'mma get "Money" tatted
#     Money in the attics, money in the stashes
#     Money in the ca...
# Wrote 16 songs to Lyrics_A$APRocky{.LIVE-LOVE-A-AP.
# Searching for songs by A$AP Rocky...
#
# Done.
# Searching for "Holy Ghost" by A$AP Rocky...
# search Holy Ghost A$AP Rocky
# Done.
# "Holy Ghost" by A$AP Rocky:
#     Ay, I have a message from the Most High that says:
#     "This negra kept his soul from the Devil"
#     It's tr...
# Searching for "Canal St." by A$AP Rocky...
# search Canal St. A$AP Rocky
# Done.
# "Canal St." by A$AP Rocky:
#     Yeah, live through the strugglin', life's a every day (hustle)
#     I hustle every day in life, thinkin' ...
# Searching for "Fine Whine" by A$AP Rocky...
# search Fine Whine A$AP Rocky
# Done.
# "Fine Whine" by A$AP Rocky:
#     This love, this love, this love won't last forever
#     This love, this love, this love gon' own our eyes...
# Searching for "L$D" by A$AP Rocky...
# search L$D A$AP Rocky
# Done.
# "L$D" by A$AP Rocky:
#     I know I dream about her all day
#     I think about her with her clothes off
#     I'm ridin' 'round with my sy...
# Searching for "Excuse Me" by A$AP Rocky...
# search Excuse Me A$AP Rocky
# Done.
# "Excuse Me" by A$AP Rocky:
#     For all them hoes that was frontin' on niggas back in the days, man
#     (You know I'm sayin'? This for m...
# Searching for "JD" by A$AP Rocky...
# search JD A$AP Rocky
# Done.
# "JD" by A$AP Rocky:
#     - Yo, what's your name, young blood? What they call you?
#     - Well I got, I got, James, Jimmy or Byron ...
# Searching for "Lord Pretty Flacko Jodye 2 (LPFJ2)" by A$AP Rocky...
# search Lord Pretty Flacko Jodye 2 (LPFJ2) A$AP Rocky
# Done.
# "Lord Pretty Flacko Jodye 2 (LPFJ2)" by A$AP Rocky:
#     Who the jiggy nigga with the gold links?
#     Got me reminiscin' 'bout my old day
#     Three 6, suck a nigga d...
# Searching for "Electric Body" by A$AP Rocky...
# search Electric Body A$AP Rocky
# Done.
# "Electric Body" by A$AP Rocky:
#     Yeah, yeah, yeah this year we finna make a killin' (Yeah)
#     Now the money stack up to the ceilin' (Yea...
# Searching for "Jukebox Joints" by A$AP Rocky...
# search Jukebox Joints A$AP Rocky
# Done.
# "Jukebox Joints" by A$AP Rocky:
#     And I'm a man of my word, that I got nothing at all
#     So tell me now does it hurt or is it too late? I...
# Searching for "Max B" by A$AP Rocky...
# search Max B A$AP Rocky
# Done.
# "Max B" by A$AP Rocky:
#     … Through the spot
#     Everyday was like a beef to me
#     Little nigga said he’d make it hot
#     You don’t wanna...
# Searching for "Pharsyde" by A$AP Rocky...
# search Pharsyde A$AP Rocky
# Done.
# "Pharsyde" by A$AP Rocky:
#     Love on the low, love everywhere I go
#     And I can't face that all I need is right where I belong
#     Love ...
# Searching for "Wavybone" by A$AP Rocky...
# search Wavybone A$AP Rocky
# Done.
# "Wavybone" by A$AP Rocky:
#     The hustle continues
#     Gettin' money is, gettin' money is
#     Put your mind to, something you want
#     Gettin'...
# Searching for "West Side Highway" by A$AP Rocky...
# search West Side Highway A$AP Rocky
# Done.
# "West Side Highway" by A$AP Rocky:
#     These days of preference has no complexion
#     You could be light, dark, mixed or fair skin
#     Just light t...
# Searching for "Better Things" by A$AP Rocky...
# search Better Things A$AP Rocky
# Done.
# "Better Things" by A$AP Rocky:
#     Don't give a fuck about your man
#     I'm just seeing what it's hitting for (bitch I'm sayin')
#     How you fr...
# Searching for "M'$" by A$AP Rocky...
# search M'$ A$AP Rocky
# Done.
# "M’$" by A$AP Rocky:
#     P.O
#     One time for A$AP Yams
#     Let's go
#
#     What's this I see? Niggas tryna act like G's
#     Got A$AP, got Ferg...
# Searching for "Dreams (Interlude)" by A$AP Rocky...
# search Dreams (Interlude) A$AP Rocky
# Done.
# "Dreams (Interlude)" by A$AP Rocky:
#     Yeah, yeah, yeah
#     It's good
#     Oh shit
#     Mushrooms, LSD, marijuana
#     Light that shit
#     Oh shit
#
#     This is every ...
# Searching for "Everyday" by A$AP Rocky...
# search Everyday A$AP Rocky
# Done.
# "Everyday" by A$AP Rocky:
#     Everyday I spend my time
#     Drinkin' wine, feelin' fine
#     Waitin' here to find the sign
#     That I can unders...
# Searching for "Back Home" by A$AP Rocky...
# search Back Home A$AP Rocky
# Done.
# "Back Home" by A$AP Rocky:
#     Gotta find my way back home
#     I've been away too long
#     Gotta find my way back home
#     I'm moving...
#
#     War L...
# Wrote 18 songs to Lyrics_A$APRocky{.AT-LONG-LAST-A-AP.
# Searching for songs by A$AP Rocky...
#
# Done.
# Searching for "Long Live A$AP" by A$AP Rocky...
# search Long Live A$AP A$AP Rocky
# Done.
# "Long Live A$AP" by A$AP Rocky:
#     I thought I'd probably die in prison, expensive taste in women
#     Ain't had no pot to piss in, now my k...
# Searching for "Goldie" by A$AP Rocky...
# search Goldie A$AP Rocky
# Done.
# "Goldie" by A$AP Rocky:
#     Aha, aha
#     I said it must be 'cause a nigga got dough
#     Extraordinary swag and a mouth full of gold
#     Hoes...
# Searching for "PMW (All I Really Need)" by A$AP Rocky...
# search PMW (All I Really Need) A$AP Rocky
# Done.
# "PMW (All I Really Need)" by A$AP Rocky:
#     All I think about is life, nights, sipping on Sprite
#     Little codeine, nigga get throwed right
#     Two blo...
# Searching for "LVL" by A$AP Rocky...
# search LVL A$AP Rocky
# Done.
# "LVL" by A$AP Rocky:
#     Clams Casino, nigga
#     A$AP
#
#     Mr. Pistol Popper, Flacko locked and loaded
#     Life's a bitch and she pussy p...
# Searching for "Hell" by A$AP Rocky...
# search Hell A$AP Rocky
# Done.
# "Hell" by A$AP Rocky:
#     We use to wear rugged boots, now it's all tailored suits
#     Audemars Piguets for my criminal recruits
#     C...
# Searching for "Pain" by A$AP Rocky...
# search Pain A$AP Rocky
# Done.
# "Pain" by A$AP Rocky:
#     Ahh, pain
#     Ahh, pain
#     Ahh, pain
#     Ahh
#
#     So big you are, shining like the star
#     With your head in the cloud...
# Searching for "Fuckin' Problems" by A$AP Rocky...
# search Fuckin' Problems A$AP Rocky
# Done.
# "Fuckin’ Problems" by A$AP Rocky:
#     I love bad bitches, that's my fuckin' problem
#     And yeah, I like to fuck, I got a fuckin' problem
#     I lo...
# Searching for "Wild for the Night" by A$AP Rocky...
# search Wild for the Night A$AP Rocky
# Done.
# "Wild for the Night" by A$AP Rocky:
#     Wake up feeling blessed up, pistol on that dresser
#     Ain't afraid to show it, I'll expose it if I dres...
# Searching for "1Train" by A$AP Rocky...
# search 1Train A$AP Rocky
# Done.
# "1Train" by A$AP Rocky:
#     Ah, feelin' like a vigilante or a missionary
#     Tell my A$AP killers, get they pistols ready
#     Send 'em t...
# Searching for "Fashion Killa" by A$AP Rocky...
# search Fashion Killa A$AP Rocky
# Done.
# "Fashion Killa" by A$AP Rocky:
#     Her pistol go "bang-bang, boom-boom, pop-pop"
#     Her pistol go "bang-bang, boom-boom, pop-pop"
#     I said h...
# Searching for "Phoenix" by A$AP Rocky...
# search Phoenix A$AP Rocky
# Done.
# "Phoenix" by A$AP Rocky:
#     Bloody ink on my pad spelled suicide
#     Michael Jackson even passed cause you scrutinized
#     Fuck Illumina...
# Searching for "Suddenly" by A$AP Rocky...
# search Suddenly A$AP Rocky
# Done.
# "Suddenly" by A$AP Rocky:
#     I swear this famous shit just happened overnight
#     For sure these hoes was so uptight, but now they so...
# Wrote 12 songs to Lyrics_A$APRocky{.LONG-LIVE-A-AP.
# Searching for songs by A$AP Rocky...
#
# Done.
# Searching for "Distorted Records" by A$AP Rocky...
# search Distorted Records A$AP Rocky
# Done.
# "Distorted Records" by A$AP Rocky:
#     Uh, uh
#
#     I can feel the bass, from the ceiling to the basement
#     I don't feel a thing, get the fuck up ...
# Searching for "A$AP Forever REMIX" by A$AP Rocky...
# search A$AP Forever REMIX A$AP Rocky
# Done.
# "A$AP Forever REMIX" by A$AP Rocky:
#     Gang! Gang
#     They tryna front on the gang!
#     They going to remember my name
#     Ayy, anybody ever took the t...
# Searching for "Tony Tone" by A$AP Rocky...
# search Tony Tone A$AP Rocky
# Done.
# "Tony Tone" by A$AP Rocky:
#     Uh, my mic sounds nice, check one (Woo!)
#     My mic sounds nice, check two (Uh-huh, yeah-yeah)
#     Testing, ...
# Searching for "Fukk Sleep" by A$AP Rocky...
# search Fukk Sleep A$AP Rocky
# Done.
# "Fukk Sleep" by A$AP Rocky:
#     Oh, yeah
#     Ohh, ahh
#
#     Fuck home, fuck sleep, come clean, zonin'
#     Can't forget that I'm golden, can't for...
# Searching for "Praise the Lord (Da Shine)" by A$AP Rocky...
# search Praise the Lord (Da Shine) A$AP Rocky
# Done.
# "Praise the Lord (Da Shine)" by A$AP Rocky:
#     Get it
#     Text a message, I don't know the number
#     Flexin' on these niggas, every bone and muscle
#     Steady...
# Searching for "CALLDROPS" by A$AP Rocky...
# search CALLDROPS A$AP Rocky
# Done.
# "CALLDROPS" by A$AP Rocky:
#     "Mo—money and the power, money and the power"
#
#     Eyedrops, ("Fuckin' with the killas")
#     Teardrops
#     Dropt...
# Searching for "Buck Shots" by A$AP Rocky...
# search Buck Shots A$AP Rocky
# Done.
# "Buck Shots" by A$AP Rocky:
#     I ain't scared, uh
#     Real niggas put the clip in and let it go, uh
#     Real niggas wanna run real, uh
#
#     Rea...
# Searching for "Gunz N Butter" by A$AP Rocky...
# search Gunz N Butter A$AP Rocky
# Done.
# "Gunz N Butter" by A$AP Rocky:
#     Swingin' burning tires leave a third degree
#     And I heard there's bouncin' niggas hatin' wanna murder ...
# Searching for "Brotha Man" by A$AP Rocky...
# search Brotha Man A$AP Rocky
# Done.
# "Brotha Man" by A$AP Rocky:
#     Young man, brotha brotha, you gotta fight for somethin'
#     Stand for somethin', gotta understand, gotta...
# Searching for "OG Beeper" by A$AP Rocky...
# search OG Beeper A$AP Rocky
# Done.
# "OG Beeper" by A$AP Rocky:
#     Uh, posted on the corner like a trapper, uh
#     Why he move his hands all around like a rapper? uh
#     Why h...
# Searching for "Kids Turned Out Fine" by A$AP Rocky...
# search Kids Turned Out Fine A$AP Rocky
# Done.
# "Kids Turned Out Fine" by A$AP Rocky:
#     Crazy kids, understand
#     Out late, going crazy, kids innocent
#     Crazy kids, understand
#     Out late, going c...
# Searching for "Hun43rd" by A$AP Rocky...
# search Hun43rd A$AP Rocky
# Done.
# "Hun43rd" by A$AP Rocky:
#     From the cradle to the grave, I'ma put in work
#     From the cradle to the grave, I'ma put in work
#     From t...
# Searching for "Changes" by A$AP Rocky...
# search Changes A$AP Rocky
# Done.
# "Changes" by A$AP Rocky:
#     Changes
#     I'm goin' through changes
#     I'm goin' through changes
#     I'm goin' through changes
#     I'm goin' thro...
# Searching for "Black Tux, White Collar" by A$AP Rocky...
# search Black Tux, White Collar A$AP Rocky
# Done.
# "Black Tux, White Collar" by A$AP Rocky:
#     Know what I'm sayin'
#     Got jealous of a nigga or something tryna...
#     Check it, whole lot of jewelry, my...
# Searching for "Purity" by A$AP Rocky...
# search Purity A$AP Rocky
# Done.
# "Purity" by A$AP Rocky:
#     I've been busy (Busy, busy)
#     I've been fuckin' busy, I've been busy fuckin'
#     I've been all kinds of bu...
# Wrote 15 songs to Lyrics_A$APRocky{.TESTING.

# %%
for album in ["Summertime '06","Big Fish Theory","FM!"]:
    Genius.search_album(api, "Vince Staples", album)
# Out:
# Searching for songs by Vince Staples...
#
# Done.
# Searching for "Feels Like Summer" by Vince Staples...
# Done.
# "Feels Like Summer" by Vince Staples:
#     Big Boy!
#     Man, whatever day, vibe, month it is
#     It just feels like summer
#     You know what I'm saying?
#     It...
# Searching for "Outside!" by Vince Staples...
# Done.
# "Outside!" by Vince Staples:
#     Yeah, yeah, yeah, yeah, citch
#     (Ayy, when they play shit, shoot the party up)
#     Yeah, yeah (Ayy, when t...
# Searching for "Don't Get Chipped" by Vince Staples...
# Done.
# "Don’t Get Chipped" by Vince Staples:
#     Can't wait ’til I'm rich, I'm finna buy a whole crate of guns
#     For my naughty Crips, shit I really ca...
# Searching for "Relay" by Vince Staples...
# Done.
# "Relay" by Vince Staples:
#     Fed chirp on scanner (Scanner)
#     Got blurped with the hammer
#     I ain't playin' with the DA
#     I'm finna hit...
# Searching for "New earlsweatshirt (Interlude)" by Vince Staples...
# Done.
# "New earlsweatshirt (Interlude)" by Vince Staples:
#     N-n-new Earl Sweatshirt on Big Boy's neighborhood
#
#     By my mama crib, it's a lotta Crips (Crips)
#     I rep...
# Searching for "Run the Bands" by Vince Staples...
# Done.
# "Run the Bands" by Vince Staples:
#     Run the bands, run the bands
#     Run the bands, run the bands, hey
#     Run the bands, run the bands
#     Run the ...
# Searching for "FUN!" by Vince Staples...
# Done.
# "FUN!" by Vince Staples:
#     One time, circling the block (The block)
#     Lil buddy got murdered on a flock
#     Two times, you know how w...
# Searching for "No Bleedin" by Vince Staples...
# Done.
# "No Bleedin" by Vince Staples:
#     Call us up, 562-453-9382
#     You're listening to Big Boy’s Neighborhood
#
#     Head on the swivel, no bleedin'...
# Searching for "Brand New Tyga (Interlude)" by Vince Staples...
# Done.
# "Brand New Tyga (Interlude)" by Vince Staples:
#     It's your girl Ayydé, this is Big Boy’s Neighborhood
#     Make sure you keep it locked
#     We got that brand ...
# Searching for "(562) 453-9382 (Skit)" by Vince Staples...
# Done.
# "(562) 453-9382 (Skit)" by Vince Staples:
#     Big Boy's Neighborhood
#     Alrighty, playing around that Seven 7 Seven right now
#     Let’s go ahead and brin...
# Searching for "Tweakin'" by Vince Staples...
# Done.
# "Tweakin’" by Vince Staples:
#     This for the ones
#     (Never had none and never been bums)
#     Live by the gun
#     (Die by the gun, rise 'fore t...
# Wrote 11 songs to Lyrics_VinceStaples{.FM.
