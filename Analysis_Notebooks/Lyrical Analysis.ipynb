# %% [markdown]
# What song characteristics are correlated with higher streaming count?
#
# KL Divergence
# Sentiment Analysis
#
# bing lu- modern review data?
#
# what are the words contributing to the sentiment?
#
# Bing Dictionary?
#
# Szyuyet? Trust the result- edit the lexicon?
#
#
# LDA
# Aggregate all of them
# Kanye West
# Childish Gambino
# Frank Ocean

# %%
from collections import Counter
import math, glob, csv, re, numpy
from matplotlib import pyplot
import json

# %%
with open('Lyrics_Tyler,TheCreator.json') as json_file:
    data = json.load(json_file)

# %%
data["songs"][0]["lyrics"].splitlines()
# Out:
# ['For real, for real this time',
#  'For real, for real, for real this time',
#  'Bitch, I cannot fall short',
#  'For real, for real, for real this time (Yeah, yeah)',
#  'For real, for real, for real this time',
#  '',
#  "'Cause you make my earth quake",
#  'Oh, you make my earth quake',
#  'Riding around, your love be shakin’ me up',
#  "And it's making my heart break",
#  "'Cause you make my earth quake",
#  'Oh, you make my earth quake (Earthquake, ooh)',
#  'Riding around, your love be shakin’ me up',
#  "And it's making my heart break",
#  '',
#  "Don't leave, it's my fault",
#  "Don't leave, it's my fault",
#  "Don't leave, it's my fault (Girl)",
#  '’Cause when it all comes crashing down I’ll need you',
#  '',
#  "'Cause you make my earth quake",
#  'Oh, you make my earth quake',
#  'Riding around, you’re telling me something is bad',
#  "And it's making my heart break",
#  "'Cause you make my earth quake, oh, you make my earth quake",
#  '(Earth quake, yeah)',
#  "Riding around, your love be shakin' me up",
#  'And it’s making my heart break (You already know)',
#  '',
#  "We ain't gotta ball, D. Rose, huh",
#  "I don't give a fuck 'bout none', huh",
#  "Beamin' like fuck my lungs, huh",
#  'Just might call my lawyer, huh',
#  "Plug gon' set me up, huh (Yeah)",
#  "Bih', don't set me up (Okay)",
#  "I'm with Tyler, yuh (Slime)",
#  'He ride like the car, huh',
#  'And she wicked, huh, yuh',
#  'Like Woah Vicky, huh, yeah (Like Woah Vicky)',
#  'Oh, my God, hold up, um',
#  'Diamonds not Tiffany, huh, yeah (Woah, woah)',
#  'So in love',
#  'So in love',
#  '',
#  "Don't leave, it's my fault (Fault)",
#  "Don't leave, it's my fault",
#  "Don't leave, it's my fault (Ayy)",
#  "'Cause when it all comes crashing down I'll need you (Ayy, ayy)",
#  '',
#  "'Cause you make my earth quake",
#  "I don't want no confrontation, no",
#  "You don't want my conversation (I don't want no conversation)",
#  'I just need some confirmation on how you feel (For real)',
#  "You don't want no complication, no",
#  "I don't want no side information (I don't want no side information)",
#  "I just need to know what's happening",
#  "'cause I'm for real (For real)",
#  '',
#  "I said don't leave, it's my fault (One)",
#  "I said don't leave, it's my fault (Two, two)",
#  "Don't leave, it's, it's my fault, girl (Three, three, three)",
#  "Don't, do-do-do-do-do, I need-"]

# %%
## Read metadata and text for novels

word_pattern = re.compile("\w[\w\-\']*\w|\w")

songs = []

all_counts = Counter()

line_buffer = []
with open('/Lyrics_A$APRocky{.TESTING.json') as json_file:
    data = json.load(json_file)
    
    for row in data["songs"]:
#         print (row)
    
#     for row in data:
        
#         print("Reading {} ({})".format(row["title"], row["album"]))
        songs.append(row)
#         row["Year"] = int(row["Year"])
        
        counter = Counter()
        row["Tokens"] = counter
        
        
#         print ((row['lyrics']))
        line_buffer.append(row['lyrics'])
#         print (line_buffer)
        counter.update(word_pattern.findall(" ".join(line_buffer)))
all_counts += counter
#         with open("../data/westerns/{}".format(row["Filename"])) as reader:
#             for line in reader:
#                 line = line.rstrip()
                
#                 ## The encoding looks like it messed up for some documents
#                 line = line.replace("â", "'")
                
#                 ## split m-dashes
#                 line = line.replace("--", " -- ")
                
#                 if line != "":
#                     line_buffer.append(line)
#                 else:
#                     counter.update(word_pattern.findall(" ".join(line_buffer)))
                    
#                     # Not using Spacy version for now, but this is what it would look like
#                     #tokens = nlp(" ".join(line_buffer))
#                     #counter.update([token.text for token in tokens])
                    
#                     line_buffer = []
        
#         all_counts += counter

# %%
songs[8]["Tokens"].most_common()
# Out:
# [('I', 193),
#  ('the', 121),
#  ('me', 71),
#  ('a', 65),
#  ('some', 65),
#  ('time', 62),
#  ('to', 61),
#  ('my', 59),
#  ('you', 57),
#  ('it', 49),
#  ('in', 47),
#  ("I'm", 42),
#  ('that', 41),
#  ('is', 37),
#  ('and', 34),
#  ('on', 33),
#  ('out', 31),
#  ('of', 28),
#  ('know', 28),
#  ('for', 27),
#  ('Find', 27),
#  ('la', 25),
#  ('can', 24),
#  ("don't", 24),
#  ('like', 24),
#  ('And', 23),
#  ('nigga', 23),
#  ('got', 23),
#  ('call', 22),
#  ('em', 21),
#  ('with', 19),
#  ('okay', 19),
#  ('You', 18),
#  ('if', 18),
#  ('get', 18),
#  ('do', 18),
#  ('Who', 18),
#  ('fuck', 16),
#  ('pothole', 16),
#  ('run', 15),
#  ('yeah', 15),
#  ('But', 15),
#  ('find', 15),
#  ('be', 14),
#  ('up', 14),
#  ('oh', 14),
#  ('was', 13),
#  ('what', 13),
#  ("that's", 13),
#  ('could', 13),
#  ('him', 13),
#  ('How', 12),
#  ('this', 12),
#  ('Cause', 12),
#  ('who', 12),
#  ('so', 12),
#  ('Nigga', 12),
#  ('something', 12),
#  ('go', 11),
#  ('never', 11),
#  ('but', 11),
#  ('had', 11),
#  ('cause', 11),
#  ('boy', 11),
#  ('said', 11),
#  ('been', 11),
#  ('watch', 11),
#  ('Call', 11),
#  ('911', 11),
#  ('they', 10),
#  ('not', 10),
#  ('see', 10),
#  ('roll', 10),
#  ("I've", 10),
#  ('boredom', 10),
#  ('bloom', 9),
#  ('say', 9),
#  ('niggas', 9),
#  ('garden', 9),
#  ('make', 9),
#  ('sick', 9),
#  ('Can', 9),
#  ('lonely', 9),
#  ('have', 8),
#  ('much', 8),
#  ('all', 8),
#  ("ain't", 8),
#  ('them', 8),
#  ('back', 8),
#  ('your', 8),
#  ('wanna', 8),
#  ('20', 8),
#  ('bout', 8),
#  ('So', 8),
#  ('fuckin', 8),
#  ('My', 8),
#  ('shed', 8),
#  ("can't", 8),
#  ('til', 7),
#  ('until', 7),
#  ('want', 7),
#  ('forever', 7),
#  ('Yeah', 7),
#  ('keep', 7),
#  ("I'll", 7),
#  ('rock', 7),
#  ('grow', 7),
#  ('at', 7),
#  ('Okay', 7),
#  ("it's", 7),
#  ('dat', 7),
#  ('need', 7),
#  ('That', 7),
#  ('dem', 7),
#  ('Fuck', 7),
#  ('even', 7),
#  ('new', 7),
#  ('best', 7),
#  ('friend', 7),
#  ('many', 6),
#  ('If', 6),
#  ('when', 6),
#  ('one', 6),
#  ('from', 6),
#  ('only', 6),
#  ('Run', 6),
#  ('glow', 6),
#  ('One', 6),
#  ('more', 6),
#  ('these', 6),
#  ('are', 6),
#  ('The', 6),
#  ('hit', 6),
#  ('kiss', 6),
#  ("I'ma", 6),
#  ("y'all", 6),
#  ('off', 6),
#  ('should', 6),
#  ('Boredom', 6),
#  ('as', 6),
#  ('ring', 6),
#  ('Uh', 5),
#  ('drive', 5),
#  ('then', 5),
#  ('let', 5),
#  ('he', 5),
#  ('too', 5),
#  ('come', 5),
#  ('Now', 5),
#  ('skrrt', 5),
#  ('through', 5),
#  ('Out', 5),
#  ('just', 5),
#  ('man', 5),
#  ('room', 5),
#  ("It's", 5),
#  ("you're", 5),
#  ('day', 5),
#  ('last', 5),
#  ('war', 5),
#  ('again', 5),
#  ('switch', 5),
#  ('Oh', 5),
#  ('no', 5),
#  ('how', 5),
#  ('she', 5),
#  ('words', 5),
#  ('couple', 5),
#  ('Time', 5),
#  ('cars', 4),
#  ('there', 4),
#  ('See', 4),
#  ('cool', 4),
#  ('gone', 4),
#  ('seen', 4),
#  ('friends', 4),
#  ('nothing', 4),
#  ('always', 4),
#  ('their', 4),
#  ('matter', 4),
#  ('Them', 4),
#  ('gonna', 4),
#  ('Maybe', 4),
#  ('sheep', 4),
#  ('baby', 4),
#  ('These', 4),
#  ('shinin', 4),
#  ('What', 4),
#  ('T', 4),
#  ('shit', 4),
#  ('low', 4),
#  ('about', 4),
#  ("That's", 4),
#  ('we', 4),
#  ('Cupid', 4),
#  ('When', 4),
#  ('mind', 4),
#  ('face', 4),
#  ('eyes', 4),
#  ('La', 4),
#  ('where', 4),
#  ('right', 4),
#  ('bitch', 4),
#  ('boys', 4),
#  ('Why', 4),
#  ('wheel', 4),
#  ('else', 4),
#  ('ass', 4),
#  ('tryna', 4),
#  ('bitches', 4),
#  ('left', 4),
#  ('talk', 4),
#  ('gears', 4),
#  ('swerve', 4),
#  ('Watch', 4),
#  ('Gotta', 4),
#  ('Damn', 4),
#  ('real', 4),
#  ('goes', 4),
#  ('flies', 4),
#  ('morning', 4),
#  ('line', 4),
#  ('lie', 4),
#  ('fans', 3),
#  ('turn', 3),
#  ('well', 3),
#  ('Please', 3),
#  ('keepin', 3),
#  ('better', 3),
#  ('over', 3),
#  ('will', 3),
#  ('mansion', 3),
#  ('windows', 3),
#  ('walk', 3),
#  ('drown', 3),
#  ('mean', 3),
#  ("Who's", 3),
#  ("Let's", 3),
#  ('days', 3),
#  ("they're", 3),
#  ('window', 3),
#  ('float', 3),
#  ('stuck', 3),
#  ('look', 3),
#  ('Shit', 3),
#  ('Look', 3),
#  ('other', 3),
#  ('dark', 3),
#  ('ohh', 3),
#  ('name', 3),
#  ('since', 3),
#  ('stay', 3),
#  ('both', 3),
#  ('chasing', 3),
#  ('Is', 3),
#  ('another', 3),
#  ('stop', 3),
#  ('rose', 3),
#  ('give', 3),
#  ('here', 3),
#  ('feel', 3),
#  ('neck', 3),
#  ('bad', 3),
#  ('doin', 3),
#  ('number', 3),
#  ('McLaren', 3),
#  ('gotta', 3),
#  ('now', 3),
#  ('Like', 3),
#  ('mirror', 3),
#  ('by', 3),
#  ("Don't", 3),
#  ('everyone', 3),
#  ('love', 3),
#  ('Garden', 3),
#  ('fun', 3),
#  ('long', 3),
#  ('amusing', 3),
#  ('someone', 3),
#  ('Gonna', 3),
#  ('loneliest', 3),
#  ('pet', 3),
#  ('uh', 2),
#  ('road', 2),
#  ('land', 2),
#  ('Niggas', 2),
#  ('plans', 2),
#  ('into', 2),
#  ('outta', 2),
#  ('down', 2),
#  ('AC', 2),
#  ('blows', 2),
#  ('lasts', 2),
#  ('For', 2),
#  ('head', 2),
#  ('bed', 2),
#  ('straight', 2),
#  ('thought', 2),
#  ('click', 2),
#  ('cop', 2),
#  ('pull', 2),
#  ('usually', 2),
#  ('ego', 2),
#  ('Because', 2),
#  ('rooms', 2),
#  ('views', 2),
#  ('bottom', 2),
#  ('prolly', 2),
#  ('pool', 2),
#  ('ten', 2),
#  ('toes', 2),
#  ('crash', 2),
#  ('Ayo', 2),
#  ('floor', 2),
#  ('dollar', 2),
#  ('Nobody', 2),
#  ('home', 2),
#  ('In', 2),
#  ('ride', 2),
#  ('frog', 2),
#  ('goggles', 2),
#  ('leanin', 2),
#  ('OJ', 2),
#  ('Simp', 2),
#  ('sun', 2),
#  ('Slick', 2),
#  ('circles', 2),
#  ('world', 2),
#  ('Let', 2),
#  ("Ain't", 2),
#  ('nobody', 2),
#  ('might', 2),
#  ('Man', 2),
#  ('smell', 2),
#  ('mall', 2),
#  ('skin', 2),
#  ('feels', 2),
#  ('forget', 2),
#  ('car', 2),
#  ('Ohh', 2),
#  ('Keep', 2),
#  ('trunk', 2),
#  ('Ah', 2),
#  ('Ahh', 2),
#  ('us', 2),
#  ('air', 2),
#  ("What's", 2),
#  ('hear', 2),
#  ('live', 2),
#  ('dream', 2),
#  ('state', 2),
#  ('exist', 2),
#  ('eyelids', 2),
#  ('vision', 2),
#  ('precision', 2),
#  ('Wonder', 2),
#  ('ways', 2),
#  ('cross', 2),
#  ("You're", 2),
#  ('running', 2),
#  ('dreams', 2),
#  ('close', 2),
#  ('an', 2),
#  ('tinted', 2),
#  ("I'd", 2),
#  ('Make', 2),
#  ('Bout', 2),
#  ('GOLF', 2),
#  ('deposit', 2),
#  ('runnin', 2),
#  ('found', 2),
#  ('Young', 2),
#  ('Mad', 2),
#  ('chill', 2),
#  ('mad', 2),
#  ('push', 2),
#  ('puttin', 2),
#  ('vibes', 2),
#  ('Never', 2),
#  ('before', 2),
#  ('Had', 2),
#  ('Been', 2),
#  ('From', 2),
#  ('He', 2),
#  ('lookin', 2),
#  ('To', 2),
#  ('start', 2),
#  ('eatin', 2),
#  ('meals', 2),
#  ('way', 2),
#  ('reason', 2),
#  ('help', 2),
#  ('Do', 2),
#  ('listen', 2),
#  ('prepared', 2),
#  ('throw', 2),
#  ('front', 2),
#  ('Fishtail', 2),
#  ('rearview', 2),
#  ('Skrrrrrt', 2),
#  ('steerin', 2),
#  ('grass', 2),
#  ('still', 2),
#  ('All', 2),
#  ('show', 2),
#  ('things', 2),
#  ("he's", 2),
#  ('gon', 2),
#  ('myself', 2),
#  ('next', 2),
#  ('four', 2),
#  ('good', 2),
#  ('potholes', 2),
#  ('kill', 2),
#  ('Before', 2),
#  ('Fly', 2),
#  ('fly', 2),
#  ('cocoon', 2),
#  ('They', 2),
#  ('tell', 2),
#  ('having', 2),
#  ('talkin', 2),
#  ('stomach', 2),
#  ('Morning', 2),
#  ('going', 2),
#  ('Tick', 2),
#  ('tock', 2),
#  ('Lonely', 2),
#  ('gas', 2),
#  ('speaker', 2),
#  ('bang', 2),
#  ('Chirp', 2),
#  ('chirp', 2),
#  ('burbs', 2),
#  ('birds', 2),
#  ('Old', 2),
#  ('loudest', 2),
#  ('thing', 2),
#  ('really', 2),
#  ('fillin', 2),
#  ('Bitch', 1),
#  ('question', 1),
#  ('buy', 1),
#  ('pave', 1),
#  ('ocean', 1),
#  ('motions', 1),
#  ('beaches', 1),
#  ('sands', 1),
#  ('woods', 1),
#  ('flowers', 1),
#  ('rainbows', 1),
#  ('posies', 1),
#  ('Falling', 1),
#  ('pocket', 1),
#  ("ya'll", 1),
#  ('swam', 1),
#  ('cooler', 1),
#  ('TNT', 1),
#  ('finished', 1),
#  ('minute', 1),
#  ('Guessing', 1),
#  ('Nothing', 1),
#  ('sticks', 1),
#  ('together', 1),
#  ('Sick', 1),
#  ('sitting', 1),
#  ('doubt', 1),
#  ('figure', 1),
#  ('Shout', 1),
#  ('girls', 1),
#  ('lead', 1),
#  ('occasional', 1),
#  ('warm', 1),
#  ('trying', 1),
#  ('hardest', 1),
#  ('enough', 1),
#  ('airborne', 1),
#  ('raps', 1),
#  ('write', 1),
#  ('chain', 1),
#  ('chains', 1),
#  ('wear', 1),
#  ('considered', 1),
#  ('slave', 1),
#  ('slaves', 1),
#  ('Nat', 1),
#  ('Turner', 1),
#  ('arise', 1),
#  ('riots', 1),
#  ('Black', 1),
#  ('lives', 1),
#  ('clack', 1),
#  ('splatter', 1),
#  ('Pew', 1),
#  ('pew', 1),
#  ('Life', 1),
#  ('game', 1),
#  ('basketball', 1),
#  ('shoot', 1),
#  ('trigger', 1),
#  ('pulled', 1),
#  ('play', 1),
#  ('drivin', 1),
#  ('paid', 1),
#  ('full', 1),
#  ('possessions', 1),
#  ('Nah', 1),
#  ('stares', 1),
#  ('backyard', 1),
#  ('does', 1),
#  ("you'll", 1),
#  ('fucked', 1),
#  ('swim', 1),
#  ('fall', 1),
#  ('wondering', 1),
#  ('take', 1),
#  ('Counting', 1),
#  ('Sadie', 1),
#  ("Hannah's", 1),
#  ('Carpet', 1),
#  ('mama', 1),
#  ('80', 1),
#  ('profit', 1),
#  ('coffee', 1),
#  ('poured', 1),
#  ('Rent-A-Center', 1),
#  ('calling', 1),
#  ('everyday', 1),
#  ('knocking', 1),
#  ('door', 1),
#  ('toys', 1),
#  ('dreamed', 1),
#  ('afford', 1),
#  ('Okaga', 1),
#  ('California', 1),
#  ('oval', 1),
#  ('fucking', 1),
#  ('may', 1),
#  ('freeze', 1),
#  ('cold', 1),
#  ('ice', 1),
#  ('weighs', 1),
#  ('ton', 1),
#  ('water', 1),
#  ('Stunt', 1),
#  ('Tell', 1),
#  ('black', 1),
#  ('kids', 1),
#  ('Dye', 1),
#  ('hair', 1),
#  ('blue', 1),
#  ('Chanel', 1),
#  ('grip', 1),
#  ('manicured', 1),
#  ('nails', 1),
#  ('coconut', 1),
#  ('oil', 1),
#  ('top', 1),
#  ('follicles', 1),
#  ('thinnin', 1),
#  ('than', 1),
#  ('winning', 1),
#  ('winnin', 1),
#  ('Went', 1),
#  ('statistic', 1),
#  ('millionaire', 1),
#  ('CNN', 1),
#  ('doubted', 1),
#  ('Then', 1),
#  ('oak', 1),
#  ('Flower', 1),
#  ('Rooted', 1),
#  ('bloomed', 1),
#  ('tree', 1),
#  ('Took', 1),
#  ('lil', 1),
#  ('while', 1),
#  ('makin', 1),
#  ('leaves', 1),
#  ('branches', 1),
#  ('family', 1),
#  ('eat', 1),
#  ('Favorite', 1),
#  ('color', 1),
#  ('green', 1),
#  ('energy', 1),
#  ('strong', 1),
#  ('Giving', 1),
#  ('life', 1),
#  ('birdies', 1),
#  ('beez', 1),
#  ('Droppin', 1),
#  ('seeds', 1),
#  ('ahh', 1),
#  ('Sometimes', 1),
#  ('sit', 1),
#  ('think', 1),
#  ('Golf', 1),
#  ('Radio', 1),
#  ('Shane', 1),
#  ('Powers', 1),
#  ('Taking', 1),
#  ('requests', 1),
#  ('Hello', 1),
#  ('Um', 1),
#  ('Mr', 1),
#  ('Fucking-Secret-Agent', 1),
#  ('song', 1),
#  ('Relocate', 1),
#  ('fantasy', 1),
#  ('reality', 1),
#  ('Anytime', 1),
#  ('count', 1),
#  ('behind', 1),
#  ('wake', 1),
#  ('okie', 1),
#  ('dokie', 1),
#  ('infatuation', 1),
#  ('translatin', 1),
#  ('form', 1),
#  ('Love', 1),
#  ('met', 1),
#  ('looking', 1),
#  ('waiting', 1),
#  ('fore', 1),
#  ('alcoholic', 1),
#  ('understand', 1),
#  ('cheeks', 1),
#  ('dirt-colored', 1),
#  ('Sugar', 1),
#  ('honey', 1),
#  ('iced', 1),
#  ('tea', 1),
#  ('bumblebee', 1),
#  ('scene', 1),
#  ('bakery', 1),
#  ('piece', 1),
#  ('pie', 1),
#  ('Yeugh', 1),
#  ('cupid', 1),
#  ('Yo', 1),
#  ('Him', 1),
#  ('ni-guh', 1),
#  ('swear', 1),
#  ('Stand', 1),
#  ('guy', 1),
#  ('chair', 1),
#  ('Well', 1),
#  ('shop', 1),
#  ('Dumb', 1),
#  ('mothafucka', 1),
#  ('goddamn', 1),
#  ('artist', 1),
#  ('markers', 1),
#  ('draw', 1),
#  ('closet', 1),
#  ('fresh', 1),
#  ('death', 1),
#  ('dressed', 1),
#  ('coffin', 1),
#  ('Cons', 1),
#  ('overalls', 1),
#  ('striped', 1),
#  ('shirt', 1),
#  ('drips', 1),
#  ('swag', 1),
#  ('broken', 1),
#  ('faucet', 1),
#  ('cherry', 1),
#  ('bomb', 1),
#  ('ran', 1),
#  ('Boston', 1),
#  ("Won't", 1),
#  ('cops', 1),
#  ('surround', 1),
#  ('jiggy', 1),
#  ('awesome', 1),
#  ('With', 1),
#  ('his', 1),
#  ('blown', 1),
#  ('step', 1),
#  ('jig', 1),
#  ('bick', 1),
#  ('big', 1),
#  ('came', 1),
#  ('wrist', 1),
#  ('flick', 1),
#  ('Guess', 1),
#  ('pants', 1),
#  ('dance', 1),
#  ('Spin', 1),
#  ('around', 1),
#  ('Raf', 1),
#  ('Still', 1),
#  ('math', 1),
#  ('miss', 1),
#  ('class', 1),
#  ('Was', 1),
#  ('Summertime', 1),
#  ('06', 1),
#  ('Number', 1),
#  ('N', 1),
#  ('ine', 1),
#  ('Vince', 1),
#  ('Gucci', 1),
#  ('gold', 1),
#  ('tips', 1),
#  ('letterman', 1),
#  ('sign', 1),
#  ('favorite', 1),
#  ('Fresh', 1),
#  ('freshmen', 1),
#  ('skipped', 1),
#  ('Senior', 1),
#  ('citizen', 1),
#  ('pass', 1),
#  ('knew', 1),
#  ('dick', 1),
#  ('disappear', 1),
#  ("nigga's", 1),
#  ('rap', 1),
#  ('own', 1),
#  ('planet', 1),
#  ('business', 1),
#  ('ventures', 1),
#  ('Actin', 1),
#  ('ya', 1),
#  ('Teeth', 1),
#  ('glistenin', 1),
#  ('Jesus', 1),
#  ('Christmas', 1),
#  ('shittin', 1),
#  ('exquisite', 1),
#  ('expensive', 1),
#  ('attention', 1),
#  ('WANG', 1),
#  ('AP', 1),
#  ('bumper', 1),
#  ('sticker', 1),
#  ('global', 1),
#  ('warming', 1),
#  ('frío', 1),
#  ('currently', 1),
#  ('95', 1),
#  ('Leo', 1),
#  ('mom', 1),
#  ('worried', 1),
#  ('because', 1),
#  ('ill', 1),
#  ('bread', 1),
#  ('weight', 1),
#  ('stayed', 1),
#  ('Get', 1),
#  ('guey', 1),
#  ('0', 1),
#  ('60', 1),
#  ('2', 1),
#  ('point', 1),
#  ('nueve', 1),
#  ('mother', 1),
#  ('warned', 1),
#  ('hand', 1),
#  ('trust', 1),
#  ('her', 1),
#  ('heart', 1),
#  ('elder', 1),
#  ('white', 1),
#  ('His', 1),
#  ('Clancy', 1),
#  ('fancy', 1),
#  ('props', 1),
#  ('half', 1),
#  ('why', 1),
#  ('dealerships', 1),
#  ('speedin', 1),
#  ('away', 1),
#  ('fact', 1),
#  ('triple', 1),
#  ('double', 1),
#  ('streets', 1),
#  ('filled', 1),
#  ('clues', 1),
#  ('notice', 1),
#  ('familiar', 1),
#  ('cul-de-sac', 1),
#  ('Really', 1),
#  ('themself', 1),
#  ('dilemma', 1),
#  ('traffic', 1),
#  ('picking', 1),
#  ('leave', 1),
#  ('Skrt', 1),
#  ('speed', 1),
#  ('barely', 1),
#  ('seems', 1),
#  ('awkward', 1),
#  ('heard', 1),
#  ('steer', 1),
#  ('path', 1),
#  ('distracted', 1),
#  ('weather', 1),
#  ('rain', 1),
#  ('windshield', 1),
#  ('wipers', 1),
#  ('shade', 1),
#  ('jacket', 1),
#  ('also', 1),
#  ('power', 1),
#  ('ever', 1),
#  ('jump', 1),
#  ('Just', 1),
#  ('Snakes', 1),
#  ('boots', 1),
#  ('says', 1),
#  ('bites', 1),
#  ('condom', 1),
#  ('Watchin', 1),
#  ('Clarence', 1),
#  ('successful', 1),
#  ('piggies', 1),
#  ('amazin', 1),
#  ('irony', 1),
#  ('stopped', 1),
#  ('bacon', 1),
#  ('twisted', 1),
#  ('hungry', 1),
#  ('hoes', 1),
#  ('tenderonies', 1),
#  ('made', 1),
#  ('past', 1),
#  ('month', 1),
#  ('please', 1),
#  ('Everyone', 1),
#  ('lone', 1),
#  ('wolf', 1),
#  ('peep', 1),
#  ('wants', 1),
#  ('wool', 1),
#  ('Since', 1),
#  ('rather', 1),
#  ('Than', 1),
#  ('fleece', 1),
#  ('T-Man', 1),
#  ('seesaw', 1),
#  ('Wind', 1),
#  ('which', 1),
#  ('knows', 1),
#  ('Batmobile', 1),
#  ('Good', 1),
#  ('health', 1),
#  ('success', 1),
#  ('earth', 1),
#  ('worthwhile', 1),
#  ('somebody', 1),
#  ('raise', 1),
#  ('lizards', 1),
#  ("vehicle's", 1),
#  ('miles', 1),
#  ('pushin', 1),
#  ('Do-do-do-do-do-do', 1),
#  ('Ooh', 1),
#  ('Haha', 1),
#  ('hide', 1),
#  ("there's", 1),
#  ('Shed', 1),
#  ('Go', 1),
#  ('hidin', 1),
#  ('pretend', 1),
#  ('garçons', 1),
#  ('feelings', 1),
#  ('guardin', 1),
#  ('Heavy', 1),
#  ('lost', 1),
#  ("couldn't", 1),
#  ('read', 1),
#  ('signs', 1),
#  ("didn't", 1),
#  ('location', 1),
#  ('Truth', 1),
#  ('youth', 1),
#  ('kid', 1),
#  ('phase', 1),
#  ('Thought', 1),
#  ("it'd", 1),
#  ('phrase', 1),
#  ('poof', 1),
#  ('goin', 1),
#  ('Big', 1),
#  ('fan', 1),
#  ('beige', 1),
#  ('tan', 1),
#  ('Polka', 1),
#  ('dot', 1),
#  ('nose', 1),
#  ('subwoofer', 1),
#  ('A', 1),
#  ('butterflies', 1),
#  ('Eh', 1),
#  ('Barely', 1),
#  ('interested', 1),
#  ('bagged', 1),
#  ('brag', 1),
#  ('Bruh', 1),
#  ('This', 1),
#  ('crucial', 1),
#  ('subject', 1),
#  ('Sensitive', 1),
#  ('cookin', 1),
#  ('batter', 1),
#  ('Til', 1),
#  ('temperature', 1),
#  ('risin', 1),
#  ('Steppin', 1),
#  ('ladder', 1),
#  ('Grab', 1),
#  ('rings', 1),
#  ('Saturn', 1),
#  ('Planet', 1),
#  ('chatter', 1),
#  ('heat', 1),
#  ('It', 1),
#  ('Na-na-na', 1),
#  ('na-na-na', 1),
#  ('oh-na-na-na', 1),
#  ('Boy', 1),
#  ('bedroom', 1),
#  ('cereal', 1),
#  ('burial', 1),
#  ('serious', 1),
#  ('ate', 1),
#  ('dry', 1),
#  ('boxes', 1),
#  ('bodies', 1),
#  ('caught', 1),
#  ("we're", 1),
#  ('ask', 1),
#  ('saw', 1),
#  ('eyeballs', 1),
#  ('turning', 1),
#  ('drywall', 1),
#  ('suck', 1),
#  ('Hi', 1),
#  ('problem', 1),
#  ('solved', 1),
#  ('bored', 1),
#  ('Bored', 1),
#  ('getting', 1),
#  ('desperate', 1),
#  ('hell', 1),
#  ('Desperate', 1),
#  ('using', 1),
#  ('texting', 1),
#  ('Cellular', 1),
#  ('hope', 1),
#  ('Message', 1),
#  ('haven', 1),
#  ('t', 1),
#  ('exit', 1),
#  ('walls', 1),
#  ('Got', 1),
#  ('handle', 1),
#  ('nowhere', 1),
#  ('performance', 1),
#  ('angry', 1),
#  ('yellin', 1),
#  ('food', 1),
#  ('order', 1),
#  ('hate', 1),
#  ('eating', 1),
#  ('solo', 1),
#  ('Need', 1),
#  ('loiter', 1),
#  ('parking', 1),
#  ('lots', 1),
#  ('As', 1),
#  ('sunsets', 1),
#  ('border', 1),
#  ('Ringy', 1),
#  ('dingy', 1),
#  ('dong', 1),
#  ('alone', 1),
#  ('starting', 1),
#  ('anyone', 1),
#  ('staring', 1),
#  ('ceiling', 1),
#  ('idea', 1),
#  ('Hey', 1),
#  ('quick', 1),
#  ("Ride's", 1),
#  ('tickets', 1),
#  ('s', 1),
#  ('nice', 1),
#  ('meet', 1),
#  ("Here's", 1),
#  ('reach', 1),
#  ('woo', 1),
#  ('thirst', 1),
#  ('levels', 1),
#  ('infinity', 1),
#  ('beyond', 1),
#  ...]

# %%
all_counts.most_common()
# Out:
# [('I', 241),
#  ('the', 149),
#  ('me', 116),
#  ('to', 83),
#  ('my', 80),
#  ('you', 78),
#  ('a', 77),
#  ('some', 66),
#  ('time', 64),
#  ('it', 60),
#  ('in', 59),
#  ('that', 53),
#  ('back', 48),
#  ("I'm", 46),
#  ('is', 45),
#  ('and', 43),
#  ('on', 38),
#  ('of', 35),
#  ('out', 33),
#  ('know', 32),
#  ('for', 31),
#  ('if', 30),
#  ('like', 30),
#  ('And', 28),
#  ('got', 28),
#  ("don't", 28),
#  ('How', 27),
#  ('can', 27),
#  ('Find', 27),
#  ('was', 26),
#  ('la', 25),
#  ('call', 24),
#  ('November', 24),
#  ('with', 23),
#  ('nigga', 23),
#  ('feel', 23),
#  ('em', 22),
#  ('get', 20),
#  ('up', 20),
#  ('take', 19),
#  ('do', 19),
#  ('okay', 19),
#  ('Who', 19),
#  ('You', 18),
#  ('be', 18),
#  ('fuck', 17),
#  ('yeah', 17),
#  ("ain't", 16),
#  ('this', 16),
#  ('Cause', 16),
#  ('what', 16),
#  ('But', 16),
#  ('My', 16),
#  ('pothole', 16),
#  ('find', 16),
#  ('Take', 16),
#  ('run', 15),
#  ('never', 15),
#  ("that's", 15),
#  ('who', 15),
#  ('cause', 15),
#  ('so', 15),
#  ('him', 15),
#  ('ya', 15),
#  ('could', 14),
#  ('What', 14),
#  ('oh', 14),
#  ('go', 13),
#  ('all', 13),
#  ('but', 13),
#  ('one', 13),
#  ('your', 13),
#  ('been', 13),
#  ('they', 12),
#  ('Yeah', 12),
#  ('boy', 12),
#  ('Nigga', 12),
#  ('Fuck', 12),
#  ('something', 12),
#  ('na', 12),
#  ('had', 11),
#  ('not', 11),
#  ('see', 11),
#  ("I'll", 11),
#  ('niggas', 11),
#  ('said', 11),
#  ('Can', 11),
#  ('watch', 11),
#  ("can't", 11),
#  ('Call', 11),
#  ('911', 11),
#  ('want', 10),
#  ('them', 10),
#  ('when', 10),
#  ('roll', 10),
#  ('say', 10),
#  ('at', 10),
#  ('make', 10),
#  ("I've", 10),
#  ('So', 10),
#  ('boredom', 10),
#  ('keep', 9),
#  ('bloom', 9),
#  ('more', 9),
#  ('just', 9),
#  ('garden', 9),
#  ('these', 9),
#  ('we', 9),
#  ('sick', 9),
#  ('day', 9),
#  ('fuckin', 9),
#  ('lonely', 9),
#  ('have', 8),
#  ('much', 8),
#  ('are', 8),
#  ('wanna', 8),
#  ('20', 8),
#  ('bout', 8),
#  ("it's", 8),
#  ('no', 8),
#  ('love', 8),
#  ('shed', 8),
#  ('til', 7),
#  ('drive', 7),
#  ('until', 7),
#  ('If', 7),
#  ('forever', 7),
#  ('too', 7),
#  ('come', 7),
#  ('only', 7),
#  ('rock', 7),
#  ('grow', 7),
#  ('Okay', 7),
#  ('mind', 7),
#  ("I'ma", 7),
#  ('Oh', 7),
#  ('dat', 7),
#  ('need', 7),
#  ("y'all", 7),
#  ('That', 7),
#  ('how', 7),
#  ('dem', 7),
#  ('even', 7),
#  ('new', 7),
#  ('best', 7),
#  ('friend', 7),
#  ('many', 6),
#  ('then', 6),
#  ('Please', 6),
#  ('over', 6),
#  ('from', 6),
#  ('through', 6),
#  ('Run', 6),
#  ('glow', 6),
#  ('One', 6),
#  ('shit', 6),
#  ('The', 6),
#  ('life', 6),
#  ('about', 6),
#  ('hit', 6),
#  ('When', 6),
#  ("You're", 6),
#  ('kiss', 6),
#  ('last', 6),
#  ('off', 6),
#  ('should', 6),
#  ('Time', 6),
#  ('Boredom', 6),
#  ('Boy', 6),
#  ('as', 6),
#  ('ring', 6),
#  ('Uh', 5),
#  ('cars', 5),
#  ('seen', 5),
#  ('friends', 5),
#  ('let', 5),
#  ('their', 5),
#  ('he', 5),
#  ('baby', 5),
#  ('Now', 5),
#  ('skrrt', 5),
#  ('Out', 5),
#  ('cold', 5),
#  ('look', 5),
#  ('water', 5),
#  ('man', 5),
#  ('room', 5),
#  ("It's", 5),
#  ("you're", 5),
#  ("That's", 5),
#  ('face', 5),
#  ('war', 5),
#  ('again', 5),
#  ('switch', 5),
#  ('where', 5),
#  ('right', 5),
#  ('around', 5),
#  ('she', 5),
#  ('tryna', 5),
#  ('way', 5),
#  ('gotta', 5),
#  ('talk', 5),
#  ('words', 5),
#  ('mirror', 5),
#  ('couple', 5),
#  ('Damn', 5),
#  ('lie', 5),
#  ('deep', 5),
#  ('thoughts', 5),
#  ('glitter', 5),
#  ('there', 4),
#  ('See', 4),
#  ('cool', 4),
#  ('turn', 4),
#  ('gone', 4),
#  ('nothing', 4),
#  ('always', 4),
#  ('matter', 4),
#  ('Them', 4),
#  ('gonna', 4),
#  ('Maybe', 4),
#  ('sheep', 4),
#  ('These', 4),
#  ('window', 4),
#  ('shinin', 4),
#  ('T', 4),
#  ('stuck', 4),
#  ('low', 4),
#  ('Flower', 4),
#  ('since', 4),
#  ('stay', 4),
#  ('Cupid', 4),
#  ('eyes', 4),
#  ('Is', 4),
#  ('give', 4),
#  ('La', 4),
#  ('bitch', 4),
#  ('boys', 4),
#  ('Why', 4),
#  ('wheel', 4),
#  ('bad', 4),
#  ('else', 4),
#  ('ass', 4),
#  ('doin', 4),
#  ('bitches', 4),
#  ('because', 4),
#  ('now', 4),
#  ('left', 4),
#  ('gears', 4),
#  ('swerve', 4),
#  ('Watch', 4),
#  ('gon', 4),
#  ('Gotta', 4),
#  ('real', 4),
#  ('They', 4),
#  ('goes', 4),
#  ('having', 4),
#  ('flies', 4),
#  ('someone', 4),
#  ('morning', 4),
#  ('Got', 4),
#  ('line', 4),
#  ('really', 4),
#  ('Hawaiian', 4),
#  ('shirts', 4),
#  ('wassup', 4),
#  ('needed', 4),
#  ('down', 3),
#  ('fans', 3),
#  ('well', 3),
#  ('keepin', 3),
#  ('thought', 3),
#  ('better', 3),
#  ('pull', 3),
#  ('will', 3),
#  ('Because', 3),
#  ('mansion', 3),
#  ('windows', 3),
#  ('walk', 3),
#  ('drown', 3),
#  ('mean', 3),
#  ("Who's", 3),
#  ('Ayo', 3),
#  ("Let's", 3),
#  ('days', 3),
#  ("they're", 3),
#  ('float', 3),
#  ('world', 3),
#  ('Let', 3),
#  ('Shit', 3),
#  ('Look', 3),
#  ('skin', 3),
#  ('other', 3),
#  ('than', 3),
#  ('dark', 3),
#  ('ohh', 3),
#  ('name', 3),
#  ('hear', 3),
#  ('state', 3),
#  ('both', 3),
#  ('chasing', 3),
#  ('another', 3),
#  ('stop', 3),
#  ('an', 3),
#  ('rose', 3),
#  ('tinted', 3),
#  ('here', 3),
#  ('neck', 3),
#  ('number', 3),
#  ('start', 3),
#  ('McLaren', 3),
#  ('heart', 3),
#  ('Like', 3),
#  ('help', 3),
#  ('leave', 3),
#  ('by', 3),
#  ("Don't", 3),
#  ('All', 3),
#  ('show', 3),
#  ('everyone', 3),
#  ('myself', 3),
#  ('good', 3),
#  ('Garden', 3),
#  ('lost', 3),
#  ('fun', 3),
#  ('long', 3),
#  ('amusing', 3),
#  ('hope', 3),
#  ('Gonna', 3),
#  ('gas', 3),
#  ('At', 3),
#  ('answer', 3),
#  ('loneliest', 3),
#  ('or', 3),
#  ('pet', 3),
#  ('Feel', 3),
#  ('woah', 3),
#  ('track', 3),
#  ('every', 3),
#  ('We', 3),
#  ('Scum', 3),
#  ('Bitch', 2),
#  ('uh', 2),
#  ('road', 2),
#  ('land', 2),
#  ('Niggas', 2),
#  ('plans', 2),
#  ('into', 2),
#  ('outta', 2),
#  ('AC', 2),
#  ('blows', 2),
#  ('lasts', 2),
#  ('For', 2),
#  ('head', 2),
#  ('bed', 2),
#  ('straight', 2),
#  ('click', 2),
#  ('cop', 2),
#  ('usually', 2),
#  ('play', 2),
#  ('paid', 2),
#  ('ego', 2),
#  ('rooms', 2),
#  ('views', 2),
#  ('bottom', 2),
#  ('prolly', 2),
#  ('pool', 2),
#  ('ten', 2),
#  ('toes', 2),
#  ('fucked', 2),
#  ('crash', 2),
#  ('floor', 2),
#  ('dollar', 2),
#  ('Nobody', 2),
#  ('home', 2),
#  ('In', 2),
#  ('ride', 2),
#  ('frog', 2),
#  ('goggles', 2),
#  ('leanin', 2),
#  ('OJ', 2),
#  ('Simp', 2),
#  ('sun', 2),
#  ('Slick', 2),
#  ('circles', 2),
#  ("Ain't", 2),
#  ('nobody', 2),
#  ('might', 2),
#  ('Man', 2),
#  ('Tell', 2),
#  ('smell', 2),
#  ('mall', 2),
#  ('feels', 2),
#  ('forget', 2),
#  ('car', 2),
#  ('Ohh', 2),
#  ('Keep', 2),
#  ('trunk', 2),
#  ('Ah', 2),
#  ('Ahh', 2),
#  ('think', 2),
#  ('us', 2),
#  ('air', 2),
#  ("What's", 2),
#  ('Hello', 2),
#  ('song', 2),
#  ('live', 2),
#  ('dream', 2),
#  ('exist', 2),
#  ('eyelids', 2),
#  ('vision', 2),
#  ('precision', 2),
#  ('Wonder', 2),
#  ('ways', 2),
#  ('cross', 2),
#  ('running', 2),
#  ('dreams', 2),
#  ('close', 2),
#  ('cheeks', 2),
#  ("I'd", 2),
#  ('Make', 2),
#  ('Bout', 2),
#  ('GOLF', 2),
#  ('deposit', 2),
#  ('runnin', 2),
#  ('awesome', 2),
#  ('his', 2),
#  ('found', 2),
#  ('Young', 2),
#  ('Mad', 2),
#  ('chill', 2),
#  ('mad', 2),
#  ('push', 2),
#  ('puttin', 2),
#  ('vibes', 2),
#  ('Never', 2),
#  ('06', 2),
#  ('before', 2),
#  ('Had', 2),
#  ('Been', 2),
#  ('disappear', 2),
#  ('From', 2),
#  ('He', 2),
#  ('attention', 2),
#  ('lookin', 2),
#  ('To', 2),
#  ('eatin', 2),
#  ('meals', 2),
#  ('point', 2),
#  ('Clancy', 2),
#  ('reason', 2),
#  ('fact', 2),
#  ('Really', 2),
#  ('Do', 2),
#  ('listen', 2),
#  ('prepared', 2),
#  ('throw', 2),
#  ('front', 2),
#  ('ever', 2),
#  ('Fishtail', 2),
#  ('rearview', 2),
#  ('Skrrrrrt', 2),
#  ('steerin', 2),
#  ('grass', 2),
#  ('still', 2),
#  ('things', 2),
#  ("he's", 2),
#  ('next', 2),
#  ('four', 2),
#  ('potholes', 2),
#  ('kill', 2),
#  ('Before', 2),
#  ('Fly', 2),
#  ('fly', 2),
#  ('cocoon', 2),
#  ("couldn't", 2),
#  ("didn't", 2),
#  ('tell', 2),
#  ('This', 2),
#  ('heat', 2),
#  ('caught', 2),
#  ('talkin', 2),
#  ('stomach', 2),
#  ('Morning', 2),
#  ('hate', 2),
#  ('going', 2),
#  ('Tick', 2),
#  ('tock', 2),
#  ('quick', 2),
#  ('Lonely', 2),
#  ('speaker', 2),
#  ('bang', 2),
#  ('Chirp', 2),
#  ('chirp', 2),
#  ('burbs', 2),
#  ('birds', 2),
#  ('used', 2),
#  ('night', 2),
#  ('Old', 2),
#  ('weird', 2),
#  ('loudest', 2),
#  ('songs', 2),
#  ('thing', 2),
#  ('fillin', 2),
#  ('wall', 2),
#  ('winter', 2),
#  ('Naw', 2),
#  ('classics', 2),
#  ('buck', 2),
#  ("what's", 2),
#  ('summer', 2),
#  ('Winter', 2),
#  ('first', 2),
#  ('message', 2),
#  ('Da', 2),
#  ('Fireworks', 2),
#  ('wait', 2),
#  ('save', 2),
#  ('question', 1),
#  ('buy', 1),
#  ('pave', 1),
#  ('ocean', 1),
#  ('motions', 1),
#  ('beaches', 1),
#  ('sands', 1),
#  ('woods', 1),
#  ('flowers', 1),
#  ('rainbows', 1),
#  ('posies', 1),
#  ('Falling', 1),
#  ('pocket', 1),
#  ("ya'll", 1),
#  ('swam', 1),
#  ('cooler', 1),
#  ('TNT', 1),
#  ('finished', 1),
#  ('minute', 1),
#  ('Guessing', 1),
#  ('Nothing', 1),
#  ('sticks', 1),
#  ('together', 1),
#  ('Sick', 1),
#  ('sitting', 1),
#  ('doubt', 1),
#  ('figure', 1),
#  ('Shout', 1),
#  ('girls', 1),
#  ('lead', 1),
#  ('occasional', 1),
#  ('warm', 1),
#  ('trying', 1),
#  ('hardest', 1),
#  ('enough', 1),
#  ('airborne', 1),
#  ('raps', 1),
#  ('write', 1),
#  ('chain', 1),
#  ('chains', 1),
#  ('wear', 1),
#  ('considered', 1),
#  ('slave', 1),
#  ('slaves', 1),
#  ('Nat', 1),
#  ('Turner', 1),
#  ('arise', 1),
#  ('riots', 1),
#  ('Black', 1),
#  ('lives', 1),
#  ('clack', 1),
#  ('splatter', 1),
#  ('Pew', 1),
#  ('pew', 1),
#  ('Life', 1),
#  ('game', 1),
#  ('basketball', 1),
#  ('shoot', 1),
#  ('trigger', 1),
#  ('pulled', 1),
#  ('drivin', 1),
#  ('full', 1),
#  ('possessions', 1),
#  ('Nah', 1),
#  ('stares', 1),
#  ('backyard', 1),
#  ('does', 1),
#  ("you'll", 1),
#  ('swim', 1),
#  ('fall', 1),
#  ('wondering', 1),
#  ('Counting', 1),
#  ('Sadie', 1),
#  ("Hannah's", 1),
#  ('Carpet', 1),
#  ('mama', 1),
#  ('80', 1),
#  ('profit', 1),
#  ('coffee', 1),
#  ('poured', 1),
#  ('Rent-A-Center', 1),
#  ('calling', 1),
#  ('everyday', 1),
#  ('knocking', 1),
#  ('door', 1),
#  ('toys', 1),
#  ('dreamed', 1),
#  ('afford', 1),
#  ('Okaga', 1),
#  ('California', 1),
#  ('oval', 1),
#  ('fucking', 1),
#  ('may', 1),
#  ('freeze', 1),
#  ('ice', 1),
#  ('weighs', 1),
#  ('ton', 1),
#  ('Stunt', 1),
#  ('black', 1),
#  ('kids', 1),
#  ('Dye', 1),
#  ('hair', 1),
#  ('blue', 1),
#  ('Chanel', 1),
#  ('grip', 1),
#  ('manicured', 1),
#  ('nails', 1),
#  ('coconut', 1),
#  ('oil', 1),
#  ('top', 1),
#  ('follicles', 1),
#  ('thinnin', 1),
#  ('winning', 1),
#  ('winnin', 1),
#  ('Went', 1),
#  ('statistic', 1),
#  ('millionaire', 1),
#  ('CNN', 1),
#  ('doubted', 1),
#  ('Then', 1),
#  ('oak', 1),
#  ('Rooted', 1),
#  ('bloomed', 1),
#  ('tree', 1),
#  ('Took', 1),
#  ('lil', 1),
#  ('while', 1),
#  ('makin', 1),
#  ('leaves', 1),
#  ('branches', 1),
#  ('family', 1),
#  ('eat', 1),
#  ('Favorite', 1),
#  ('color', 1),
#  ('green', 1),
#  ('energy', 1),
#  ('strong', 1),
#  ('Giving', 1),
#  ('birdies', 1),
#  ('beez', 1),
#  ('Droppin', 1),
#  ('seeds', 1),
#  ('ahh', 1),
#  ('Sometimes', 1),
#  ('sit', 1),
#  ('Golf', 1),
#  ('Radio', 1),
#  ('Shane', 1),
#  ('Powers', 1),
#  ('Taking', 1),
#  ('requests', 1),
#  ('Um', 1),
#  ('Mr', 1),
#  ('Fucking-Secret-Agent', 1),
#  ('Relocate', 1),
#  ('fantasy', 1),
#  ('reality', 1),
#  ('Anytime', 1),
#  ('count', 1),
#  ('behind', 1),
#  ('wake', 1),
#  ('okie', 1),
#  ('dokie', 1),
#  ('infatuation', 1),
#  ('translatin', 1),
#  ('form', 1),
#  ('Love', 1),
#  ('met', 1),
#  ('looking', 1),
#  ('waiting', 1),
#  ('fore', 1),
#  ('alcoholic', 1),
#  ('understand', 1),
#  ('dirt-colored', 1),
#  ('Sugar', 1),
#  ('honey', 1),
#  ('iced', 1),
#  ('tea', 1),
#  ('bumblebee', 1),
#  ('scene', 1),
#  ('bakery', 1),
#  ('piece', 1),
#  ('pie', 1),
#  ('Yeugh', 1),
#  ('cupid', 1),
#  ('Yo', 1),
#  ('Him', 1),
#  ('ni-guh', 1),
#  ('swear', 1),
#  ('Stand', 1),
#  ('guy', 1),
#  ('chair', 1),
#  ('Well', 1),
#  ('shop', 1),
#  ('Dumb', 1),
#  ('mothafucka', 1),
#  ('goddamn', 1),
#  ('artist', 1),
#  ('markers', 1),
#  ('draw', 1),
#  ('closet', 1),
#  ('fresh', 1),
#  ('death', 1),
#  ('dressed', 1),
#  ('coffin', 1),
#  ('Cons', 1),
#  ('overalls', 1),
#  ('striped', 1),
#  ('shirt', 1),
#  ('drips', 1),
#  ('swag', 1),
#  ('broken', 1),
#  ('faucet', 1),
#  ('cherry', 1),
#  ('bomb', 1),
#  ('ran', 1),
#  ('Boston', 1),
#  ("Won't", 1),
#  ('cops', 1),
#  ('surround', 1),
#  ('jiggy', 1),
#  ('With', 1),
#  ('blown', 1),
#  ('step', 1),
#  ('jig', 1),
#  ('bick', 1),
#  ('big', 1),
#  ('came', 1),
#  ('wrist', 1),
#  ('flick', 1),
#  ('Guess', 1),
#  ('pants', 1),
#  ('dance', 1),
#  ('Spin', 1),
#  ('Raf', 1),
#  ('Still', 1),
#  ('math', 1),
#  ('miss', 1),
#  ('class', 1),
#  ('Was', 1),
#  ('Summertime', 1),
#  ('Number', 1),
#  ('N', 1),
#  ('ine', 1),
#  ('Vince', 1),
#  ('Gucci', 1),
#  ('gold', 1),
#  ('tips', 1),
#  ('letterman', 1),
#  ('sign', 1),
#  ('favorite', 1),
#  ('Fresh', 1),
#  ('freshmen', 1),
#  ('skipped', 1),
#  ('Senior', 1),
#  ('citizen', 1),
#  ('pass', 1),
#  ('knew', 1),
#  ('dick', 1),
#  ("nigga's", 1),
#  ('rap', 1),
#  ('own', 1),
#  ('planet', 1),
#  ('business', 1),
#  ('ventures', 1),
#  ('Actin', 1),
#  ('Teeth', 1),
#  ('glistenin', 1),
#  ('Jesus', 1),
#  ('Christmas', 1),
#  ('shittin', 1),
#  ('exquisite', 1),
#  ('expensive', 1),
#  ('WANG', 1),
#  ('AP', 1),
#  ('bumper', 1),
#  ('sticker', 1),
#  ('global', 1),
#  ('warming', 1),
#  ('frío', 1),
#  ('currently', 1),
#  ('95', 1),
#  ('Leo', 1),
#  ('mom', 1),
#  ('worried', 1),
#  ('ill', 1),
#  ('bread', 1),
#  ('weight', 1),
#  ('stayed', 1),
#  ('Get', 1),
#  ('guey', 1),
#  ('0', 1),
#  ('60', 1),
#  ('2', 1),
#  ('nueve', 1),
#  ('mother', 1),
#  ('warned', 1),
#  ('hand', 1),
#  ('trust', 1),
#  ('her', 1),
#  ('elder', 1),
#  ('white', 1),
#  ('His', 1),
#  ('fancy', 1),
#  ('props', 1),
#  ('half', 1),
#  ('why', 1),
#  ('dealerships', 1),
#  ('speedin', 1),
#  ('away', 1),
#  ('triple', 1),
#  ('double', 1),
#  ('streets', 1),
#  ('filled', 1),
#  ('clues', 1),
#  ('notice', 1),
#  ('familiar', 1),
#  ('cul-de-sac', 1),
#  ('themself', 1),
#  ('dilemma', 1),
#  ('traffic', 1),
#  ('picking', 1),
#  ('Skrt', 1),
#  ('speed', 1),
#  ('barely', 1),
#  ('seems', 1),
#  ('awkward', 1),
#  ('heard', 1),
#  ('steer', 1),
#  ('path', 1),
#  ('distracted', 1),
#  ('weather', 1),
#  ('rain', 1),
#  ('windshield', 1),
#  ('wipers', 1),
#  ('shade', 1),
#  ('jacket', 1),
#  ('also', 1),
#  ('power', 1),
#  ('jump', 1),
#  ('Just', 1),
#  ('Snakes', 1),
#  ('boots', 1),
#  ('says', 1),
#  ('bites', 1),
#  ('condom', 1),
#  ('Watchin', 1),
#  ('Clarence', 1),
#  ('successful', 1),
#  ('piggies', 1),
#  ('amazin', 1),
#  ('irony', 1),
#  ('stopped', 1),
#  ('bacon', 1),
#  ('twisted', 1),
#  ('hungry', 1),
#  ('hoes', 1),
#  ('tenderonies', 1),
#  ('made', 1),
#  ('past', 1),
#  ('month', 1),
#  ('please', 1),
#  ('Everyone', 1),
#  ('lone', 1),
#  ('wolf', 1),
#  ('peep', 1),
#  ('wants', 1),
#  ('wool', 1),
#  ('Since', 1),
#  ('rather', 1),
#  ('Than', 1),
#  ('fleece', 1),
#  ('T-Man', 1),
#  ('seesaw', 1),
#  ('Wind', 1),
#  ('which', 1),
#  ('knows', 1),
#  ('Batmobile', 1),
#  ('Good', 1),
#  ('health', 1),
#  ('success', 1),
#  ('earth', 1),
#  ('worthwhile', 1),
#  ('somebody', 1),
#  ('raise', 1),
#  ('lizards', 1),
#  ("vehicle's", 1),
#  ('miles', 1),
#  ('pushin', 1),
#  ('Do-do-do-do-do-do', 1),
#  ('Ooh', 1),
#  ('Haha', 1),
#  ('hide', 1),
#  ("there's", 1),
#  ('Shed', 1),
#  ('Go', 1),
#  ('hidin', 1),
#  ('pretend', 1),
#  ('garçons', 1),
#  ('feelings', 1),
#  ('guardin', 1),
#  ('Heavy', 1),
#  ('read', 1),
#  ('signs', 1),
#  ('location', 1),
#  ('Truth', 1),
#  ('youth', 1),
#  ('kid', 1),
#  ('phase', 1),
#  ('Thought', 1),
#  ("it'd", 1),
#  ('phrase', 1),
#  ('poof', 1),
#  ('goin', 1),
#  ('Big', 1),
#  ('fan', 1),
#  ('beige', 1),
#  ('tan', 1),
#  ('Polka', 1),
#  ('dot', 1),
#  ('nose', 1),
#  ('subwoofer', 1),
#  ('A', 1),
#  ('butterflies', 1),
#  ('Eh', 1),
#  ('Barely', 1),
#  ('interested', 1),
#  ('bagged', 1),
#  ('brag', 1),
#  ('Bruh', 1),
#  ('crucial', 1),
#  ('subject', 1),
#  ('Sensitive', 1),
#  ('cookin', 1),
#  ('batter', 1),
#  ('Til', 1),
#  ('temperature', 1),
#  ('risin', 1),
#  ('Steppin', 1),
#  ('ladder', 1),
#  ('Grab', 1),
#  ('rings', 1),
#  ('Saturn', 1),
#  ('Planet', 1),
#  ('chatter', 1),
#  ('It', 1),
#  ('Na-na-na', 1),
#  ('na-na-na', 1),
#  ('oh-na-na-na', 1),
#  ('bedroom', 1),
#  ('cereal', 1),
#  ('burial', 1),
#  ('serious', 1),
#  ('ate', 1),
#  ('dry', 1),
#  ('boxes', 1),
#  ('bodies', 1),
#  ("we're", 1),
#  ('ask', 1),
#  ('saw', 1),
#  ('eyeballs', 1),
#  ('turning', 1),
#  ('drywall', 1),
#  ('suck', 1),
#  ('Hi', 1),
#  ('problem', 1),
#  ('solved', 1),
#  ('bored', 1),
#  ('Bored', 1),
#  ('getting', 1),
#  ('desperate', 1),
#  ('hell', 1),
#  ('Desperate', 1),
#  ('using', 1),
#  ('texting', 1),
#  ('Cellular', 1),
#  ('Message', 1),
#  ('haven', 1),
#  ('t', 1),
#  ('exit', 1),
#  ('walls', 1),
#  ('handle', 1),
#  ...]

# %%
# Construct a fixed vocabulary
# print (all_counts.most_common())
vocabulary = [w for w, c in all_counts.most_common()]
# print (vocabulary)
vocabulary_size = len(vocabulary)

reverse_vocab = { w: i for i, w in enumerate(vocabulary) }

# %%
def counter_to_vector(counter):
    vector = numpy.zeros(vocabulary_size)
    for word in counter.keys():
        ## look up the integer ID for the string
        word_id = reverse_vocab[word]
#         print (counter[word])
        vector[word_id] = counter[word]
    
    return vector / vector.sum()

# %%
all_counts.most_common()
# Out:
# [('I', 241),
#  ('the', 149),
#  ('me', 116),
#  ('to', 83),
#  ('my', 80),
#  ('you', 78),
#  ('a', 77),
#  ('some', 66),
#  ('time', 64),
#  ('it', 60),
#  ('in', 59),
#  ('that', 53),
#  ('back', 48),
#  ("I'm", 46),
#  ('is', 45),
#  ('and', 43),
#  ('on', 38),
#  ('of', 35),
#  ('out', 33),
#  ('know', 32),
#  ('for', 31),
#  ('if', 30),
#  ('like', 30),
#  ('And', 28),
#  ('got', 28),
#  ("don't", 28),
#  ('How', 27),
#  ('can', 27),
#  ('Find', 27),
#  ('was', 26),
#  ('la', 25),
#  ('call', 24),
#  ('November', 24),
#  ('with', 23),
#  ('nigga', 23),
#  ('feel', 23),
#  ('em', 22),
#  ('get', 20),
#  ('up', 20),
#  ('take', 19),
#  ('do', 19),
#  ('okay', 19),
#  ('Who', 19),
#  ('You', 18),
#  ('be', 18),
#  ('fuck', 17),
#  ('yeah', 17),
#  ("ain't", 16),
#  ('this', 16),
#  ('Cause', 16),
#  ('what', 16),
#  ('But', 16),
#  ('My', 16),
#  ('pothole', 16),
#  ('find', 16),
#  ('Take', 16),
#  ('run', 15),
#  ('never', 15),
#  ("that's", 15),
#  ('who', 15),
#  ('cause', 15),
#  ('so', 15),
#  ('him', 15),
#  ('ya', 15),
#  ('could', 14),
#  ('What', 14),
#  ('oh', 14),
#  ('go', 13),
#  ('all', 13),
#  ('but', 13),
#  ('one', 13),
#  ('your', 13),
#  ('been', 13),
#  ('they', 12),
#  ('Yeah', 12),
#  ('boy', 12),
#  ('Nigga', 12),
#  ('Fuck', 12),
#  ('something', 12),
#  ('na', 12),
#  ('had', 11),
#  ('not', 11),
#  ('see', 11),
#  ("I'll", 11),
#  ('niggas', 11),
#  ('said', 11),
#  ('Can', 11),
#  ('watch', 11),
#  ("can't", 11),
#  ('Call', 11),
#  ('911', 11),
#  ('want', 10),
#  ('them', 10),
#  ('when', 10),
#  ('roll', 10),
#  ('say', 10),
#  ('at', 10),
#  ('make', 10),
#  ("I've", 10),
#  ('So', 10),
#  ('boredom', 10),
#  ('keep', 9),
#  ('bloom', 9),
#  ('more', 9),
#  ('just', 9),
#  ('garden', 9),
#  ('these', 9),
#  ('we', 9),
#  ('sick', 9),
#  ('day', 9),
#  ('fuckin', 9),
#  ('lonely', 9),
#  ('have', 8),
#  ('much', 8),
#  ('are', 8),
#  ('wanna', 8),
#  ('20', 8),
#  ('bout', 8),
#  ("it's", 8),
#  ('no', 8),
#  ('love', 8),
#  ('shed', 8),
#  ('til', 7),
#  ('drive', 7),
#  ('until', 7),
#  ('If', 7),
#  ('forever', 7),
#  ('too', 7),
#  ('come', 7),
#  ('only', 7),
#  ('rock', 7),
#  ('grow', 7),
#  ('Okay', 7),
#  ('mind', 7),
#  ("I'ma", 7),
#  ('Oh', 7),
#  ('dat', 7),
#  ('need', 7),
#  ("y'all", 7),
#  ('That', 7),
#  ('how', 7),
#  ('dem', 7),
#  ('even', 7),
#  ('new', 7),
#  ('best', 7),
#  ('friend', 7),
#  ('many', 6),
#  ('then', 6),
#  ('Please', 6),
#  ('over', 6),
#  ('from', 6),
#  ('through', 6),
#  ('Run', 6),
#  ('glow', 6),
#  ('One', 6),
#  ('shit', 6),
#  ('The', 6),
#  ('life', 6),
#  ('about', 6),
#  ('hit', 6),
#  ('When', 6),
#  ("You're", 6),
#  ('kiss', 6),
#  ('last', 6),
#  ('off', 6),
#  ('should', 6),
#  ('Time', 6),
#  ('Boredom', 6),
#  ('Boy', 6),
#  ('as', 6),
#  ('ring', 6),
#  ('Uh', 5),
#  ('cars', 5),
#  ('seen', 5),
#  ('friends', 5),
#  ('let', 5),
#  ('their', 5),
#  ('he', 5),
#  ('baby', 5),
#  ('Now', 5),
#  ('skrrt', 5),
#  ('Out', 5),
#  ('cold', 5),
#  ('look', 5),
#  ('water', 5),
#  ('man', 5),
#  ('room', 5),
#  ("It's", 5),
#  ("you're", 5),
#  ("That's", 5),
#  ('face', 5),
#  ('war', 5),
#  ('again', 5),
#  ('switch', 5),
#  ('where', 5),
#  ('right', 5),
#  ('around', 5),
#  ('she', 5),
#  ('tryna', 5),
#  ('way', 5),
#  ('gotta', 5),
#  ('talk', 5),
#  ('words', 5),
#  ('mirror', 5),
#  ('couple', 5),
#  ('Damn', 5),
#  ('lie', 5),
#  ('deep', 5),
#  ('thoughts', 5),
#  ('glitter', 5),
#  ('there', 4),
#  ('See', 4),
#  ('cool', 4),
#  ('turn', 4),
#  ('gone', 4),
#  ('nothing', 4),
#  ('always', 4),
#  ('matter', 4),
#  ('Them', 4),
#  ('gonna', 4),
#  ('Maybe', 4),
#  ('sheep', 4),
#  ('These', 4),
#  ('window', 4),
#  ('shinin', 4),
#  ('T', 4),
#  ('stuck', 4),
#  ('low', 4),
#  ('Flower', 4),
#  ('since', 4),
#  ('stay', 4),
#  ('Cupid', 4),
#  ('eyes', 4),
#  ('Is', 4),
#  ('give', 4),
#  ('La', 4),
#  ('bitch', 4),
#  ('boys', 4),
#  ('Why', 4),
#  ('wheel', 4),
#  ('bad', 4),
#  ('else', 4),
#  ('ass', 4),
#  ('doin', 4),
#  ('bitches', 4),
#  ('because', 4),
#  ('now', 4),
#  ('left', 4),
#  ('gears', 4),
#  ('swerve', 4),
#  ('Watch', 4),
#  ('gon', 4),
#  ('Gotta', 4),
#  ('real', 4),
#  ('They', 4),
#  ('goes', 4),
#  ('having', 4),
#  ('flies', 4),
#  ('someone', 4),
#  ('morning', 4),
#  ('Got', 4),
#  ('line', 4),
#  ('really', 4),
#  ('Hawaiian', 4),
#  ('shirts', 4),
#  ('wassup', 4),
#  ('needed', 4),
#  ('down', 3),
#  ('fans', 3),
#  ('well', 3),
#  ('keepin', 3),
#  ('thought', 3),
#  ('better', 3),
#  ('pull', 3),
#  ('will', 3),
#  ('Because', 3),
#  ('mansion', 3),
#  ('windows', 3),
#  ('walk', 3),
#  ('drown', 3),
#  ('mean', 3),
#  ("Who's", 3),
#  ('Ayo', 3),
#  ("Let's", 3),
#  ('days', 3),
#  ("they're", 3),
#  ('float', 3),
#  ('world', 3),
#  ('Let', 3),
#  ('Shit', 3),
#  ('Look', 3),
#  ('skin', 3),
#  ('other', 3),
#  ('than', 3),
#  ('dark', 3),
#  ('ohh', 3),
#  ('name', 3),
#  ('hear', 3),
#  ('state', 3),
#  ('both', 3),
#  ('chasing', 3),
#  ('another', 3),
#  ('stop', 3),
#  ('an', 3),
#  ('rose', 3),
#  ('tinted', 3),
#  ('here', 3),
#  ('neck', 3),
#  ('number', 3),
#  ('start', 3),
#  ('McLaren', 3),
#  ('heart', 3),
#  ('Like', 3),
#  ('help', 3),
#  ('leave', 3),
#  ('by', 3),
#  ("Don't", 3),
#  ('All', 3),
#  ('show', 3),
#  ('everyone', 3),
#  ('myself', 3),
#  ('good', 3),
#  ('Garden', 3),
#  ('lost', 3),
#  ('fun', 3),
#  ('long', 3),
#  ('amusing', 3),
#  ('hope', 3),
#  ('Gonna', 3),
#  ('gas', 3),
#  ('At', 3),
#  ('answer', 3),
#  ('loneliest', 3),
#  ('or', 3),
#  ('pet', 3),
#  ('Feel', 3),
#  ('woah', 3),
#  ('track', 3),
#  ('every', 3),
#  ('We', 3),
#  ('Scum', 3),
#  ('Bitch', 2),
#  ('uh', 2),
#  ('road', 2),
#  ('land', 2),
#  ('Niggas', 2),
#  ('plans', 2),
#  ('into', 2),
#  ('outta', 2),
#  ('AC', 2),
#  ('blows', 2),
#  ('lasts', 2),
#  ('For', 2),
#  ('head', 2),
#  ('bed', 2),
#  ('straight', 2),
#  ('click', 2),
#  ('cop', 2),
#  ('usually', 2),
#  ('play', 2),
#  ('paid', 2),
#  ('ego', 2),
#  ('rooms', 2),
#  ('views', 2),
#  ('bottom', 2),
#  ('prolly', 2),
#  ('pool', 2),
#  ('ten', 2),
#  ('toes', 2),
#  ('fucked', 2),
#  ('crash', 2),
#  ('floor', 2),
#  ('dollar', 2),
#  ('Nobody', 2),
#  ('home', 2),
#  ('In', 2),
#  ('ride', 2),
#  ('frog', 2),
#  ('goggles', 2),
#  ('leanin', 2),
#  ('OJ', 2),
#  ('Simp', 2),
#  ('sun', 2),
#  ('Slick', 2),
#  ('circles', 2),
#  ("Ain't", 2),
#  ('nobody', 2),
#  ('might', 2),
#  ('Man', 2),
#  ('Tell', 2),
#  ('smell', 2),
#  ('mall', 2),
#  ('feels', 2),
#  ('forget', 2),
#  ('car', 2),
#  ('Ohh', 2),
#  ('Keep', 2),
#  ('trunk', 2),
#  ('Ah', 2),
#  ('Ahh', 2),
#  ('think', 2),
#  ('us', 2),
#  ('air', 2),
#  ("What's", 2),
#  ('Hello', 2),
#  ('song', 2),
#  ('live', 2),
#  ('dream', 2),
#  ('exist', 2),
#  ('eyelids', 2),
#  ('vision', 2),
#  ('precision', 2),
#  ('Wonder', 2),
#  ('ways', 2),
#  ('cross', 2),
#  ('running', 2),
#  ('dreams', 2),
#  ('close', 2),
#  ('cheeks', 2),
#  ("I'd", 2),
#  ('Make', 2),
#  ('Bout', 2),
#  ('GOLF', 2),
#  ('deposit', 2),
#  ('runnin', 2),
#  ('awesome', 2),
#  ('his', 2),
#  ('found', 2),
#  ('Young', 2),
#  ('Mad', 2),
#  ('chill', 2),
#  ('mad', 2),
#  ('push', 2),
#  ('puttin', 2),
#  ('vibes', 2),
#  ('Never', 2),
#  ('06', 2),
#  ('before', 2),
#  ('Had', 2),
#  ('Been', 2),
#  ('disappear', 2),
#  ('From', 2),
#  ('He', 2),
#  ('attention', 2),
#  ('lookin', 2),
#  ('To', 2),
#  ('eatin', 2),
#  ('meals', 2),
#  ('point', 2),
#  ('Clancy', 2),
#  ('reason', 2),
#  ('fact', 2),
#  ('Really', 2),
#  ('Do', 2),
#  ('listen', 2),
#  ('prepared', 2),
#  ('throw', 2),
#  ('front', 2),
#  ('ever', 2),
#  ('Fishtail', 2),
#  ('rearview', 2),
#  ('Skrrrrrt', 2),
#  ('steerin', 2),
#  ('grass', 2),
#  ('still', 2),
#  ('things', 2),
#  ("he's", 2),
#  ('next', 2),
#  ('four', 2),
#  ('potholes', 2),
#  ('kill', 2),
#  ('Before', 2),
#  ('Fly', 2),
#  ('fly', 2),
#  ('cocoon', 2),
#  ("couldn't", 2),
#  ("didn't", 2),
#  ('tell', 2),
#  ('This', 2),
#  ('heat', 2),
#  ('caught', 2),
#  ('talkin', 2),
#  ('stomach', 2),
#  ('Morning', 2),
#  ('hate', 2),
#  ('going', 2),
#  ('Tick', 2),
#  ('tock', 2),
#  ('quick', 2),
#  ('Lonely', 2),
#  ('speaker', 2),
#  ('bang', 2),
#  ('Chirp', 2),
#  ('chirp', 2),
#  ('burbs', 2),
#  ('birds', 2),
#  ('used', 2),
#  ('night', 2),
#  ('Old', 2),
#  ('weird', 2),
#  ('loudest', 2),
#  ('songs', 2),
#  ('thing', 2),
#  ('fillin', 2),
#  ('wall', 2),
#  ('winter', 2),
#  ('Naw', 2),
#  ('classics', 2),
#  ('buck', 2),
#  ("what's", 2),
#  ('summer', 2),
#  ('Winter', 2),
#  ('first', 2),
#  ('message', 2),
#  ('Da', 2),
#  ('Fireworks', 2),
#  ('wait', 2),
#  ('save', 2),
#  ('question', 1),
#  ('buy', 1),
#  ('pave', 1),
#  ('ocean', 1),
#  ('motions', 1),
#  ('beaches', 1),
#  ('sands', 1),
#  ('woods', 1),
#  ('flowers', 1),
#  ('rainbows', 1),
#  ('posies', 1),
#  ('Falling', 1),
#  ('pocket', 1),
#  ("ya'll", 1),
#  ('swam', 1),
#  ('cooler', 1),
#  ('TNT', 1),
#  ('finished', 1),
#  ('minute', 1),
#  ('Guessing', 1),
#  ('Nothing', 1),
#  ('sticks', 1),
#  ('together', 1),
#  ('Sick', 1),
#  ('sitting', 1),
#  ('doubt', 1),
#  ('figure', 1),
#  ('Shout', 1),
#  ('girls', 1),
#  ('lead', 1),
#  ('occasional', 1),
#  ('warm', 1),
#  ('trying', 1),
#  ('hardest', 1),
#  ('enough', 1),
#  ('airborne', 1),
#  ('raps', 1),
#  ('write', 1),
#  ('chain', 1),
#  ('chains', 1),
#  ('wear', 1),
#  ('considered', 1),
#  ('slave', 1),
#  ('slaves', 1),
#  ('Nat', 1),
#  ('Turner', 1),
#  ('arise', 1),
#  ('riots', 1),
#  ('Black', 1),
#  ('lives', 1),
#  ('clack', 1),
#  ('splatter', 1),
#  ('Pew', 1),
#  ('pew', 1),
#  ('Life', 1),
#  ('game', 1),
#  ('basketball', 1),
#  ('shoot', 1),
#  ('trigger', 1),
#  ('pulled', 1),
#  ('drivin', 1),
#  ('full', 1),
#  ('possessions', 1),
#  ('Nah', 1),
#  ('stares', 1),
#  ('backyard', 1),
#  ('does', 1),
#  ("you'll", 1),
#  ('swim', 1),
#  ('fall', 1),
#  ('wondering', 1),
#  ('Counting', 1),
#  ('Sadie', 1),
#  ("Hannah's", 1),
#  ('Carpet', 1),
#  ('mama', 1),
#  ('80', 1),
#  ('profit', 1),
#  ('coffee', 1),
#  ('poured', 1),
#  ('Rent-A-Center', 1),
#  ('calling', 1),
#  ('everyday', 1),
#  ('knocking', 1),
#  ('door', 1),
#  ('toys', 1),
#  ('dreamed', 1),
#  ('afford', 1),
#  ('Okaga', 1),
#  ('California', 1),
#  ('oval', 1),
#  ('fucking', 1),
#  ('may', 1),
#  ('freeze', 1),
#  ('ice', 1),
#  ('weighs', 1),
#  ('ton', 1),
#  ('Stunt', 1),
#  ('black', 1),
#  ('kids', 1),
#  ('Dye', 1),
#  ('hair', 1),
#  ('blue', 1),
#  ('Chanel', 1),
#  ('grip', 1),
#  ('manicured', 1),
#  ('nails', 1),
#  ('coconut', 1),
#  ('oil', 1),
#  ('top', 1),
#  ('follicles', 1),
#  ('thinnin', 1),
#  ('winning', 1),
#  ('winnin', 1),
#  ('Went', 1),
#  ('statistic', 1),
#  ('millionaire', 1),
#  ('CNN', 1),
#  ('doubted', 1),
#  ('Then', 1),
#  ('oak', 1),
#  ('Rooted', 1),
#  ('bloomed', 1),
#  ('tree', 1),
#  ('Took', 1),
#  ('lil', 1),
#  ('while', 1),
#  ('makin', 1),
#  ('leaves', 1),
#  ('branches', 1),
#  ('family', 1),
#  ('eat', 1),
#  ('Favorite', 1),
#  ('color', 1),
#  ('green', 1),
#  ('energy', 1),
#  ('strong', 1),
#  ('Giving', 1),
#  ('birdies', 1),
#  ('beez', 1),
#  ('Droppin', 1),
#  ('seeds', 1),
#  ('ahh', 1),
#  ('Sometimes', 1),
#  ('sit', 1),
#  ('Golf', 1),
#  ('Radio', 1),
#  ('Shane', 1),
#  ('Powers', 1),
#  ('Taking', 1),
#  ('requests', 1),
#  ('Um', 1),
#  ('Mr', 1),
#  ('Fucking-Secret-Agent', 1),
#  ('Relocate', 1),
#  ('fantasy', 1),
#  ('reality', 1),
#  ('Anytime', 1),
#  ('count', 1),
#  ('behind', 1),
#  ('wake', 1),
#  ('okie', 1),
#  ('dokie', 1),
#  ('infatuation', 1),
#  ('translatin', 1),
#  ('form', 1),
#  ('Love', 1),
#  ('met', 1),
#  ('looking', 1),
#  ('waiting', 1),
#  ('fore', 1),
#  ('alcoholic', 1),
#  ('understand', 1),
#  ('dirt-colored', 1),
#  ('Sugar', 1),
#  ('honey', 1),
#  ('iced', 1),
#  ('tea', 1),
#  ('bumblebee', 1),
#  ('scene', 1),
#  ('bakery', 1),
#  ('piece', 1),
#  ('pie', 1),
#  ('Yeugh', 1),
#  ('cupid', 1),
#  ('Yo', 1),
#  ('Him', 1),
#  ('ni-guh', 1),
#  ('swear', 1),
#  ('Stand', 1),
#  ('guy', 1),
#  ('chair', 1),
#  ('Well', 1),
#  ('shop', 1),
#  ('Dumb', 1),
#  ('mothafucka', 1),
#  ('goddamn', 1),
#  ('artist', 1),
#  ('markers', 1),
#  ('draw', 1),
#  ('closet', 1),
#  ('fresh', 1),
#  ('death', 1),
#  ('dressed', 1),
#  ('coffin', 1),
#  ('Cons', 1),
#  ('overalls', 1),
#  ('striped', 1),
#  ('shirt', 1),
#  ('drips', 1),
#  ('swag', 1),
#  ('broken', 1),
#  ('faucet', 1),
#  ('cherry', 1),
#  ('bomb', 1),
#  ('ran', 1),
#  ('Boston', 1),
#  ("Won't", 1),
#  ('cops', 1),
#  ('surround', 1),
#  ('jiggy', 1),
#  ('With', 1),
#  ('blown', 1),
#  ('step', 1),
#  ('jig', 1),
#  ('bick', 1),
#  ('big', 1),
#  ('came', 1),
#  ('wrist', 1),
#  ('flick', 1),
#  ('Guess', 1),
#  ('pants', 1),
#  ('dance', 1),
#  ('Spin', 1),
#  ('Raf', 1),
#  ('Still', 1),
#  ('math', 1),
#  ('miss', 1),
#  ('class', 1),
#  ('Was', 1),
#  ('Summertime', 1),
#  ('Number', 1),
#  ('N', 1),
#  ('ine', 1),
#  ('Vince', 1),
#  ('Gucci', 1),
#  ('gold', 1),
#  ('tips', 1),
#  ('letterman', 1),
#  ('sign', 1),
#  ('favorite', 1),
#  ('Fresh', 1),
#  ('freshmen', 1),
#  ('skipped', 1),
#  ('Senior', 1),
#  ('citizen', 1),
#  ('pass', 1),
#  ('knew', 1),
#  ('dick', 1),
#  ("nigga's", 1),
#  ('rap', 1),
#  ('own', 1),
#  ('planet', 1),
#  ('business', 1),
#  ('ventures', 1),
#  ('Actin', 1),
#  ('Teeth', 1),
#  ('glistenin', 1),
#  ('Jesus', 1),
#  ('Christmas', 1),
#  ('shittin', 1),
#  ('exquisite', 1),
#  ('expensive', 1),
#  ('WANG', 1),
#  ('AP', 1),
#  ('bumper', 1),
#  ('sticker', 1),
#  ('global', 1),
#  ('warming', 1),
#  ('frío', 1),
#  ('currently', 1),
#  ('95', 1),
#  ('Leo', 1),
#  ('mom', 1),
#  ('worried', 1),
#  ('ill', 1),
#  ('bread', 1),
#  ('weight', 1),
#  ('stayed', 1),
#  ('Get', 1),
#  ('guey', 1),
#  ('0', 1),
#  ('60', 1),
#  ('2', 1),
#  ('nueve', 1),
#  ('mother', 1),
#  ('warned', 1),
#  ('hand', 1),
#  ('trust', 1),
#  ('her', 1),
#  ('elder', 1),
#  ('white', 1),
#  ('His', 1),
#  ('fancy', 1),
#  ('props', 1),
#  ('half', 1),
#  ('why', 1),
#  ('dealerships', 1),
#  ('speedin', 1),
#  ('away', 1),
#  ('triple', 1),
#  ('double', 1),
#  ('streets', 1),
#  ('filled', 1),
#  ('clues', 1),
#  ('notice', 1),
#  ('familiar', 1),
#  ('cul-de-sac', 1),
#  ('themself', 1),
#  ('dilemma', 1),
#  ('traffic', 1),
#  ('picking', 1),
#  ('Skrt', 1),
#  ('speed', 1),
#  ('barely', 1),
#  ('seems', 1),
#  ('awkward', 1),
#  ('heard', 1),
#  ('steer', 1),
#  ('path', 1),
#  ('distracted', 1),
#  ('weather', 1),
#  ('rain', 1),
#  ('windshield', 1),
#  ('wipers', 1),
#  ('shade', 1),
#  ('jacket', 1),
#  ('also', 1),
#  ('power', 1),
#  ('jump', 1),
#  ('Just', 1),
#  ('Snakes', 1),
#  ('boots', 1),
#  ('says', 1),
#  ('bites', 1),
#  ('condom', 1),
#  ('Watchin', 1),
#  ('Clarence', 1),
#  ('successful', 1),
#  ('piggies', 1),
#  ('amazin', 1),
#  ('irony', 1),
#  ('stopped', 1),
#  ('bacon', 1),
#  ('twisted', 1),
#  ('hungry', 1),
#  ('hoes', 1),
#  ('tenderonies', 1),
#  ('made', 1),
#  ('past', 1),
#  ('month', 1),
#  ('please', 1),
#  ('Everyone', 1),
#  ('lone', 1),
#  ('wolf', 1),
#  ('peep', 1),
#  ('wants', 1),
#  ('wool', 1),
#  ('Since', 1),
#  ('rather', 1),
#  ('Than', 1),
#  ('fleece', 1),
#  ('T-Man', 1),
#  ('seesaw', 1),
#  ('Wind', 1),
#  ('which', 1),
#  ('knows', 1),
#  ('Batmobile', 1),
#  ('Good', 1),
#  ('health', 1),
#  ('success', 1),
#  ('earth', 1),
#  ('worthwhile', 1),
#  ('somebody', 1),
#  ('raise', 1),
#  ('lizards', 1),
#  ("vehicle's", 1),
#  ('miles', 1),
#  ('pushin', 1),
#  ('Do-do-do-do-do-do', 1),
#  ('Ooh', 1),
#  ('Haha', 1),
#  ('hide', 1),
#  ("there's", 1),
#  ('Shed', 1),
#  ('Go', 1),
#  ('hidin', 1),
#  ('pretend', 1),
#  ('garçons', 1),
#  ('feelings', 1),
#  ('guardin', 1),
#  ('Heavy', 1),
#  ('read', 1),
#  ('signs', 1),
#  ('location', 1),
#  ('Truth', 1),
#  ('youth', 1),
#  ('kid', 1),
#  ('phase', 1),
#  ('Thought', 1),
#  ("it'd", 1),
#  ('phrase', 1),
#  ('poof', 1),
#  ('goin', 1),
#  ('Big', 1),
#  ('fan', 1),
#  ('beige', 1),
#  ('tan', 1),
#  ('Polka', 1),
#  ('dot', 1),
#  ('nose', 1),
#  ('subwoofer', 1),
#  ('A', 1),
#  ('butterflies', 1),
#  ('Eh', 1),
#  ('Barely', 1),
#  ('interested', 1),
#  ('bagged', 1),
#  ('brag', 1),
#  ('Bruh', 1),
#  ('crucial', 1),
#  ('subject', 1),
#  ('Sensitive', 1),
#  ('cookin', 1),
#  ('batter', 1),
#  ('Til', 1),
#  ('temperature', 1),
#  ('risin', 1),
#  ('Steppin', 1),
#  ('ladder', 1),
#  ('Grab', 1),
#  ('rings', 1),
#  ('Saturn', 1),
#  ('Planet', 1),
#  ('chatter', 1),
#  ('It', 1),
#  ('Na-na-na', 1),
#  ('na-na-na', 1),
#  ('oh-na-na-na', 1),
#  ('bedroom', 1),
#  ('cereal', 1),
#  ('burial', 1),
#  ('serious', 1),
#  ('ate', 1),
#  ('dry', 1),
#  ('boxes', 1),
#  ('bodies', 1),
#  ("we're", 1),
#  ('ask', 1),
#  ('saw', 1),
#  ('eyeballs', 1),
#  ('turning', 1),
#  ('drywall', 1),
#  ('suck', 1),
#  ('Hi', 1),
#  ('problem', 1),
#  ('solved', 1),
#  ('bored', 1),
#  ('Bored', 1),
#  ('getting', 1),
#  ('desperate', 1),
#  ('hell', 1),
#  ('Desperate', 1),
#  ('using', 1),
#  ('texting', 1),
#  ('Cellular', 1),
#  ('Message', 1),
#  ('haven', 1),
#  ('t', 1),
#  ('exit', 1),
#  ('walls', 1),
#  ('handle', 1),
#  ...]

# %%
# Convert counters to vectors
all_vector = counter_to_vector(all_counts)
# print (all_vector)
for song in songs:
    song["Vector"] = counter_to_vector(song["Tokens"])

# %%
all_vector
# Out:
# array([0.04752514, 0.02938276, 0.02287517, ..., 0.0001972 , 0.0001972 ,
#        0.0001972 ])

# %%
for song_id, song in enumerate(songs):
    # `nonzero` returns a tuple with one element per dimension of the input array
    nzs = numpy.nonzero(song["Vector"])[0]
    kl_terms = song["Vector"][nzs] * numpy.log2(song["Vector"][nzs] / all_vector[nzs])
    
    vocabulary_subset = [vocabulary[i] for i in nzs]

    sorted_words = sorted(zip(kl_terms, vocabulary_subset), reverse=True)
    print(song_id, song["title"])
    print(", ".join(["{} ({:.3f})".format(w, s) for s, w in sorted_words[:20]]))
    print(", ".join(["{} ({:.3f})".format(w, s) for s, w in sorted_words[-20:]]))
    print()
#more frequent in general*multiplied high ratio may not be as important*because it occurs more
#Four Context
#my changes over time
# self referential
# introspective 
#story
# Out:
# 0 Foreword
# many (0.047), can (0.047), How (0.047), until (0.044), and (0.038), And (0.038), then (0.037), know (0.034), til (0.034), Maybe (0.032), if (0.029), I (0.026), come (0.024), better (0.024), Who's (0.024), much (0.023), run (0.022), gonna (0.021), I'll (0.019), views (0.016)
# had (0.000), with (-0.000), nigga (-0.000), Yeah (-0.000), one (-0.000), go (-0.000), but (-0.000), back (-0.001), that's (-0.001), never (-0.001), on (-0.001), this (-0.001), ain't (-0.001), is (-0.004), some (-0.005), it (-0.005), to (-0.006), you (-0.008), the (-0.009), me (-0.012)
#
# 1 Where This Flower Blooms
# I (0.073), run (0.035), roll (0.029), it (0.022), rock (0.020), grow (0.020), many (0.017), glow (0.017), Run (0.017), bloom (0.017), until (0.016), can (0.016), know (0.015), then (0.013), How (0.013), til (0.012), shinin (0.012), Maybe (0.012), skrrt (0.010), and (0.010)
# had (-0.001), But (-0.001), em (-0.001), boy (-0.001), one (-0.001), who (-0.002), so (-0.002), ain't (-0.002), take (-0.002), do (-0.002), like (-0.003), back (-0.004), the (-0.004), a (-0.005), is (-0.005), time (-0.006), some (-0.007), you (-0.008), to (-0.008), me (-0.012)
#
# 2 Sometimes...
# I (0.065), run (0.032), roll (0.027), it (0.019), rock (0.019), grow (0.019), many (0.016), glow (0.016), Run (0.016), bloom (0.016), until (0.015), can (0.014), know (0.014), then (0.012), be (0.011), How (0.011), til (0.011), shinin (0.011), Maybe (0.011), and (0.010)
# had (-0.001), But (-0.001), boy (-0.001), em (-0.001), who (-0.002), so (-0.002), ain't (-0.002), take (-0.002), okay (-0.002), do (-0.002), like (-0.003), back (-0.004), the (-0.005), is (-0.005), a (-0.005), time (-0.006), you (-0.006), some (-0.007), to (-0.007), me (-0.012)
#
# 3 See You Again
# I (0.058), la (0.034), okay (0.023), run (0.016), can (0.015), it (0.014), roll (0.014), And (0.012), 20 (0.011), said (0.010), Can (0.010), know (0.010), sick (0.010), rock (0.010), grow (0.010), forever (0.010), my (0.009), of (0.009), many (0.008), glow (0.008)
# never (-0.001), cause (-0.001), ain't (-0.002), But (-0.002), take (-0.002), call (-0.002), do (-0.002), in (-0.002), em (-0.002), got (-0.002), was (-0.002), like (-0.003), is (-0.004), that (-0.004), a (-0.005), back (-0.005), time (-0.006), some (-0.006), the (-0.009), me (-0.012)
#
# 4 Who Dat Boy
# I (0.021), la (0.019), okay (0.013), Who (0.011), my (0.009), nigga (0.009), run (0.008), can (0.008), roll (0.007), And (0.007), I'm (0.007), said (0.007), boy (0.006), Nigga (0.006), 20 (0.006), you (0.006), him (0.006), know (0.006), Can (0.005), sick (0.005)
# My (-0.001), so (-0.001), never (-0.001), take (-0.001), out (-0.002), got (-0.002), ain't (-0.002), But (-0.002), call (-0.002), do (-0.002), for (-0.002), em (-0.002), was (-0.002), feel (-0.002), to (-0.004), back (-0.005), time (-0.006), some (-0.007), the (-0.007), me (-0.012)
#
# 5 Pothole
# I (0.015), la (0.010), out (0.008), okay (0.008), nigga (0.007), pothole (0.006), And (0.006), Who (0.006), for (0.005), it (0.005), Nigga (0.005), my (0.004), watch (0.004), said (0.004), in (0.004), run (0.004), him (0.004), know (0.004), roll (0.004), can (0.004)
# I've (-0.001), been (-0.001), ya (-0.001), How (-0.001), take (-0.001), ain't (-0.001), call (-0.001), could (-0.001), What (-0.001), Find (-0.001), never (-0.002), My (-0.002), do (-0.002), feel (-0.002), was (-0.002), back (-0.005), to (-0.005), time (-0.006), some (-0.007), me (-0.012)
#
# 6 Garden Shed
# I (0.011), la (0.008), it (0.007), okay (0.006), out (0.006), nigga (0.006), pothole (0.005), And (0.005), the (0.004), Who (0.004), for (0.004), on (0.004), my (0.004), run (0.004), Nigga (0.004), watch (0.003), said (0.003), in (0.003), roll (0.003), can (0.003)
# I've (-0.001), ya (-0.001), ain't (-0.001), Cause (-0.001), take (-0.001), call (-0.001), What (-0.001), My (-0.002), got (-0.002), never (-0.002), How (-0.002), do (-0.002), feel (-0.002), you (-0.002), Find (-0.003), to (-0.004), back (-0.005), time (-0.006), some (-0.007), me (-0.012)
#
# 7 Boredom
# time (0.007), some (0.006), Find (0.005), la (0.005), I (0.004), okay (0.004), it (0.004), nigga (0.003), pothole (0.003), out (0.003), can (0.003), for (0.002), And (0.002), Who (0.002), em (0.002), Nigga (0.002), run (0.002), watch (0.002), said (0.002), I'm (0.002)
# can't (-0.001), ain't (-0.001), if (-0.001), so (-0.001), ya (-0.001), I've (-0.001), to (-0.001), take (-0.001), one (-0.001), call (-0.001), been (-0.001), What (-0.001), was (-0.001), never (-0.002), My (-0.002), feel (-0.002), How (-0.002), you (-0.004), back (-0.005), me (-0.012)
#
# 8 911 / Mr. Lonely
# some (0.005), time (0.005), Find (0.002), I'm (0.002), la (0.002), out (0.002), nigga (0.002), a (0.002), okay (0.002), You (0.002), the (0.002), em (0.001), I (0.001), pothole (0.001), run (0.001), call (0.001), oh (0.001), do (0.001), Who (0.001), on (0.001)
# all (-0.001), Yeah (-0.001), Fuck (-0.001), love (-0.001), we (-0.001), ya (-0.001), take (-0.001), one (-0.001), ain't (-0.001), My (-0.001), my (-0.001), to (-0.001), you (-0.001), What (-0.001), if (-0.002), feel (-0.002), was (-0.002), How (-0.002), back (-0.004), me (-0.006)
#
# 9 November
# to (0.002), some (0.002), me (0.002), back (0.001), time (0.001), it (0.001), know (0.001), and (0.001), if (0.001), Find (0.001), a (0.001), was (0.001), la (0.001), call (0.001), November (0.001), nigga (0.001), I'm (0.001), out (0.001), is (0.001), take (0.000)
# around (-0.000), Cause (-0.000), never (-0.001), Boy (-0.001), Yeah (-0.001), on (-0.001), love (-0.001), life (-0.001), You're (-0.001), Fuck (-0.001), ya (-0.001), ain't (-0.001), like (-0.001), I (-0.001), one (-0.001), my (-0.001), that (-0.001), feel (-0.002), you (-0.002), How (-0.003)
#
# 10 Glitter
# youth (0.000), your (0.000), you're (0.000), you'll (0.000), you (0.000), yellin (0.000), year (0.000), yeah (0.000), ya'll (0.000), ya (0.000), y'all (0.000), wrote (0.000), write (0.000), wrist (0.000), would (0.000), worthwhile (0.000), worried (0.000), world (0.000), working (0.000), work (0.000)
# Actin (0.000), AP (0.000), AC (0.000), A (0.000), 95 (0.000), 911 (0.000), 80 (0.000), 8 (0.000), 7 (0.000), 60 (0.000), 5 (0.000), 43rd (0.000), 4 (0.000), 2015 (0.000), 2014 (0.000), 20 (0.000), 2 (0.000), 10 (0.000), 06 (0.000), 0 (0.000)
#
# 11 Enjoy Right Now, Today
# youth (0.000), your (0.000), you're (0.000), you'll (0.000), you (0.000), yellin (0.000), year (0.000), yeah (0.000), ya'll (0.000), ya (0.000), y'all (0.000), wrote (0.000), write (0.000), wrist (0.000), would (0.000), worthwhile (0.000), worried (0.000), world (0.000), working (0.000), work (0.000)
# Actin (0.000), AP (0.000), AC (0.000), A (0.000), 95 (0.000), 911 (0.000), 80 (0.000), 8 (0.000), 7 (0.000), 60 (0.000), 5 (0.000), 43rd (0.000), 4 (0.000), 2015 (0.000), 2014 (0.000), 20 (0.000), 2 (0.000), 10 (0.000), 06 (0.000), 0 (0.000)

# %%
songs[0]["Tokens"]
# Out:
# Counter({'For': 6,
#          'real': 14,
#          'for': 8,
#          'this': 4,
#          'time': 4,
#          'Bitch': 1,
#          'I': 12,
#          'cannot': 1,
#          'fall': 1,
#          'short': 1,
#          'Yeah': 2,
#          'yeah': 4,
#          'Cause': 7,
#          'you': 13,
#          'make': 9,
#          'my': 26,
#          'earth': 9,
#          'quake': 10,
#          'Oh': 4,
#          'Riding': 4,
#          'around': 4,
#          'your': 3,
#          'love': 5,
#          'be': 3,
#          'shakin': 3,
#          'me': 6,
#          'up': 6,
#          'And': 5,
#          "it's": 13,
#          'making': 4,
#          'heart': 4,
#          'break': 4,
#          'Earthquake': 1,
#          'ooh': 1,
#          "Don't": 8,
#          'leave': 9,
#          'fault': 9,
#          'Girl': 1,
#          'when': 2,
#          'it': 3,
#          'all': 2,
#          'comes': 2,
#          'crashing': 2,
#          'down': 2,
#          'll': 1,
#          'need': 5,
#          're': 1,
#          'telling': 1,
#          'something': 1,
#          'is': 1,
#          'bad': 1,
#          'oh': 1,
#          'Earth': 1,
#          's': 1,
#          'You': 3,
#          'already': 1,
#          'know': 2,
#          'We': 1,
#          "ain't": 1,
#          'gotta': 1,
#          'ball': 1,
#          'D': 1,
#          'Rose': 1,
#          'huh': 9,
#          "don't": 10,
#          'give': 1,
#          'a': 1,
#          'fuck': 2,
#          'bout': 1,
#          'none': 1,
#          'Beamin': 1,
#          'like': 2,
#          'lungs': 1,
#          'Just': 1,
#          'might': 1,
#          'call': 1,
#          'lawyer': 1,
#          'Plug': 1,
#          'gon': 1,
#          'set': 2,
#          'Bih': 1,
#          'Okay': 1,
#          "I'm": 2,
#          'with': 1,
#          'Tyler': 1,
#          'yuh': 2,
#          'Slime': 1,
#          'He': 1,
#          'ride': 1,
#          'the': 1,
#          'car': 1,
#          'she': 1,
#          'wicked': 1,
#          'Like': 2,
#          'Woah': 3,
#          'Vicky': 2,
#          'God': 1,
#          'hold': 1,
#          'um': 1,
#          'Diamonds': 1,
#          'not': 1,
#          'Tiffany': 1,
#          'woah': 1,
#          'So': 2,
#          'in': 2,
#          'Fault': 1,
#          'Ayy': 2,
#          "I'll": 1,
#          'ayy': 1,
#          'want': 6,
#          'no': 7,
#          'confrontation': 1,
#          'conversation': 2,
#          'just': 2,
#          'some': 1,
#          'confirmation': 1,
#          'on': 1,
#          'how': 1,
#          'feel': 1,
#          'complication': 1,
#          'side': 2,
#          'information': 2,
#          'to': 1,
#          "what's": 1,
#          'happening': 1,
#          'cause': 1,
#          'said': 2,
#          'One': 1,
#          'Two': 1,
#          'two': 1,
#          'girl': 1,
#          'Three': 1,
#          'three': 2,
#          'do-do-do-do-do': 1})

# %%
# song level or album level?

# %%
def cat_json(output_filename, input_filenames):
    with file(output_filename, "w") as outfile:
        first = True
        for infile_name in input_filenames:
            with file(infile_name) as infile:
                if first:
                    outfile.write('[')
                    first = False
                else:
                    outfile.write(',')
                outfile.write(mangle(infile.read()))
        outfile.write(']')

# %%
cat_json("complete_tyler.json",["Lyrics_Tyler,TheCreator{.Bastard.json","Lyrics_Tyler,TheCreator{.Cherry-Bomb"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-1283749c4aeb> in <module>
# ----> 1 cat_json("complete_tyler.json",["Lyrics_Tyler,TheCreator{.Bastard.json","Lyrics_Tyler,TheCreator{.Cherry-Bomb"])
#
# <ipython-input-46-760b670f79b1> in cat_json(output_filename, input_filenames)
#       1 def cat_json(output_filename, input_filenames):
# ----> 2     with file(output_filename, "w") as outfile:
#       3         first = True
#       4         for infile_name in input_filenames:
#       5             with file(infile_name) as infile:
#
# NameError: name 'file' is not defined

# %%
filenames = ["Lyrics_Tyler,TheCreator{.Bastard.json","Lyrics_Tyler,TheCreator{.Cherry-Bomb.json","Lyrics_Tyler,TheCreator{.Flower-Boy.json","Lyrics_Tyler,TheCreator{.Golbin.json","Lyrics_Tyler,TheCreator{.Wolf.json"]
with open('tyler_complete.json', 'w') as outfile:
    for fname in filenames:
        with open(fname) as infile:
            outfile.write(infile.read())

# %%
with open('tyler_complete.json') as json_file:
    data = json.loads(json.dumps([dict1, dict2]))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-60-45eade6696dc> in <module>
#       1 with open('tyler_complete.json') as json_file:
# ----> 2     data = json.load(json_file)
#
# /anaconda3/lib/python3.6/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     297         cls=cls, object_hook=object_hook,
#     298         parse_float=parse_float, parse_int=parse_int,
# --> 299         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#     300
#     301
#
# /anaconda3/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# /anaconda3/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     340         end = _w(s, end).end()
#     341         if end != len(s):
# --> 342             raise JSONDecodeError("Extra data", s, end)
#     343         return obj
#     344
#
# JSONDecodeError: Extra data: line 1 column 313258 (char 313257)

# %%
import glob

read_files = glob.glob("*.json")
with open("merged_file.json", "wb") as outfile:
    outfile.write('[{}]'.format(
        ','.join([open(f, "rb").read() for f in read_files])))
