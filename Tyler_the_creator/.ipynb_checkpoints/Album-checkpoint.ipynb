# %%
from collections import Counter
import math, glob, csv, re, numpy
from matplotlib import pyplot
import json
from collections import defaultdict

# %%
import jsonmerge
from json import loads
from json import dump

from jsonmerge import merge

# Store your json files here
# If all of them exist in directory, you can use os.listdir() instead
filenames = ["Lyrics_Tyler,TheCreator{.Bastard.json","Lyrics_Tyler,TheCreator{.Cherry-Bomb.json","Lyrics_Tyler,TheCreator{.Flower-Boy.json","Lyrics_Tyler,TheCreator{.Golbin.json","Lyrics_Tyler,TheCreator{.Wolf.json"]

with open('merged.json', 'w') as json_out:

    # Store updated results in this dict
    data = {}

    for file in filenames:
        print (file)
        with open(file, 'rb') as json_file:
            json_data = loads(json_file.read())

            # Update result dict with merged data
            data.update(merge(data, json_data))
    print (data)
    dump(data, json_out, indent=4)
# Out:
# Lyrics_Tyler,TheCreator{.Bastard.json
# Lyrics_Tyler,TheCreator{.Cherry-Bomb.json
# {'songs': [{'title': 'DEATHCAMP', 'album': 'Cherry Bomb', 'year': '2015-04-09', 'lyrics': 'Um, excuse me mister, but can you please turn down the lights?\nI don\'t really like all these cameras, man\nAnd this shit just don\'t feel right\nAnd I don\'t really wanna be rude to you, sir\nBut fuck you mean I can\'t wear my hat in here?\nAnd you got me fucked up, if you think I care, nigga\nI hope you little niggas is listening\nThem Golf Boys is in this bitch like an infant\nThe blind niggas used to make fun of my vision\nAnd now I pay a mortage and they stuck with tuition\nSo special, the teacher asked if I was autistic\nAnd now I\'m making plates, you just washing the dishes\nSo if you don\'t mind, get the fuck out of my kitchen\nBut keep your ego there so I can butt fuck your opinion\nBut in the meantime, brainwashing millions of minions\nLeader of the new school? (Ha, I\'m in my own school)\nAnd you would never catch me in none of their fucking shin-digs\nI hope you fucking niggas is angry, pissed, and offended\nIn Search Of... did more for me than Illmatic\nThat\'s when I realized we ain\'t cut from the same fabric\nI made my own shit, you went out and bought yours\nMan, I got too much drive, motherfucker, I hate traffic\nLa-di-da-di, I\'m going harder\nThan coming out the closet to conservative Christian fathers\nWhen it\'s a lot at stake carne asada let\'s be honest, I\'m really morphing\nNamed the album "Cherry Bomb" because "Greatest Hits" sounded boring\nI don\'t like to follow the rules\nShe said that I must, I don\'t have any armpits\nShe wanted to talk; "Who\'s in charge of this Golf shit?"\nI said "Howdy do? How are you? I\'m the sergeant\nAnd who I are isn\'t really important\nMy heart is as dark as a window with car tint\nSo hop in with your friends, gal and I\'ll unpark it\nAnd I\'ll do donuts until the fat one is carsick."\nIt\'s young T\n\nI don\'t like to follow the rules\nAnd that\'s just who I am\nI hope you understand\nAnd I don\'t really think y\'all cool\nSo give yourself a hand\nNo, no, give yourself a hand\nBetter pose for that camera\nBetter pose, boy you better pose\nAnd it\'s your life nigga I suppose\nFor the lights, for the camera, and the action\nNow your face is meltin\' from the flash of the big ol\' lights\nNigga you ask for this life\n\nWelcome to death camp\nYeah, welcome to death camp\nYeah, welcome to death camp\nKissing on my bean bag\nYour lips high-five my tongue\nAnd my fingers moonwalk through your hair\n(For the lights, and the camera, and the action)\nThis is fun I can tell\nI don\'t know if you\'ll handle it well\nWelcome to hell camp\n(Lights, and the camera, and the action)\nYou should be mine in a way tonight\n(For the lights, and the camera, and the action)', 'image': 'https://images.genius.com/d363c1a1794946fc7054c2d292e6abcf.640x640x1.jpg', 'artist': 'Tyler, The Creator', 'raw': {'annotation_count': 31, 'api_path': '/songs/745209', 'apple_music_id': '983056047', 'apple_music_player_url': 'https://genius.com/songs/745209/apple_music_player', 'description': {'dom': {'tag': 'root', 'children': [{'tag': 'p', 'children': ['“DEATHCAMP” is the first track off Tyler’s fourth album, ', {'tag': 'a', 'attributes': {'href': 'https://genius.com/albums/Tyler-the-creator/Cherry-bomb', 'rel': 'noopener'}, 'data': {'api_path': '/albums/122895'}, 'children': [{'tag': 'em', 'children': ['Cherry Bomb']}]}, ', that went up for pre-order unannounced on April 8, 2015.']}, '', {'tag': 'p', 'children': ['The song was also ', {'tag': 'a', 'attributes': {'href': 'https://youtu.be/SCcVrLcGD7k?t=284', 'rel': 'noopener nofollow'}, 'children': ['uploaded to YouTube']}, ', the first half of the video being for ', {'tag': 'a', 'attributes': {'href': 'https://genius.com/Tyler-the-creator-fucking-young-perfect-lyrics', 'rel': 'noopener'}, 'data': {'api_path': '/songs/745210'}, 'children': ['“FUCKING YOUNG”']}, ' and the latter for “DEATHCAMP”.']}, '', {'tag': 'p', 'children': ['Tyler sent out a series of tweets o ...

# %%
import json
complete=[]
filenames = ["Lyrics_Tyler,TheCreator{.Bastard.json","Lyrics_Tyler,TheCreator{.Cherry-Bomb.json","Lyrics_Tyler,TheCreator{.Flower-Boy.json","Lyrics_Tyler,TheCreator{.Golbin.json","Lyrics_Tyler,TheCreator{.Wolf.json","Lyrics_Tyler,TheCreator{.Igor.json"]
for file in filenames:
    with open(file) as json_file:
        data = json.load(json_file)
        complete.append(data)

# %%
len(complete)
# Out:
# 6

# %%
complete[1]["songs"][2]
# Out:
# {'title': 'PILOT',
#  'album': 'Cherry Bomb',
#  'year': '2015-04-13',
#  'lyrics': "Fly with the birds in the wind\nWhere you wanna go, who, what, why, when? Uh\nOn a scale of nine to ten\nYou taking L's baby, hold my hand and feel like the wind, uh\nNow fasten your seat belt, and turn everything off\nI got your attention, motherfucker, I'm bout to take off\nI'm the new pilot in this bitch\nAnd I ain't bring no extra baggage for this trip\nBut I do bring a terror like I hate America\nA brand new camera and a parachute\nNigga, you and I are not the same, we not parallel\nDon't talk to me 'fore I fucking embarrass you\nNow sit your ass down, you doing three much\nI'm the captain on this bitch, don't get it fucked up\nOr you'll get fucked up\n\n\nI'm so far ahead of you niggas, I'm in the future\nY'all don't even know about my existence, it's like I'm dead to you niggas\nI'm saying (I'm saying I'm dead to you niggas)\nLook, y'all be on the stupid shit\nI'm the fucking pilot, your role is to be the stewardess\nI'm the fucking bomb like I was stuffing my shoe with it\nThe boy's a fucking problem like turbulence boy, get used to it\nIf anything happens, it's one door\nIf I see a building, motherfucker, we're done for\nI'ma hit a couple of 'em up, this is parkour\nBetter call your family and give 'em your last wishes, nigga\nAnd every line dirty, you thought that I dug ditches\nBut I never give a fuck, it's like I was born dickless\nI don't wanna crash anymore, I don't wanna crash anymore\nI just wanna soar through the space, let the wind hit my face\nTill there's nothing left in the gas tank\nI don't wanna crash, I don't wanna crash anymore\nI don't wanna crash anymore\nI just wanna soar through the space, let the wind hit my face\nTill there's nothing left in the gas tank, I don't wanna crash\n(I don't wanna crash)\n\nI'm in first class but I feel like coach, yeah, uh\n(And it's okay if I fall, I just wanna fly)\nCause I'm in first class but I feel like coach, yeah, uh\n(The wind's getting high, I don't wanna crash)\nCause I'm in first class but I feel like coach, yeah, uh\n(And it's okay if I fall, I just wanna fly)\nIt's kinda weird\n(The wind is getting high)\nCause I'm in first class but I feel like coach, look (Say what?)\n(Oh, yeah, yeah)\n\nI'm tryna find a place, a place where I can land at\nA place where I can be with no alphabet\nDictating where to stand at\nYou can buy a car, you can buy many things\nYou can buy happiness, but you can't buy wings\nYou can buy a parachute, you can buy a parrot\nBut you can't buy a pair of wings, aerodynamic\nTo stay cloud level\nThat's why I'm in first class but I feel like coach (Fucked up)\nCause I'm in first class but I feel like coach\nIt's just crazy how you can have everything in the world, but\nYou in first class but you feel like coach, damn\nThat's why I'm in first class, but I feel like coach\n\nI don't wanna—",
#  'image': 'https://images.genius.com/bc37e364cd39806bba7469442454fc50.640x640x1.jpg',
#  'artist': 'Tyler, The Creator',
#  'raw': {'annotation_count': 17,
#   'api_path': '/songs/748256',
#   'apple_music_id': '983056051',
#   'apple_music_player_url': 'https://genius.com/songs/748256/apple_music_player',
#   'description': {'dom': {'tag': 'root',
#     'children': [{'tag': 'p',
#       'children': ['Following “Buffalo”, where Tyler realized how big of an influence he is and how much power he has, he now decides its time for him to try to reach his full potential. Much like Odd Future label-mate Earl Sweatshirt, he has taken a change of stance: He no longer wants to to mess around, and live life recklessly with no true purpose (aka crash) and instead find his own path (Find his wings, aka. find his happiness) and fly until he no longer can. He is going to live life to the fullest capacity of goodness, happiness and fun. A similar desire to fly is found all throughout african american literature from “Song Of Solomon” to “Black Boy Fly” by Kendrick Lamar.']},
#      '',
#      {'tag': 'p',
#       'children': [{'tag': 'a',
#         'attributes': {'href': 'https://twitter.com/fucktyler/status/587662368638771201',
#          'rel': 'noopener nofollow'},
#         'children': ['https://twitter.com/fucktyler/status/587662368638771201']}]}]}},
#   'embed_content': "<div id='rg_embed_link_748256' class='rg_embed_link' data-song-id='748256'>Read <a href='https://genius.com/Tyler-the-creator-pilot-lyrics'>“PILOT” by Tyler,\xa0The Creator</a> on Genius</div> <script crossorigin src='//genius.com/songs/748256/embed.js'></script>",
#   'featured_video': False,
#   'full_title': 'PILOT by\xa0Tyler,\xa0The Creator (Ft.\xa0Syd)',
#   'header_image_thumbnail_url': 'https://images.genius.com/bc37e364cd39806bba7469442454fc50.300x300x1.jpg',
#   'header_image_url': 'https://images.genius.com/bc37e364cd39806bba7469442454fc50.640x640x1.jpg',
#   'id': 748256,
#   'lyrics_owner_id': 88410,
#   'lyrics_state': 'complete',
#   'path': '/Tyler-the-creator-pilot-lyrics',
#   'pyongs_count': 43,
#   'recording_location': None,
#   'release_date': '2015-04-13',
#   'song_art_image_thumbnail_url': 'https://images.genius.com/bc37e364cd39806bba7469442454fc50.300x300x1.jpg',
#   'song_art_image_url': 'https://images.genius.com/bc37e364cd39806bba7469442454fc50.640x640x1.jpg',
#   'stats': {'accepted_annotations': 16,
#    'contributors': 70,
#    'iq_earners': 67,
#    'transcribers': 6,
#    'unreviewed_annotations': 0,
#    'verified_annotations': 0,
#    'hot': False,
#    'pageviews': 87709},
#   'title': 'PILOT',
#   'title_with_featured': 'PILOT (Ft.\xa0Syd)',
#   'url': 'https://genius.com/Tyler-the-creator-pilot-lyrics',
#   'current_user_metadata': {'permissions': ['see_pageviews',
#     'view_apple_music_player',
#     'create_comment',
#     'view_song_story_gallery'],
#    'excluded_permissions': ['follow',
#     'award_transcription_iq',
#     'remove_transcription_iq',
#     'pyong',
#     'edit_lyrics',
#     'view_annotation_engagement_data',
#     'publish',
#     'unpublish',
#     'edit_spotify_details',
#     'hide',
#     'unhide',
#     'toggle_featured_video',
#     'add_pinned_annotation_to',
#     'add_community_annotation_to',
#     'destroy',
#     'mark_as_not_spam',
#     'edit_spotify_annotations_for',
#     'verify_lyrics',
#     'unverify_lyrics',
#     'edit_anything',
#     'edit_any_media',
#     'edit',
#     'rename',
#     'edit_tags',
#     'watch_fact_track',
#     'reindex',
#     'view_lyrics_synchronization',
#     'enable_media',
#     'disable_media',
#     'edit_lyrics_or_annotation_brackets',
#     'see_editorial_indicators',
#     'view_attribution_visualization',
#     'edit_annotation_brackets',
#     'preview_lyrics_for_export',
#     'hide_apple_player',
#     'unhide_apple_player',
#     'trigger_apple_match',
#     'mark_lyrics_evaluation_as_approved',
#     'mark_lyrics_evaluation_as_staff_approved',
#     'mark_lyrics_evaluation_as_unapproved',
#     'mark_lyrics_evaluation_as_un_staff_approved',
#     'view_transcriber_media_player',
#     'override_apple_match',
#     'edit_youtube_url',
#     'edit_soundcloud_url',
#     'edit_spotify_uuid',
#     'edit_vevo_url',
#     'moderate_annotations',
#     'create_annotation',
#     'see_short_id',
#     'manage_chart_item',
#     'create_tag',
#     'propose_lyrics_edit',
#     'moderate_lyrics_edit_proposals'],
#    'interactions': {'pyong': False, 'following': False},
#    'relationships': {},
#    'iq_by_action': {}},
#   'album': {'api_path': '/albums/122895',
#    'cover_art_url': 'https://images.genius.com/bc37e364cd39806bba7469442454fc50.640x640x1.jpg',
#    'full_title': 'Cherry Bomb by Tyler, The Creator',
#    'id': 122895,
#    'name': 'Cherry Bomb',
#    'url': 'https://genius.com/albums/Tyler-the-creator/Cherry-bomb',
#    'artist': {'api_path': '/artists/685',
#     'header_image_url': 'https://images.genius.com/a0ec7b3736347c0b0d8aee13424c2a73.1000x760x1.jpg',
#     'id': 685,
#     'image_url': 'https://images.genius.com/610384882ca6311db99de4fbfcdf2b46.421x421x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Tyler, The Creator',
#     'url': 'https://genius.com/artists/Tyler-the-creator'}},
#   'custom_performances': [{'label': 'Recording Engineer',
#     'artists': [{'api_path': '/artists/636046',
#       'header_image_url': 'https://assets.genius.com/images/default_avatar_300.png?1571931191',
#       'id': 636046,
#       'image_url': 'https://assets.genius.com/images/default_avatar_300.png?1571931191',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Vic Wainstein',
#       'url': 'https://genius.com/artists/Vic-wainstein'},
#      {'api_path': '/artists/685',
#       'header_image_url': 'https://images.genius.com/a0ec7b3736347c0b0d8aee13424c2a73.1000x760x1.jpg',
#       'id': 685,
#       'image_url': 'https://images.genius.com/610384882ca6311db99de4fbfcdf2b46.421x421x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Tyler, The Creator',
#       'url': 'https://genius.com/artists/Tyler-the-creator'},
#      {'api_path': '/artists/12935',
#       'header_image_url': 'https://images.genius.com/4976f59572f9b4a7f71d57bda5c071d0.1000x333x1.jpg',
#       'id': 12935,
#       'image_url': 'https://images.genius.com/23f2759ac10a473cacd24fbe00c72573.1000x1000x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': True,
#       'name': 'Syd',
#       'url': 'https://genius.com/artists/Syd',
#       'iq': 1707}]},
#    {'label': 'Released by',
#     'artists': [{'api_path': '/artists/995710',
#       'header_image_url': 'https://images.genius.com/fa1d4832844bca9ed745543d08399248.577x577x1.jpg',
#       'id': 995710,
#       'image_url': 'https://images.genius.com/fa1d4832844bca9ed745543d08399248.577x577x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'RED Distribution',
#       'url': 'https://genius.com/artists/Red-distribution'},
#      {'api_path': '/artists/1047192',
#       'header_image_url': 'https://images.genius.com/29141860319cf26b608d1b15f745ca75.1000x1000x1.jpg',
#       'id': 1047192,
#       'image_url': 'https://images.genius.com/29141860319cf26b608d1b15f745ca75.1000x1000x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Odd Future Records',
#       'url': 'https://genius.com/artists/Odd-future-records'}]},
#    {'label': 'Mastering Engineer',
#     'artists': [{'api_path': '/artists/637914',
#       'header_image_url': 'https://images.genius.com/14b89e85011c34e3a891ba144862d6db.300x214x1.jpg',
#       'id': 637914,
#       'image_url': 'https://images.genius.com/edeef8fedbd6d77ce67179af9e7549a2.172x172x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': '“Big Bass” Brian Gardner',
#       'url': 'https://genius.com/artists/Big-bass-brian-gardner'}]},
#    {'label': 'Mixing Engineer',
#     'artists': [{'api_path': '/artists/645042',
#       'header_image_url': 'https://assets.genius.com/images/default_avatar_300.png?1571931191',
#       'id': 645042,
#       'image_url': 'https://assets.genius.com/images/default_avatar_300.png?1571931191',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Mick Guzauski',
#       'url': 'https://genius.com/artists/Mick-guzauski'}]},
#    {'label': 'Additional Vocals',
#     'artists': [{'api_path': '/artists/12935',
#       'header_image_url': 'https://images.genius.com/4976f59572f9b4a7f71d57bda5c071d0.1000x333x1.jpg',
#       'id': 12935,
#       'image_url': 'https://images.genius.com/23f2759ac10a473cacd24fbe00c72573.1000x1000x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': True,
#       'name': 'Syd',
#       'url': 'https://genius.com/artists/Syd',
#       'iq': 1707}]},
#    {'label': 'Vocals',
#     'artists': [{'api_path': '/artists/685',
#       'header_image_url': 'https://images.genius.com/a0ec7b3736347c0b0d8aee13424c2a73.1000x760x1.jpg',
#       'id': 685,
#       'image_url': 'https://images.genius.com/610384882ca6311db99de4fbfcdf2b46.421x421x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Tyler, The Creator',
#       'url': 'https://genius.com/artists/Tyler-the-creator'}]}],
#   'description_annotation': {'_type': 'referent',
#    'annotator_id': 1337140,
#    'annotator_login': 'vikkivik11',
#    'api_path': '/referents/5205642',
#    'classification': 'accepted',
#    'fragment': 'PILOT',
#    'id': 5205642,
#    'is_description': True,
#    'path': '/5205642/Tyler-the-creator-pilot/Pilot',
#    'range': {'content': 'PILOT'},
#    'song_id': 748256,
#    'url': 'https://genius.com/5205642/Tyler-the-creator-pilot/Pilot',
#    'verified_annotator_ids': [],
#    'annotatable': {'api_path': '/songs/748256',
#     'client_timestamps': {'updated_by_human_at': 1567966749,
#      'lyrics_updated_at': 1560900782},
#     'context': 'Tyler, The Creator',
#     'id': 748256,
#     'image_url': 'https://images.genius.com/bc37e364cd39806bba7469442454fc50.640x640x1.jpg',
#     'link_title': 'PILOT by\xa0Tyler,\xa0The Creator (Ft.\xa0Syd)',
#     'title': 'PILOT',
#     'type': 'Song',
#     'url': 'https://genius.com/Tyler-the-creator-pilot-lyrics'},
#    'annotations': [{'api_path': '/annotations/5205642',
#      'body': {'dom': {'tag': 'root',
#        'children': [{'tag': 'p',
#          'children': ['Following “Buffalo”, where Tyler realized how big of an influence he is and how much power he has, he now decides its time for him to try to reach his full potential. Much like Odd Future label-mate Earl Sweatshirt, he has taken a change of stance: He no longer wants to to mess around, and live life recklessly with no true purpose (aka crash) and instead find his own path (Find his wings, aka. find his happiness) and fly until he no longer can. He is going to live life to the fullest capacity of goodness, happiness and fun. A similar desire to fly is found all throughout african american literature from “Song Of Solomon” to “Black Boy Fly” by Kendrick Lamar.']},
#         '',
#         {'tag': 'p',
#          'children': [{'tag': 'a',
#            'attributes': {'href': 'https://twitter.com/fucktyler/status/587662368638771201',
#             'rel': 'noopener nofollow'},
#            'children': ['https://twitter.com/fucktyler/status/587662368638771201']}]}]}},
#      'comment_count': 2,
#      'community': True,
#      'custom_preview': None,
#      'has_voters': True,
#      'id': 5205642,
#      'pinned': False,
#      'share_url': 'https://genius.com/5205642',
#      'source': None,
#      'state': 'accepted',
#      'url': 'https://genius.com/5205642/Tyler-the-creator-pilot/Pilot',
#      'verified': False,
#      'votes_total': 50,
#      'current_user_metadata': {'permissions': ['create_comment'],
#       'excluded_permissions': ['vote',
#        'edit',
#        'cosign',
#        'uncosign',
#        'destroy',
#        'accept',
#        'reject',
#        'see_unreviewed',
#        'clear_votes',
#        'propose_edit_to',
#        'pin_to_profile',
#        'unpin_from_profile',
#        'update_source',
#        'edit_custom_preview'],
#       'interactions': {'cosign': False, 'pyong': False, 'vote': None},
#       'iq_by_action': {}},
#      'authors': [{'attribution': 0.6776315789473684,
#        'pinned_role': None,
#        'user': {'api_path': '/users/1066690',
#         'avatar': {'tiny': {'url': 'https://assets.genius.com/images/default_avatar_16.png?1571931191',
#           'bounding_box': {'width': 16, 'height': 16}},
#          'thumb': {'url': 'https://assets.genius.com/images/default_avatar_32.png?1571931191',
#           'bounding_box': {'width': 32, 'height': 32}},
#          'small': {'url': 'https://assets.genius.com/images/default_avatar_100.png?1571931191',
#           'bounding_box': {'width': 100, 'height': 100}},
#          'medium': {'url': 'https://assets.genius.com/images/default_avatar_300.png?1571931191',
#           'bounding_box': {'width': 300, 'height': 400}}},
#         'header_image_url': 'https://assets.genius.com/images/default_avatar_300.png?1571931191',
#         'human_readable_role_for_display': 'Contributor',
#         'id': 1066690,
#         'iq': 2555,
#         'login': 'Ryehauge16',
#         'name': 'Ryehauge16',
#         'role_for_display': 'contributor',
#         'url': 'https://genius.com/Ryehauge16',
#         'current_user_metadata': {'permissions': [],
#          'excluded_permissions': ['follow'],
#          'interactions': {'following': False}}}},
#       {'attribution': 0.3223684210526316,
#        'pinned_role': None,
#        'user': {'api_path': '/users/98861',
#         'avatar': {'tiny': {'url': 'https://images.rapgenius.com/avatars/tiny/ff521a6afcdd88a85d1013134b4d6a99',
#           'bounding_box': {'width': 16, 'height': 16}},
#          'thumb': {'url': 'https://images.rapgenius.com/avatars/thumb/ff521a6afcdd88a85d1013134b4d6a99',
#           'bounding_box': {'width': 32, 'height': 32}},
#          'small': {'url': 'https://images.rapgenius.com/avatars/small/ff521a6afcdd88a85d1013134b4d6a99',
#           'bounding_box': {'width': 100, 'height': 100}},
#          'medium': {'url': 'https://images.rapgenius.com/avatars/medium/ff521a6afcdd88a85d1013134b4d6a99',
#           'bounding_box': {'width': 300, 'height': 400}}},
#         'header_image_url': 'https://images.rapgenius.com/avatars/medium/ff521a6afcdd88a85d1013134b4d6a99',
#         'human_readable_role_for_display': 'Contributor',
#         'id': 98861,
#         'iq': 7268,
#         'login': 'NicRaps',
#         'name': 'NicRaps',
#         'role_for_display': 'contributor',
#         'url': 'https://genius.com/NicRaps',
#         'current_user_metadata': {'permissions': [],
#          'excluded_permissions': ['follow'],
#          'interactions': {'following': False}}}}],
#      'cosigned_by': [],
#      'rejection_comment': None,
#      'verified_by': None}]},
#   'featured_artists': [{'api_path': '/artists/12935',
#     'header_image_url': 'https://images.genius.com/4976f59572f9b4a7f71d57bda5c071d0.1000x333x1.jpg',
#     'id': 12935,
#     'image_url': 'https://images.genius.com/23f2759ac10a473cacd24fbe00c72573.1000x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': True,
#     'name': 'Syd',
#     'url': 'https://genius.com/artists/Syd',
#     'iq': 1707}],
#   'lyrics_marked_complete_by': None,
#   'media': [{'native_uri': 'spotify:track:332Yig3HD2IdDigzlf5Ndl',
#     'provider': 'spotify',
#     'type': 'audio',
#     'url': 'https://open.spotify.com/track/332Yig3HD2IdDigzlf5Ndl'},
#    {'attribution': 'tylerthecreatorofficial',
#     'provider': 'soundcloud',
#     'type': 'audio',
#     'url': 'https://soundcloud.com/tylerthecreatorofficial/pilot?in=tylerthecreatorofficial/sets/cherry-bomb-5'},
#    {'provider': 'youtube',
#     'start': 0,
#     'type': 'video',
#     'url': 'http://www.youtube.com/watch?v=Z_QfmPZNlhw'}],
#   'primary_artist': {'api_path': '/artists/685',
#    'header_image_url': 'https://images.genius.com/a0ec7b3736347c0b0d8aee13424c2a73.1000x760x1.jpg',
#    'id': 685,
#    'image_url': 'https://images.genius.com/610384882ca6311db99de4fbfcdf2b46.421x421x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': 'Tyler, The Creator',
#    'url': 'https://genius.com/artists/Tyler-the-creator'},
#   'producer_artists': [{'api_path': '/artists/685',
#     'header_image_url': 'https://images.genius.com/a0ec7b3736347c0b0d8aee13424c2a73.1000x760x1.jpg',
#     'id': 685,
#     'image_url': 'https://images.genius.com/610384882ca6311db99de4fbfcdf2b46.421x421x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Tyler, The Creator',
#     'url': 'https://genius.com/artists/Tyler-the-creator'}],
#   'song_relationships': [{'type': 'samples', 'songs': []},
#    {'type': 'sampled_in', 'songs': []},
#    {'type': 'interpolates', 'songs': []},
#    {'type': 'interpolated_by', 'songs': []},
#    {'type': 'cover_of', 'songs': []},
#    {'type': 'covered_by', 'songs': []},
#    {'type': 'remix_of', 'songs': []},
#    {'type': 'remixed_by', 'songs': []},
#    {'type': 'live_version_of', 'songs': []},
#    {'type': 'performed_live_as', 'songs': []}],
#   'verified_annotations_by': [],
#   'verified_contributors': [],
#   'verified_lyrics_by': [],
#   'writer_artists': [{'api_path': '/artists/685',
#     'header_image_url': 'https://images.genius.com/a0ec7b3736347c0b0d8aee13424c2a73.1000x760x1.jpg',
#     'id': 685,
#     'image_url': 'https://images.genius.com/610384882ca6311db99de4fbfcdf2b46.421x421x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Tyler, The Creator',
#     'url': 'https://genius.com/artists/Tyler-the-creator'}],
#   'lyrics': "Fly with the birds in the wind\nWhere you wanna go, who, what, why, when? Uh\nOn a scale of nine to ten\nYou taking L's baby, hold my hand and feel like the wind, uh\nNow fasten your seat belt, and turn everything off\nI got your attention, motherfucker, I'm bout to take off\nI'm the new pilot in this bitch\nAnd I ain't bring no extra baggage for this trip\nBut I do bring a terror like I hate America\nA brand new camera and a parachute\nNigga, you and I are not the same, we not parallel\nDon't talk to me 'fore I fucking embarrass you\nNow sit your ass down, you doing three much\nI'm the captain on this bitch, don't get it fucked up\nOr you'll get fucked up\n\n\nI'm so far ahead of you niggas, I'm in the future\nY'all don't even know about my existence, it's like I'm dead to you niggas\nI'm saying (I'm saying I'm dead to you niggas)\nLook, y'all be on the stupid shit\nI'm the fucking pilot, your role is to be the stewardess\nI'm the fucking bomb like I was stuffing my shoe with it\nThe boy's a fucking problem like turbulence boy, get used to it\nIf anything happens, it's one door\nIf I see a building, motherfucker, we're done for\nI'ma hit a couple of 'em up, this is parkour\nBetter call your family and give 'em your last wishes, nigga\nAnd every line dirty, you thought that I dug ditches\nBut I never give a fuck, it's like I was born dickless\nI don't wanna crash anymore, I don't wanna crash anymore\nI just wanna soar through the space, let the wind hit my face\nTill there's nothing left in the gas tank\nI don't wanna crash, I don't wanna crash anymore\nI don't wanna crash anymore\nI just wanna soar through the space, let the wind hit my face\nTill there's nothing left in the gas tank, I don't wanna crash\n(I don't wanna crash)\n\nI'm in first class but I feel like coach, yeah, uh\n(And it's okay if I fall, I just wanna fly)\nCause I'm in first class but I feel like coach, yeah, uh\n(The wind's getting high, I don't wanna crash)\nCause I'm in first class but I feel like coach, yeah, uh\n(And it's okay if I fall, I just wanna fly)\nIt's kinda weird\n(The wind is getting high)\nCause I'm in first class but I feel like coach, look (Say what?)\n(Oh, yeah, yeah)\n\nI'm tryna find a place, a place where I can land at\nA place where I can be with no alphabet\nDictating where to stand at\nYou can buy a car, you can buy many things\nYou can buy happiness, but you can't buy wings\nYou can buy a parachute, you can buy a parrot\nBut you can't buy a pair of wings, aerodynamic\nTo stay cloud level\nThat's why I'm in first class but I feel like coach (Fucked up)\nCause I'm in first class but I feel like coach\nIt's just crazy how you can have everything in the world, but\nYou in first class but you feel like coach, damn\nThat's why I'm in first class, but I feel like coach\n\nI don't wanna—"},
#  'Tokens': Counter({'Yo': 8,
#           'fuck': 72,
#           '2DopeBoyz': 2,
#           'and': 130,
#           'Nah': 3,
#           'Right': 2,
#           'And': 75,
#           'any': 4,
#           'other': 5,
#           'fuck-nigga-ass': 1,
#           'blog': 2,
#           'that': 78,
#           "can't": 19,
#           'put': 8,
#           'an': 13,
#           '18': 2,
#           'year': 2,
#           'old': 7,
#           'nigga': 41,
#           'Making': 2,
#           'his': 8,
#           'own': 6,
#           'fucking': 96,
#           'beats': 2,
#           'covers': 1,
#           'videos': 1,
#           'all': 26,
#           'shit': 54,
#           'Fuck': 29,
#           'you': 191,
#           'post-Drake-ass': 1,
#           'cliche-jerking': 1,
#           'LA-slauson': 1,
#           'rapping': 1,
#           'Fuck-nigga-ass': 1,
#           'Hypebeast': 1,
#           'niggas': 40,
#           'now': 17,
#           'back': 11,
#           'to': 176,
#           'the': 326,
#           'album': 4,
#           'Well': 11,
#           'Tyler': 14,
#           'hi': 1,
#           "I'm": 198,
#           'Dr': 2,
#           'TC': 2,
#           'um': 3,
#           'guessing': 2,
#           'your': 80,
#           'teacher': 3,
#           'sent': 1,
#           'here': 8,
#           'talk': 8,
#           'cause': 10,
#           'were': 3,
#           'misbehaving': 1,
#           'Um': 6,
#           "it's": 34,
#           'gonna': 1,
#           'be': 35,
#           'three': 3,
#           'sessions': 2,
#           'today': 4,
#           'tomorrow': 1,
#           'next': 8,
#           'day': 10,
#           'So': 20,
#           'just': 37,
#           'tell': 16,
#           'me': 83,
#           'something': 9,
#           'about': 22,
#           'yourself': 3,
#           'look': 11,
#           'if': 24,
#           "don't": 63,
#           'I': 338,
#           'mean': 6,
#           'these': 9,
#           'are': 11,
#           'going': 4,
#           'go': 21,
#           'slower': 1,
#           'This': 15,
#           'is': 100,
#           'what': 20,
#           'devil': 2,
#           'plays': 1,
#           'before': 2,
#           'he': 7,
#           'goes': 2,
#           'sleep': 7,
#           'Some': 1,
#           'food': 4,
#           'for': 46,
#           'thought': 3,
#           'death': 5,
#           'ahead': 3,
#           'eat': 9,
#           'My': 29,
#           "father's": 3,
#           'dead': 9,
#           'well': 4,
#           'know': 26,
#           "we'll": 1,
#           'never': 26,
#           'meet': 3,
#           'cut': 3,
#           'my': 207,
#           'wrist': 2,
#           'play': 10,
#           'piano': 1,
#           'so': 46,
#           'depressed': 2,
#           'Somebody': 1,
#           'call': 10,
#           'pastor': 1,
#           'this': 58,
#           'bastard': 6,
#           'possessed': 1,
#           'meeting': 1,
#           'begun': 1,
#           "Satan's": 1,
#           'son': 3,
#           'mother': 4,
#           'raised': 1,
#           'a': 224,
#           'single': 1,
#           'parent': 2,
#           'apparent': 2,
#           'That': 12,
#           'got': 32,
#           'love': 10,
#           'none': 6,
#           'of': 71,
#           'fuckers': 1,
#           'Are': 1,
#           'much': 8,
#           'important': 2,
#           'getting': 10,
#           'angrier': 1,
#           'while': 5,
#           'recording': 1,
#           'feeling': 2,
#           'like': 125,
#           'bulls': 1,
#           "I've": 2,
#           'gang': 2,
#           'wolves': 2,
#           'Odd': 18,
#           'Future': 16,
#           'children': 2,
#           "that's": 15,
#           'fucked': 9,
#           'up': 65,
#           'in': 140,
#           'they': 34,
#           'mental': 3,
#           'Simple': 1,
#           'but': 40,
#           'probably': 10,
#           'not': 34,
#           'them': 17,
#           'tall': 2,
#           'dark': 3,
#           'skinny': 4,
#           'ears': 2,
#           'big': 8,
#           'as': 16,
#           'Drunk': 1,
#           'white': 11,
#           'girls': 6,
#           'only': 15,
#           'way': 10,
#           "I'll": 16,
#           'get': 41,
#           'dick': 13,
#           'sucked': 1,
#           'Suspended': 1,
#           'from': 26,
#           'school': 7,
#           'coolest': 1,
#           'without': 6,
#           'effort': 1,
#           'Easy': 1,
#           'spot': 2,
#           'black': 8,
#           'bitches': 12,
#           'with': 81,
#           'fake': 1,
#           'leopard': 1,
#           'Soak': 1,
#           'tampon': 1,
#           'keep': 6,
#           'lamp': 1,
#           'on': 54,
#           'Cause': 23,
#           'pack': 2,
#           'enough': 5,
#           'evil': 4,
#           'fit': 2,
#           'inside': 4,
#           'Jansport': 1,
#           'AP': 2,
#           'JC': 1,
#           'week': 1,
#           'Waking': 1,
#           'random': 1,
#           'bitch': 41,
#           'how': 13,
#           'we': 23,
#           'stay': 6,
#           'grandma': 1,
#           'she': 22,
#           'always': 10,
#           'bitching': 1,
#           'her': 44,
#           'carpet': 1,
#           'Every': 1,
#           'time': 12,
#           'walk': 4,
#           'house': 10,
#           'tend': 1,
#           'start': 4,
#           'No': 13,
#           'drugs': 2,
#           'spark': 1,
#           'it': 79,
#           'used': 5,
#           'bullied': 1,
#           'honor': 2,
#           'classes': 1,
#           'By': 1,
#           'those': 3,
#           'slow': 4,
#           'molasses': 1,
#           'take': 10,
#           'Raquel': 2,
#           'treat': 1,
#           'father': 11,
#           'stranger': 1,
#           'She': 10,
#           'still': 4,
#           'made': 6,
#           'Sarah': 4,
#           'strangle': 1,
#           'Not': 3,
#           'danger': 1,
#           'chop': 2,
#           'Wrangler': 1,
#           'All': 3,
#           'because': 5,
#           'said': 12,
#           'no': 34,
#           'homecoming': 2,
#           'demons': 1,
#           'running': 1,
#           'Inside': 2,
#           'heads': 1,
#           'telling': 1,
#           'thoughts': 4,
#           'dream': 4,
#           'catcher': 1,
#           'nothing': 4,
#           'nightmares': 1,
#           'caught': 1,
#           'wear': 6,
#           'green': 3,
#           'hats': 1,
#           'fortunately': 1,
#           'lucky': 1,
#           'monster': 3,
#           'somehow': 1,
#           "monster's": 1,
#           'tells': 1,
#           'With': 14,
#           'state': 3,
#           'mind': 6,
#           'moves': 3,
#           'Max': 1,
#           'Keeble': 1,
#           'grind': 2,
#           'feeble': 2,
#           'music': 4,
#           'either': 2,
#           'A': 7,
#           'sin': 2,
#           'or': 8,
#           'too': 4,
#           'illegal': 2,
#           'church': 2,
#           'graduated': 3,
#           'honors': 1,
#           'He': 8,
#           'died': 2,
#           'sorry': 12,
#           'even': 4,
#           'bother': 2,
#           'wanted': 3,
#           'brother': 3,
#           'told': 5,
#           'But': 29,
#           'instead': 1,
#           'sister': 6,
#           'mister': 3,
#           'nada': 1,
#           'both': 3,
#           'our': 8,
#           'imaginations': 1,
#           'creations': 1,
#           'situation': 1,
#           "That's": 7,
#           'having': 3,
#           'brains': 2,
#           'racing': 1,
#           'Dayton': 1,
#           'wearing': 3,
#           'some': 31,
#           'Heelys': 1,
#           'feel': 26,
#           'want': 28,
#           'kill': 5,
#           'times': 1,
#           'serious': 3,
#           'think': 11,
#           'silly': 2,
#           'doing': 5,
#           'Big': 1,
#           'Style': 1,
#           'Willy': 2,
#           "couldn't": 1,
#           'touch': 2,
#           '11': 1,
#           'Seven': 1,
#           "what's": 1,
#           'religion': 1,
#           'am': 6,
#           'legend': 2,
#           'roll': 2,
#           'skaters': 1,
#           'musicians': 1,
#           'intuition': 1,
#           'created': 1,
#           'O': 10,
#           'F': 9,
#           "we're": 3,
#           'more': 5,
#           'talented': 1,
#           'Than': 2,
#           '40': 1,
#           'rappers': 1,
#           'talking': 3,
#           'Gucci': 5,
#           'When': 6,
#           'have': 17,
#           'kids': 12,
#           "haven't": 1,
#           'seen': 6,
#           'years': 5,
#           'impressing': 1,
#           'their': 8,
#           'peers': 1,
#           'same': 5,
#           'problem': 3,
#           'solve': 1,
#           'Is': 2,
#           "Father's": 2,
#           'Day': 2,
#           'convention': 1,
#           'gold': 18,
#           'revolver': 1,
#           "Life's": 1,
#           'salad': 2,
#           'toss': 1,
#           'Rick': 1,
#           'Ross': 1,
#           'Shit': 4,
#           'out': 24,
#           'bag': 3,
#           'sell': 3,
#           'damn': 3,
#           'rebellious': 1,
#           'let': 14,
#           'do': 16,
#           "wasn't": 3,
#           'careless': 1,
#           'protective': 1,
#           'bear': 2,
#           'The': 34,
#           'bare': 1,
#           'diary': 1,
#           "isn't": 3,
#           'hid': 1,
#           "didn't": 9,
#           'give': 22,
#           'inherit': 1,
#           'mom': 5,
#           'parents': 1,
#           'Danielle': 3,
#           'Milan': 3,
#           'decide': 1,
#           'share': 1,
#           'confused': 2,
#           'boy': 10,
#           'wanna': 23,
#           'hug': 1,
#           'hoy': 1,
#           'm': 1,
#           'bad': 5,
#           'listen': 3,
#           'Soy': 1,
#           'choice': 1,
#           'milk': 1,
#           'drink': 3,
#           'Whoa': 2,
#           'umm': 2,
#           'seems': 1,
#           'had': 5,
#           'lot': 4,
#           'say': 12,
#           'Uh': 8,
#           'who': 9,
#           'knows': 1,
#           'might': 1,
#           'evaluating': 1,
#           'red': 5,
#           'cutter': 1,
#           'Dripping': 1,
#           'cold': 4,
#           'blood': 2,
#           'winter': 1,
#           'summer': 2,
#           'equivalent': 2,
#           'name': 4,
#           'clever': 1,
#           'kissing': 1,
#           'sitting': 3,
#           'downing': 1,
#           'beers': 1,
#           'simply': 1,
#           'wishing': 2,
#           'tear': 1,
#           'try': 4,
#           'down': 14,
#           'pissing': 1,
#           'Eighteen': 2,
#           'imaginaries': 1,
#           'Hopefully': 1,
#           'see': 13,
#           'talent': 1,
#           'carry': 1,
#           'Jimmy': 1,
#           'Losers': 1,
#           'can': 50,
#           'win': 3,
#           'offend': 2,
#           'goal': 1,
#           'life': 10,
#           'Grammy': 1,
#           'hopefully': 1,
#           'momma': 3,
#           'will': 4,
#           'attend': 1,
#           'Ceremony': 1,
#           'homies': 2,
#           'suicidal': 1,
#           'Zombie': 1,
#           'Circus': 1,
#           'hope': 5,
#           'majors': 1,
#           'heard': 2,
#           'deal': 1,
#           'email': 1,
#           'him': 8,
#           'hate': 5,
#           'detail': 1,
#           'Wow': 2,
#           'chance': 3,
#           'What': 6,
#           'would': 11,
#           "I'd": 1,
#           'quicker': 1,
#           'than': 9,
#           'Mexicans': 1,
#           'sprint': 1,
#           'over': 9,
#           'borders': 1,
#           'quarter': 1,
#           '20': 1,
#           'cent': 1,
#           'At': 2,
#           'Hamptons': 2,
#           'Fred': 1,
#           'Hampton': 1,
#           'relaxing': 2,
#           'at': 27,
#           'Happy': 1,
#           'Camper': 1,
#           "It's": 18,
#           'financial': 1,
#           'aid': 1,
#           'taxing': 1,
#           'em': 6,
#           's': 3,
#           'chanting': 1,
#           "Don't": 7,
#           'complain': 1,
#           'ranting': 1,
#           'ranking': 1,
#           'best': 2,
#           "champion's": 1,
#           'chariot': 1,
#           'liar': 1,
#           'Carrey': 2,
#           'Liar': 2,
#           'dirtier': 1,
#           'sheets': 1,
#           'Marriott': 1,
#           'Cable': 1,
#           'guy': 3,
#           'Larry': 1,
#           'Peter': 2,
#           'Pan': 1,
#           'youth': 2,
#           'fairies': 1,
#           'using': 3,
#           'tooth': 1,
#           'bait': 1,
#           'teeth': 1,
#           'paste': 1,
#           'Nazis': 2,
#           'copy': 2,
#           'We': 12,
#           'perfect': 1,
#           'sloppy': 2,
#           'hotter': 1,
#           'Saki': 1,
#           'Takei': 1,
#           'label': 1,
#           'jacket': 1,
#           'screw': 1,
#           'ratchet': 1,
#           'Screw': 1,
#           'teen': 1,
#           'Judge': 1,
#           'Hatchett': 1,
#           'Hang': 1,
#           'thrashers': 1,
#           'jackers': 1,
#           'Drug': 1,
#           'dealers': 1,
#           'crackers': 2,
#           'students': 1,
#           'slackers': 1,
#           'backwards': 1,
#           'Jermaine': 1,
#           'Dupri': 1,
#           '93': 1,
#           'Escaping': 1,
#           'concentration': 1,
#           'camps': 1,
#           'girl': 5,
#           'board': 1,
#           'ramp': 1,
#           'ordered': 1,
#           'CCS': 1,
#           'diamonds': 2,
#           'VVS': 1,
#           'Like': 4,
#           'went': 4,
#           'Sierra': 1,
#           'Leone': 1,
#           'dress': 1,
#           'matching': 1,
#           'pink': 5,
#           'panties': 3,
#           'lipstick': 1,
#           'granny': 1,
#           'Sup': 1,
#           'hat': 7,
#           'motherfucker': 7,
#           'friendly': 1,
#           'White': 4,
#           'red-headed': 1,
#           'reminded': 1,
#           'Annie': 1,
#           'dino': 1,
#           'yeah': 17,
#           'understand': 3,
#           'You': 38,
#           'Bunch': 1,
#           'disrespect': 2,
#           'family': 3,
#           'little': 12,
#           'cousin': 1,
#           'auntie': 1,
#           'Wasted': 2,
#           'antiques': 1,
#           'skate': 2,
#           'rape': 8,
#           'sluts': 1,
#           'donuts': 3,
#           'Randy': 1,
#           'Bitches': 5,
#           'Tia': 1,
#           'Landry': 1,
#           'watching': 7,
#           'Billy': 1,
#           'Mandy': 1,
#           'Motherfuckers': 1,
#           'Sit': 1,
#           'stand': 2,
#           'faggot': 8,
#           'guess': 6,
#           'hand-me-down': 1,
#           'rapper': 4,
#           'From': 1,
#           'Los': 1,
#           'Angee': 1,
#           'area': 1,
#           'anytime': 1,
#           'landing': 1,
#           'NahRight': 1,
#           'shout': 1,
#           'Hype': 1,
#           'Trak': 1,
#           'Them': 4,
#           'motherfuckers': 2,
#           'could': 1,
#           'rid': 1,
#           'Guess': 1,
#           'gotta': 4,
#           'song': 6,
#           'Dom': 1,
#           'Kennedy': 1,
#           'Get': 5,
#           'hip': 1,
#           'hop': 3,
#           'bloggers': 1,
#           'Because': 2,
#           'seventeen': 2,
#           'compose': 1,
#           'Lyrically': 1,
#           'dope': 5,
#           'ass-fuck': 1,
#           'dude': 2,
#           'nicotine': 1,
#           'Maybe': 6,
#           'should': 4,
#           'buy': 9,
#           'Hundreds': 1,
#           'jeans': 3,
#           'follow': 3,
#           'footsteps': 1,
#           'motherfucking': 2,
#           'millipede': 1,
#           'Centipede': 1,
#           'make': 18,
#           'songs': 2,
#           'ciggaweed': 1,
#           'Jerk': 1,
#           'freshmen': 1,
#           'league': 1,
#           'hipster': 1,
#           'Kid': 1,
#           'Cudi': 1,
#           'fans': 2,
#           'Collaboration': 1,
#           'hits': 1,
#           'screaming': 3,
#           'buddies': 1,
#           'yo': 9,
#           'driving': 2,
#           'stolen': 1,
#           'truck': 2,
#           'drunk': 3,
#           'DJ': 1,
#           'Unk': 1,
#           'uh': 6,
#           'nose': 1,
#           'filled': 2,
#           'coke': 2,
#           'license': 1,
#           'revoked': 1,
#           'Shut': 2,
#           'Who': 1,
#           'spoke': 1,
#           'everybody': 3,
#           'vanished': 1,
#           'managed': 1,
#           'Hop': 1,
#           'off': 18,
#           'sandwich': 1,
#           'Everybody': 1,
#           'listening': 4,
#           'suck': 2,
#           'Spanish': 1,
#           'Yeah': 22,
#           'record': 4,
#           'was': 29,
#           'angry': 2,
#           'period': 1,
#           'didn': 1,
#           't': 1,
#           'anyone': 2,
#           'Alright': 2,
#           'lying': 3,
#           'OF': 2,
#           'doin': 1,
#           'uh-huh': 2,
#           'Ace': 10,
#           'Creator': 10,
#           'man': 11,
#           'Casey': 3,
#           'Veggies': 2,
#           'Hello': 1,
#           'hype': 5,
#           'mellow': 2,
#           'Bitch': 8,
#           'pipe': 1,
#           'yellow': 3,
#           'blue': 1,
#           'polka': 1,
#           'dots': 1,
#           'stripes': 1,
#           'title': 1,
#           'Nigga': 17,
#           'role': 3,
#           'model': 2,
#           'idol': 1,
#           'If': 15,
#           'face': 6,
#           'ass': 7,
#           'accessorized': 1,
#           'accessories': 1,
#           'bring': 9,
#           'assets': 2,
#           'sound': 3,
#           'acid': 1,
#           'tablets': 1,
#           'Stussy': 1,
#           'G-Shock': 1,
#           'custom': 1,
#           'pair': 2,
#           '3D': 1,
#           'glasses': 1,
#           'suffer': 1,
#           'ADHD': 3,
#           'award': 2,
#           'being': 1,
#           'Beat': 1,
#           'banging': 5,
#           'tom-toms': 1,
#           'producer': 2,
#           'selection': 1,
#           'fresh': 2,
#           'Vons': 1,
#           'underdog': 1,
#           'thrown': 1,
#           'bender': 1,
#           'change': 2,
#           'outfit': 1,
#           'transsexuals': 1,
#           'gender': 1,
#           'Eating': 2,
#           'Belgian': 1,
#           'waffles': 1,
#           'Italian': 1,
#           'biscotts': 1,
#           'sold': 1,
#           'soul': 2,
#           'thirty': 2,
#           'percent': 1,
#           'emo': 2,
#           'around': 3,
#           'pissed': 3,
#           'Step': 2,
#           'one': 12,
#           'pull': 3,
#           'piss': 1,
#           'two': 2,
#           'run': 2,
#           'radio': 1,
#           'turn': 7,
#           'help': 2,
#           'when': 24,
#           'beat': 5,
#           'hit': 4,
#           'belts': 2,
#           'imprint': 1,
#           'leather': 4,
#           'welts': 1,
#           'Uh-huh': 2,
#           'yea': 1,
#           'Ay': 1,
#           "I'mma": 2,
#           'right': 7,
#           'quick': 1,
#           'dapper': 1,
#           'funky': 2,
#           'Dapper': 1,
#           'Dan': 1,
#           'favorite': 4,
#           'fan': 2,
#           'shake': 1,
#           'hand': 4,
#           'On': 3,
#           'tour': 2,
#           'excursions': 1,
#           'virgin': 1,
#           'swap': 1,
#           'meets': 1,
#           'pure': 1,
#           'sick': 5,
#           'cure': 1,
#           'where': 14,
#           'fiends': 1,
#           'Aight': 1,
#           'crew': 1,
#           't-shirt': 2,
#           'Supreme': 7,
#           'Pictionary': 1,
#           'good': 18,
#           'words': 1,
#           'dictionary': 2,
#           'by': 5,
#           'Fresh': 1,
#           'They': 6,
#           'making': 6,
#           'progress': 1,
#           'Becoming': 1,
#           "ain't": 23,
#           'easy': 3,
#           'process': 1,
#           'Eargasms': 1,
#           'hotels': 1,
#           'staying': 1,
#           'twelve': 5,
#           'star': 1,
#           'write': 2,
#           'bar': 1,
#           'people': 1,
#           'stars': 3,
#           'haters': 1,
#           'guards': 1,
#           'against': 1,
#           'us': 7,
#           'Oh': 4,
#           'Red': 2,
#           'box': 3,
#           'logo': 2,
#           'Got': 4,
#           'mad': 4,
#           'main': 1,
#           'vanilla': 2,
#           'tryna': 3,
#           'groove': 1,
#           'Stella': 1,
#           'grab': 2,
#           'umbrella': 1,
#           'comes': 2,
#           'perception': 1,
#           'Helen': 1,
#           'Keller': 1,
#           'perfection': 1,
#           'smell': 4,
#           'Rectum': 1,
#           'chromosome': 1,
#           'X': 1,
#           'Wolverine': 1,
#           'stepson': 1,
#           'attacking': 1,
#           'deadly': 1,
#           'weapon': 1,
#           'opening': 1,
#           'Led': 1,
#           'Zeppelin': 1,
#           'Mary': 2,
#           'Goldilocks': 1,
#           'forest': 2,
#           'In': 9,
#           'eating': 7,
#           'mothafuckin': 6,
#           'porridge': 1,
#           'basement': 3,
#           'locked': 1,
#           'storage': 1,
#           'Rape': 1,
#           'then': 10,
#           'edit': 1,
#           'Octopussy': 1,
#           'special': 2,
#           'effect': 1,
#           'wet': 3,
#           'please': 2,
#           'set': 1,
#           'Canons': 1,
#           'hanging': 1,
#           'necks': 1,
#           'circus': 2,
#           'better': 8,
#           'check': 14,
#           'French': 15,
#           'money': 3,
#           'Better': 5,
#           'huh': 2,
#           'Check': 2,
#           'speak': 2,
#           'English': 2,
#           'Your': 10,
#           'ho': 3,
#           'penis': 2,
#           'left': 4,
#           'dignity': 1,
#           'cupboard': 1,
#           'every': 6,
#           'digging': 2,
#           'pussy': 2,
#           'rubber': 2,
#           'stretch': 2,
#           'flubber': 1,
#           'leave': 2,
#           'dripping': 1,
#           'double': 1,
#           'cheese': 1,
#           'burgers': 1,
#           'Chewing': 1,
#           'cum': 3,
#           'bubble': 2,
#           'gum': 2,
#           'Hubba': 1,
#           'knew': 2,
#           'Bubba': 1,
#           'shrimp': 1,
#           'already': 4,
#           'sniffing': 1,
#           'blow': 3,
#           'friends': 4,
#           'asthma': 1,
#           'itch': 1,
#           'throat': 1,
#           'new': 6,
#           'show': 5,
#           'MTV': 1,
#           'Pimp': 1,
#           'Boat': 1,
#           'semen': 1,
#           'dirty': 4,
#           'most': 1,
#           'fine': 1,
#           'hiding': 1,
#           'Somewhere': 1,
#           'Chris': 2,
#           'Stokes': 2,
#           'find': 8,
#           'Mr': 2,
#           'misters': 1,
#           'R': 1,
#           'Kelly': 2,
#           'bench': 1,
#           'Left': 1,
#           'Brain': 1,
#           'Super': 1,
#           '3': 1,
#           'Put': 3,
#           'expressions': 1,
#           'create': 1,
#           'Of': 4,
#           'picture': 2,
#           'punchline': 1,
#           'figured': 2,
#           'ahh': 1,
#           'why': 7,
#           'figure': 2,
#           'seem': 1,
#           'anyway': 2,
#           'pressured': 1,
#           'type': 2,
#           'choke': 2,
#           'pressure': 3,
#           'pump': 1,
#           'eargasms': 1,
#           'pleasure': 1,
#           'Niggas': 4,
#           'letters': 1,
#           "Competition's": 1,
#           'competition': 1,
#           'Digest': 1,
#           'saying': 3,
#           'throw': 4,
#           'sink': 1,
#           'These': 1,
#           'beginning': 1,
#           'spill': 1,
#           'flows': 1,
#           'sorta': 1,
#           'odd': 2,
#           'Crusing': 1,
#           ...})}

# %%
word_pattern = re.compile("\w[\w\-\']*\w|\w")

albumlist = defaultdict(list)

# all_counts = Counter()



for albums in complete:
#     print (albums)
    line_buffer = []
    for row in albums["songs"]:
        print (row["album"])
    
# #     for row in data:
        
#         print("Reading {} ({})".format(row["title"], row["album"]))
        
#         if row["album"] not in albumlist:
#             albums[row["album"]]=[]
        albumlist[row["album"]].append(row)
            
# # #         row["Year"] = int(row["Year"])
        
        counter = Counter()
        row["Tokens"] = counter
        
        
# #         print ((row['lyrics']))
        line_buffer.append(row['lyrics'])
#         print (line_buffer)
        counter.update(word_pattern.findall(" ".join(line_buffer)))
        line_buffer = []
#     all_counts += counter
# print (albumlist)
# Out:
# Bastard
# Bastard
# Bastard
# Bastard
# Bastard
# Bastard
# Bastard
# Bastard
# Bastard
# Bastard
# Bastard
# Bastard
# Bastard
# Bastard
# Bastard
# Cherry Bomb
# Cherry Bomb
# Cherry Bomb
# Cherry Bomb
# Cherry Bomb
# Cherry Bomb
# Cherry Bomb
# Cherry Bomb
# Cherry Bomb
# Cherry Bomb
# Cherry Bomb
# Cherry Bomb
# Cherry Bomb
# Flower Boy
# Flower Boy
# Flower Boy
# Flower Boy
# Flower Boy
# Flower Boy
# Flower Boy
# Flower Boy
# Flower Boy
# Flower Boy
# Flower Boy
# Flower Boy
# Goblin
# Goblin
# Goblin
# Goblin
# Goblin
# Goblin
# Goblin
# Goblin
# Goblin
# Goblin
# Goblin
# Goblin
# Goblin
# Goblin
# Goblin
# Goblin
# Wolf
# Wolf
# Wolf
# Wolf
# Wolf
# Wolf
# Wolf
# Wolf
# Wolf
# Wolf
# Wolf
# Wolf
# Wolf
# Wolf
# Wolf
# Wolf
# Wolf
# Wolf
# IGOR
# IGOR
# IGOR
# IGOR
# IGOR
# IGOR
# IGOR
# IGOR
# IGOR

# %%
albumlist["IGOR"][0]["Tokens"].most_common()
# Out:
# [('my', 26),
#  ('real', 14),
#  ('you', 13),
#  ("it's", 13),
#  ('I', 12),
#  ('quake', 10),
#  ("don't", 10),
#  ('make', 9),
#  ('earth', 9),
#  ('leave', 9),
#  ('fault', 9),
#  ('huh', 9),
#  ('for', 8),
#  ("Don't", 8),
#  ('Cause', 7),
#  ('no', 7),
#  ('For', 6),
#  ('me', 6),
#  ('up', 6),
#  ('want', 6),
#  ('love', 5),
#  ('And', 5),
#  ('need', 5),
#  ('this', 4),
#  ('time', 4),
#  ('yeah', 4),
#  ('Oh', 4),
#  ('Riding', 4),
#  ('around', 4),
#  ('making', 4),
#  ('heart', 4),
#  ('break', 4),
#  ('your', 3),
#  ('be', 3),
#  ('shakin', 3),
#  ('it', 3),
#  ('You', 3),
#  ('Woah', 3),
#  ('Yeah', 2),
#  ('when', 2),
#  ('all', 2),
#  ('comes', 2),
#  ('crashing', 2),
#  ('down', 2),
#  ('know', 2),
#  ('fuck', 2),
#  ('like', 2),
#  ('set', 2),
#  ("I'm", 2),
#  ('yuh', 2),
#  ('Like', 2),
#  ('Vicky', 2),
#  ('So', 2),
#  ('in', 2),
#  ('Ayy', 2),
#  ('conversation', 2),
#  ('just', 2),
#  ('side', 2),
#  ('information', 2),
#  ('said', 2),
#  ('three', 2),
#  ('Bitch', 1),
#  ('cannot', 1),
#  ('fall', 1),
#  ('short', 1),
#  ('Earthquake', 1),
#  ('ooh', 1),
#  ('Girl', 1),
#  ('ll', 1),
#  ('re', 1),
#  ('telling', 1),
#  ('something', 1),
#  ('is', 1),
#  ('bad', 1),
#  ('oh', 1),
#  ('Earth', 1),
#  ('s', 1),
#  ('already', 1),
#  ('We', 1),
#  ("ain't", 1),
#  ('gotta', 1),
#  ('ball', 1),
#  ('D', 1),
#  ('Rose', 1),
#  ('give', 1),
#  ('a', 1),
#  ('bout', 1),
#  ('none', 1),
#  ('Beamin', 1),
#  ('lungs', 1),
#  ('Just', 1),
#  ('might', 1),
#  ('call', 1),
#  ('lawyer', 1),
#  ('Plug', 1),
#  ('gon', 1),
#  ('Bih', 1),
#  ('Okay', 1),
#  ('with', 1),
#  ('Tyler', 1),
#  ('Slime', 1),
#  ('He', 1),
#  ('ride', 1),
#  ('the', 1),
#  ('car', 1),
#  ('she', 1),
#  ('wicked', 1),
#  ('God', 1),
#  ('hold', 1),
#  ('um', 1),
#  ('Diamonds', 1),
#  ('not', 1),
#  ('Tiffany', 1),
#  ('woah', 1),
#  ('Fault', 1),
#  ("I'll", 1),
#  ('ayy', 1),
#  ('confrontation', 1),
#  ('some', 1),
#  ('confirmation', 1),
#  ('on', 1),
#  ('how', 1),
#  ('feel', 1),
#  ('complication', 1),
#  ('to', 1),
#  ("what's", 1),
#  ('happening', 1),
#  ('cause', 1),
#  ('One', 1),
#  ('Two', 1),
#  ('two', 1),
#  ('girl', 1),
#  ('Three', 1),
#  ('do-do-do-do-do', 1)]

# %%
# all_counts.most_common()
# Out:
# [('the', 84),
#  ('I', 79),
#  ('a', 66),
#  ('you', 44),
#  ("I'm", 40),
#  ('my', 36),
#  ('and', 36),
#  ('to', 34),
#  ('we', 30),
#  ('that', 29),
#  ('friends', 26),
#  ('on', 23),
#  ('fuck', 23),
#  ('in', 23),
#  ('me', 20),
#  ('it', 20),
#  ('still', 20),
#  ('with', 18),
#  ('was', 17),
#  ('is', 16),
#  ('for', 16),
#  ('nigga', 16),
#  ('And', 15),
#  ('got', 15),
#  ('be', 15),
#  ('Are', 15),
#  ('like', 13),
#  ('Fuck', 13),
#  ('good', 12),
#  ('fuckin', 12),
#  ('just', 11),
#  ('this', 11),
#  ('your', 11),
#  ('some', 11),
#  ("don't", 11),
#  ("ain't", 11),
#  ('not', 11),
#  ('up', 11),
#  ('bitch', 10),
#  ('her', 10),
#  ("you're", 9),
#  ('say', 9),
#  ('get', 9),
#  ('niggas', 9),
#  ('when', 9),
#  ('Cause', 9),
#  ('as', 9),
#  ('about', 8),
#  ('there', 8),
#  ('she', 8),
#  ("can't", 8),
#  ('fucking', 8),
#  ('ago', 8),
#  ('out', 7),
#  ('of', 7),
#  ('know', 7),
#  ('shit', 7),
#  ('Now', 7),
#  ("that's", 7),
#  ('off', 7),
#  ("it's", 6),
#  ('father', 6),
#  ('old', 6),
#  ('He', 6),
#  ('at', 6),
#  ('but', 6),
#  ('The', 6),
#  ('give', 6),
#  ('yellow', 6),
#  ('hard', 6),
#  ('Oh', 6),
#  ('Tyler', 5),
#  ('My', 5),
#  ('left', 5),
#  ('cause', 5),
#  ('no', 5),
#  ('one', 5),
#  ('So', 5),
#  ('dick', 5),
#  ('what', 5),
#  ("she's", 5),
#  ('seen', 5),
#  ('him', 5),
#  ('how', 5),
#  ('tell', 5),
#  ("I'll", 5),
#  ('could', 5),
#  ('all', 5),
#  ('now', 5),
#  ('favorite', 5),
#  ('ass', 5),
#  ('have', 5),
#  ('even', 5),
#  ('cock', 5),
#  ('put', 5),
#  ('Just', 5),
#  ('can', 5),
#  ('long', 5),
#  ('Can', 5),
#  ('wanna', 4),
#  ('day', 4),
#  ('he', 4),
#  ('only', 4),
#  ('white', 4),
#  ('gon', 4),
#  ('had', 4),
#  ('You', 4),
#  ('Yeah', 4),
#  ('Without', 4),
#  ('Nigga', 4),
#  ('them', 4),
#  ('make', 4),
#  ('if', 4),
#  ('said', 4),
#  ('When', 4),
#  ('She', 4),
#  ("I've", 4),
#  ('kids', 4),
#  ('ever', 4),
#  ('Friends', 4),
#  ('are', 4),
#  ('end', 3),
#  ('died', 3),
#  ('To', 3),
#  ("didn't", 3),
#  ('years', 3),
#  ('life', 3),
#  ('am', 3),
#  ('from', 3),
#  ('they', 3),
#  ('because', 3),
#  ('need', 3),
#  ('next', 3),
#  ('never', 3),
#  ('let', 3),
#  ('none', 3),
#  ('cold', 3),
#  ('talkin', 3),
#  ('skin', 3),
#  ('summer', 3),
#  ('tryna', 3),
#  ('Nah', 3),
#  ('been', 3),
#  ('keep', 3),
#  ('too', 3),
#  ('his', 3),
#  ('Wolf', 3),
#  ('Gang', 3),
#  ('here', 3),
#  ('go', 3),
#  ('back', 3),
#  ('Johnson', 3),
#  ('saying', 3),
#  ('gonna', 3),
#  ('smokin', 3),
#  ('But', 3),
#  ('man', 3),
#  ('boy', 3),
#  ("Can't", 3),
#  ('bruh', 3),
#  ('bad', 3),
#  ('contact', 3),
#  ('Dr', 3),
#  ('TC', 3),
#  ('goodbye', 3),
#  ('Well', 2),
#  ('Uh', 2),
#  ('time', 2),
#  ('kid', 2),
#  ('so', 2),
#  ('anything', 2),
#  ('Before', 2),
#  ('came', 2),
#  ('hole', 2),
#  ('until', 2),
#  ('enough', 2),
#  ('faggot', 2),
#  ('then', 2),
#  ('Shake', 2),
#  ('Bring', 2),
#  ('pops', 2),
#  ('meetin', 2),
#  ('way', 2),
#  ('Was', 2),
#  ('CDs', 2),
#  ('guess', 2),
#  ('smell', 2),
#  ("That's", 2),
#  ('graduated', 2),
#  ('eighteen', 2),
#  ('Got', 2),
#  ('car', 2),
#  ('Eat', 2),
#  ('or', 2),
#  ('momma', 2),
#  ('would', 2),
#  ('look', 2),
#  ('Obama', 2),
#  ('keys', 2),
#  ('bought', 2),
#  ('hoodie', 2),
#  ('couple', 2),
#  ('rent', 2),
#  ('dipped', 2),
#  ('God', 2),
#  ('see', 2),
#  ('do', 2),
#  ('nice', 2),
#  ('bout', 2),
#  ('without', 2),
#  ('tie', 2),
#  ('proud', 2),
#  ('black', 2),
#  ('hang', 2),
#  ('play', 2),
#  ('That', 2),
#  ('baby', 2),
#  ("You're", 2),
#  ('color', 2),
#  ("It's", 2),
#  ('endless', 2),
#  ('If', 2),
#  ('ask', 2),
#  ('cracker', 2),
#  ('bitches', 2),
#  ('light', 2),
#  ('goin', 2),
#  ('After', 2),
#  ('No', 2),
#  ('want', 2),
#  ('Hodgy', 2),
#  ('lost', 2),
#  ('mind', 2),
#  ('best', 2),
#  ('mom', 2),
#  ('This', 2),
#  ('room', 2),
#  ('head', 2),
#  ('sing', 2),
#  ('little', 2),
#  ('where', 2),
#  ('than', 2),
#  ('swole', 2),
#  ('Have', 2),
#  ('take', 2),
#  ('In', 2),
#  ('these', 2),
#  ('getting', 2),
#  ('thats', 2),
#  ('center', 2),
#  ('stop', 2),
#  ('cop', 2),
#  ('Talk', 2),
#  ('worry', 2),
#  ('stories', 2),
#  ('into', 2),
#  ('Domo', 2),
#  ('roll', 2),
#  ('another', 2),
#  ('squad', 2),
#  ('bring', 2),
#  ('terror', 2),
#  ('intended', 2),
#  ('pun', 2),
#  ('Merch', 2),
#  ('booth', 2),
#  ('made', 2),
#  ('extensive', 2),
#  ('funds', 2),
#  ('Mama', 2),
#  ('Rover', 2),
#  ('Range', 2),
#  ('gotta', 2),
#  ('struggle', 2),
#  ('again', 2),
#  ('dead', 2),
#  ("grandmama's", 2),
#  ('name', 2),
#  ('Too', 2),
#  ('soon', 2),
#  ('an', 2),
#  ('botherin', 2),
#  ('sister', 2),
#  ('paying', 2),
#  ('started', 2),
#  ('eye', 2),
#  ('calling', 2),
#  ('week', 2),
#  ('speak', 2),
#  ('nah', 2),
#  ('happened', 2),
#  ('Getting', 2),
#  ('sitting', 2),
#  ('Dream', 2),
#  ('dream', 2),
#  ('Long', 2),
#  ('hi', 2),
#  ("Don't", 2),
#  ('ah', 2),
#  ('mean', 1),
#  ('misguided', 1),
#  ('Okay', 1),
#  ('else', 1),
#  ("mother's", 1),
#  ('burden', 1),
#  ('soul', 1),
#  ('understand', 1),
#  ('much', 1),
#  ('loved', 1),
#  ('moms', 1),
#  ('bust', 1),
#  ('nut', 1),
#  ('Junt', 1),
#  ('school', 1),
#  ('twelve', 1),
#  ('cheated', 1),
#  ('Told', 1),
#  ('faculty', 1),
#  ('dude', 1),
#  ("wasn't", 1),
#  ('Made', 1),
#  ('U-turn', 1),
#  ('thinkin', 1),
#  ('Birthdays', 1),
#  ('Christmas', 1),
#  ('wishlist', 1),
#  ('new', 1),
#  ('fitted', 1),
#  ('Instead', 1),
#  ('inhaler', 1),
#  ('Ritalin', 1),
#  ('socks', 1),
#  ('hyper', 1),
#  ('attention', 1),
#  ('real', 1),
#  ('Cops', 1),
#  ('supposed', 1),
#  ('jail', 1),
#  ('Statistics', 1),
#  ('odor', 1),
#  ('success', 1),
#  ('bastard', 1),
#  ('America', 1),
#  ('help', 1),
#  ('part', 1),
#  ('Scream', 1),
#  ("Father's", 1),
#  ('Day', 1),
#  ('worst', 1),
#  ('gifts', 1),
#  ('who', 1),
#  ('mentioned', 1),
#  ('before', 1),
#  ('playin', 1),
#  ('both', 1),
#  ('roles', 1),
#  ('occupation', 1),
#  ('dyke', 1),
#  ('right', 1),
#  ('Nixon', 1),
#  ('Hugos', 1),
#  ('Dixons', 1),
#  ('vision', 1),
#  ('rap', 1),
#  ('cookin', 1),
#  ('kitchen', 1),
#  ('Pushin', 1),
#  ('were', 1),
#  ('bangin', 1),
#  ('probably', 1),
#  ('Stevie', 1),
#  ('albums', 1),
#  ('Like', 1),
#  ('tears', 1),
#  ('money', 1),
#  ('spent', 1),
#  ('clothes', 1),
#  ('swear', 1),
#  ('M-16', 1),
#  ('clip', 1),
#  ('RRRAAA', 1),
#  ('16', 1),
#  ('doubt', 1),
#  ('existence', 1),
#  ('either', 1),
#  ('son', 1),
#  ('done', 1),
#  ('weather', 1),
#  ('thick', 1),
#  ('leather', 1),
#  ('called', 1),
#  ('better', 1),
#  ('suit', 1),
#  ('hemmed', 1),
#  ('Take', 1),
#  ('shop', 1),
#  ("momma's", 1),
#  ('asthmatic', 1),
#  ('thin', 1),
#  ('Luck', 1),
#  ('brim', 1),
#  ('Supreme', 1),
#  ('keeps', 1),
#  ('warm', 1),
#  ('blood', 1),
#  ('swarms', 1),
#  ('veins', 1),
#  ('rain', 1),
#  ('bummer', 1),
#  ('fact', 1),
#  ('Neos', 1),
#  ('whose', 1),
#  ('marrow', 1),
#  ('stays', 1),
#  ('frio', 1),
#  ('counselor', 1),
#  ('emo', 1),
#  ('D-low', 1),
#  ("where's", 1),
#  ('trigger', 1),
#  ('bullet', 1),
#  ('hero', 1),
#  ('deserve', 1),
#  ('over', 1),
#  ('BANG', 1),
#  ('first', 1),
#  ('saw', 1),
#  ('searchin', 1),
#  ('needed', 1),
#  ('somethin', 1),
#  ('Sun', 1),
#  ('flowers', 1),
#  ('grow', 1),
#  ('Right', 1),
#  ('blooms', 1),
#  ("color's", 1),
#  ('Whenever', 1),
#  ('Rollin', 1),
#  ('golden', 1),
#  ('Tacoma', 1),
#  ("shit's", 1),
#  ('stolen', 1),
#  ("I'mma", 1),
#  ('drive-by', 1),
#  ('colon', 1),
#  ('meat', 1),
#  ('Gotta', 1),
#  ('obsolete', 1),
#  ('Chris', 1),
#  ('Brown', 1),
#  ('Rihanna', 1),
#  ('beat', 1),
#  ('Jeeves', 1),
#  ('advice', 1),
#  ('reading', 1),
#  ('Vice', 1),
#  ('squatting', 1),
#  ('down', 1),
#  ('picking', 1),
#  ('scalp', 1),
#  ('lice', 1),
#  ('Everything', 1),
#  ('write', 1),
#  ('dope', 1),
#  ('pipe', 1),
#  ('nope', 1),
#  ('hit', 1),
#  ('unless', 1),
#  ('gimme', 1),
#  ('We', 1),
#  ('burning', 1),
#  ('Dutty', 1),
#  ('Rocks', 1),
#  ('switch', 1),
#  ('Bitch', 1),
#  ("dike's", 1),
#  ('clit', 1),
#  ('Bishop', 1),
#  ('Eddie', 1),
#  ("Long's", 1),
#  ('John', 1),
#  ('Sidekick', 1),
#  ('sent', 1),
#  ('fag', 1),
#  ('pics', 1),
#  ('They', 1),
#  ('try', 1),
#  ('goddamn', 1),
#  ('Grammy', 1),
#  ('damn', 1),
#  ('retard', 1),
#  ('great', 1),
#  ('settle', 1),
#  ('flea', 1),
#  ('bargain', 1),
#  ('Unless', 1),
#  ('thrift', 1),
#  ('hipster', 1),
#  ('leotard', 1),
#  ('Painless', 1),
#  ('motherfucking', 1),
#  ('brain', 1),
#  ('ink', 1),
#  ('banged', 1),
#  ('Box', 1),
#  ('Logo', 1),
#  ("haven't", 1),
#  ('stains', 1),
#  ('Congress', 1),
#  ('blondes', 1),
#  ('Um', 1),
#  ('yes', 1),
#  ('beating', 1),
#  ('sex', 1),
#  ('Raquel', 1),
#  ('wrestling', 1),
#  ('prom', 1),
#  ('dress', 1),
#  ('While', 1),
#  ('Ray', 1),
#  ('Charles', 1),
#  ('staring', 1),
#  ('contest', 1),
#  ('step', 1),
#  ('dads', 1),
#  ('Trip-six', 1),
#  ('motherfucks', 1),
#  ('scared', 1),
#  ('It', 1),
#  ('worse', 1),
#  ('absurd', 1),
#  ("Pharrell's", 1),
#  ('butt', 1),
#  ('nerds', 1),
#  ('Creator', 1),
#  ('Justin', 1),
#  ('Bieber', 1),
#  ('flippin', 1),
#  ('Selena', 1),
#  ('Gomez', 1),
#  ('Go', 1),
#  ('pucker', 1),
#  ('come', 1),
#  ('umm', 1),
#  ('Tron', 1),
#  ('Cat', 1),
#  ('rat', 1),
#  ('shook', 1),
#  ('hook', 1),
#  ('For', 1),
#  ('along', 1),
#  ('song', 1),
#  ('cyber', 1),
#  ('bully', 1),
#  ('sissies', 1),
#  ('sisters', 1),
#  ('Macbook', 1),
#  ('nervous', 1),
#  ('Pop', 1),
#  ('Tryna', 1),
#  ('virgin', 1),
#  ('hot', 1),
#  ('vegan', 1),
#  ('daughter', 1),
#  ('goes', 1),
#  ('Wake', 1),
#  ('wash', 1),
#  ('eat', 1),
#  ("Roscoe's", 1),
#  ('Head', 1),
#  ('studio', 1),
#  ('munch', 1),
#  ('tacos', 1),
#  ('younger', 1),
#  ('bitchin', 1),
#  ('coming', 1),
#  ('quicker', 1),
#  ('swimmin', 1),
#  ('sock', 1),
#  ('teeny', 1),
#  ('boppers', 1),
#  ('around', 1),
#  ('lotion', 1),
#  ('Beat', 1),
#  ('til', 1),
#  ('Stop', 1),
#  ('sick', 1),
#  ('kinda', 1),
#  ('Herpe', 1),
#  ('coma', 1),
#  ('common', 1),
#  ('heard', 1),
#  ('brother', 1),
#  ('verse', 1),
#  ('Llama', 1),
#  ("nigga's", 1),
#  ('home', 1),
#  ('Me', 1),
#  ('game', 1),
#  ('Get', 1),
#  ('stainless', 1),
#  ('steel', 1),
#  ('AK', 1),
#  ('aim', 1),
#  ('referees', 1),
#  ('lifeless', 1),
#  ('body', 1),
#  ('choke', 1),
#  ('hold', 1),
#  ('Uh-oh', 1),
#  ('loco', 1),
#  ('Best', 1),
#  ('thing', 1),
#  ('minus', 1),
#  ('tobacco', 1),
#  ('Still', 1),
#  ('well', 1),
#  ('Malcolm', 1),
#  ('X', 1),
#  ('black-maled', 1),
#  ('Blue', 1),
#  ('eyed', 1),
#  ('named', 1),
#  ('Jenny', 1),
#  ('skinny', 1),
#  ('wanted', 1),
#  ('change', 1),
#  ('threw', 1),
#  ('pennies', 1),
#  ('chip', 1),
#  ('block', 1),
#  ('Chipped', 1),
#  ('tooth', 1),
#  ('ruth', 1),
#  ('bag', 1),
#  ('zip', 1),
#  ('lock', 1),
#  ('logo', 1),
#  ('box', 1),
#  ('will', 1),
#  ('gold', 1),
#  ('watch', 1),
#  ('boxers', 1),
#  ('Probably', 1),
#  ('harder', 1),
#  ('erect', 1),
#  ('filled', 1),
#  ('Botox', 1),
#  ('senior', 1),
#  ('citizens', 1),
#  ('slip', 1),
#  ('break', 1),
#  ('hips', 1),
#  ('pop', 1),
#  ('backs', 1),
#  ('Show', 1),
#  ('respect', 1),
#  ('chaps', 1),
#  ('fist', 1),
#  ('spitting', 1),
#  ('wreck', 1),
#  ('ex', 1),
#  ('Her', 1),
#  ("She's", 1),
#  ('met', 1),
#  ('mouth', 1),
#  ('bestest', 1),
#  ('Bestie', 1),
#  ('gets', 1),
#  ('beastie', 1),
#  ('babysitter', 1),
#  ('children', 1),
#  ('exit', 1),
#  ('taught', 1),
#  ('act', 1),
#  ('shoe', 1),
#  ('size', 1),
#  ('eleven', 1),
#  ('half', 1),
#  ('Cock', 1),
#  ('umbrella', 1),
#  ('spit', 1),
#  ('Seven', 1),
#  ('mid', 1),
#  ('stage', 1),
#  ('Coachella', 1),
#  ("Shake's", 1),
#  ('hatin', 1),
#  ('work', 1),
#  ('2DopeBoyz', 1),
#  ('Planet', 1),
#  ('Earth', 1),
#  ('All', 1),
#  ('associates', 1),
#  ('suck', 1),
#  ("what's", 1),
#  ('going', 1),
#  ('People', 1),
#  ('hear', 1),
#  ('fights', 1),
#  ('unnecessary', 1),
#  ('bullshit', 1),
#  ("What's", 1),
#  ('Rest', 1),
#  ('peace', 1),
#  ('Slater', 1),
#  ('yeah', 1),
#  ('pony', 1),
#  ('Little', 1),
#  ('homies', 1),
#  ('repping', 1),
#  ('Kony', 1),
#  ('Phillip', 1),
#  ('Kobi', 1),
#  ('Ya', 1),
#  ('seem', 1),
#  ('happy', 1),
#  ('truthfully', 1),
#  ('ya', 1),
#  ('lonely', 1),
#  ("Nigga's", 1),
#  ('target', 1),
#  ('marketing', 1),
#  ("he's", 1),
#  ('artist', 1),
#  ('walk', 1),
#  ('Target', 1),
#  ('customers', 1),
#  ('Asking', 1),
#  ('picture', 1),
#  ('talk', 1),
#  ('Naw', 1),
#  ('smothering', 1),
#  ('quit', 1),
#  ('mother', 1),
#  ('pay', 1),
#  ('Four', 1),
#  ('storage', 1),
#  ('21', 1),
#  ('mortgage', 1),
#  ("touring's", 1),
#  ('bills', 1),
#  ('thrills', 1),
#  ('Lifes', 1),
#  ('third-floor', 1),
#  ('gorgeous', 1),
#  ('A', 1),
#  ('year', 1),
#  ('broke', 1),
#  ('afford', 1),
#  ('disposables', 1),
#  ('assortment', 1),
#  ('using', 1),
#  ('negatives', 1),
#  ('develop', 1),
#  ('portrait', 1),
#  ('frame', 1),
#  ('pain', 1),
#  ('scratch', 1),
#  ('stain', 1),
#  ('glass', 1),
#  ('important', 1),
#  ('printed', 1),
#  ('hinted', 1),
#  ('sure', 1),
#  ('copy', 1),
#  ('Shit', 1),
#  ('add', 1),
#  ('signature', 1),
#  ('pic-ature', 1),
#  ('film', 1),
#  ('used', 1),
#  ('aperture', 1),
#  ('Grandmother', 1),
#  ('cry', 1),
#  ('tear', 1),
#  ('Not', 1),
#  ('lie', 1),
#  ('weird', 1),
#  ('water', 1),
#  ('dripped', 1),
#  ('news', 1),
#  ('yup', 1),
#  ('stuck', 1),
#  ('gave', 1),
#  ('Mom', 1),
#  ('show', 1),
#  ('answer', 1),
#  ('crying', 1),
#  ('Sadie', 1),
#  ('dying', 1),
#  ('doc', 1),
#  ('us', 1),
#  ('deceased', 1),
#  ('cancer', 1),
#  ('eating', 1),
#  ('cheeks', 1),
#  ('really', 1),
#  ('awkward', 1),
#  ('phone', 1),
#  ('adjust', 1),
#  ('seat', 1),
#  ('think', 1),
#  ('What', 1),
#  ('death', 1),
#  ('Meet', 1),
#  ('hospital', 1),
#  ('should', 1),
#  ('between', 1),
#  ('set', 1),
#  ('BADBADNOTGOOD', 1),
#  ('Lionel', 1),
#  ('asked', 1),
#  ('Cedars-Sinai', 1),
#  ('Oakwood', 1),
#  ('family', 1),
#  ('chair', 1),
#  ('Awkward', 1),
#  ('lobby', 1),
#  ('floating', 1),
#  ('thinning', 1),
#  ('air', 1),
#  ('sticker', 1),
#  ("there's", 1),
#  ('Open', 1),
#  ('curtain', 1),
#  ('hello', 1),
#  ('Our', 1),
#  ("conversation's", 1),
#  ('brief', 1),
#  ("couldn't", 1),
#  ('Lookin', 1),
#  ('weak', 1),
#  ('days', 1),
#  ('strength', 1),
#  ('sat', 1),
#  ('20', 1),
#  ('minutes', 1),
#  ('tops', 1),
#  ('hoping', 1),
#  ('plea', 1),
#  ('night', 1),
#  ('heavy', 1),
#  ('sorry', 1),
#  ('loss', 1),
#  ('whatever', 1),
#  ('Last', 1),
#  ('Sammy', 1),
#  ('lookin', 1),
#  ('Samuel', 1),
#  ('Uhh', 1),
#  ('woulda', 1),
#  ('killed', 1),
#  ('kno', 1),
#  ('Know', 1),
#  ('each', 1),
#  ('other', 1),
#  ('hand', 1),
#  ('rock', 1),
#  ('die', 1),
#  ('La-la-la-la-la-la-la', 1),
#  ('green', 1),
#  ('Green', 1),
#  ('Keep', 1),
#  ('Goodbye', 1),
#  ('later', 1),
#  ('Later', 1),
#  ('season', 1),
#  ('episode', 1),
#  ('Bouncing', 1),
#  ('things', 1),
#  ('fall', 1),
#  ('Your', 1),
#  ('power', 1),
#  ('drained', 1),
#  ('cannot', 1),
#  ('through', 1),
#  ('walls', 1),
#  ('caught', 1),
#  ('matrix', 1),
#  ('hate', 1),
#  ('friend', 1),
#  ('woah', 1),
#  ('Woo', 1)]

# %%
# # Construct a fixed vocabulary
# # print (all_counts.most_common())
# vocabulary = [w for w, c in all_counts.most_common()]
# # print (vocabulary)
# vocabulary_size = len(vocabulary)

# reverse_vocab = { w: i for i, w in enumerate(vocabulary) }

# reverse_vocab["Yo"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-222-4e862fbc6a99> in <module>
#       7 reverse_vocab = { w: i for i, w in enumerate(vocabulary) }
#       8
# ----> 9 reverse_vocab["Yo"]
#
# KeyError: 'Yo'

# %%
def counter_to_vector(counter):
    vector = numpy.zeros(vocabulary_size)
    for word in counter.keys():
        ## look up the integer ID for the string
        word_id = reverse_vocab[word]
#         print (counter[word])
        vector[word_id] = counter[word]
    
    return vector / vector.sum()

# %%
# print (all_vector)
albumtokens=defaultdict(dict)
for album in albumlist:
#     print (type(albumlist[album]))
    albumtokens[album]["Tokens"]=Counter()
    for song in albumlist[album]:
        albumtokens[album]["Tokens"].update(song["Tokens"])


#         print (songs["Tokens"])
#         albumtokens[album].update(songs["Tokens"])
check=Counter()
for i in albumtokens:
    check.update(albumtokens[i]["Tokens"])
#     print (albumtokens[i]["Tokens"])
print (check)
for album in albumtokens:
#     print (albumtokens[album]["Tokens"]["Yo"])
    albumtokens[album]["Vector"] = counter_to_vector(albumtokens[album]["Tokens"])
# Out:
# Counter({'I': 1701, 'the': 1421, 'a': 1010, 'you': 910, 'my': 773, 'to': 719, "I'm": 702, 'me': 587, 'and': 583, 'in': 558, 'that': 529, 'it': 402, 'like': 390, 'is': 364, 'of': 349, 'your': 332, 'fucking': 328, 'fuck': 317, 'on': 315, 'And': 310, 'with': 302, "don't": 274, 'up': 253, 'nigga': 243, 'this': 240, 'You': 240, 'for': 228, 'shit': 225, 'got': 204, 'can': 191, 'get': 181, 'just': 180, 'some': 180, 'we': 177, 'be': 176, 'out': 174, 'bitch': 168, 'was': 167, 'know': 165, 'Fuck': 161, 'But': 160, 'her': 157, 'but': 153, "it's": 149, 'at': 149, 'not': 146, 'time': 144, 'when': 141, 'niggas': 139, 'so': 137, 'all': 133, 'they': 131, 'My': 125, 'no': 120, 'yeah': 120, 'go': 114, 'if': 113, "you're": 112, 'back': 107, 'want': 107, "ain't": 107, 'Yeah': 103, "that's": 102, 'Cause': 101, 'now': 100, 'from': 96, 'see': 94, 'what': 92, 'she': 91, 'The': 91, 'have': 90, 'love': 89, 'wanna': 89, 'never': 86, 'off': 86, 'them': 85, 'down': 85, 'Wolf': 85, 'man': 84, 'cause': 83, 'dick': 82, "It's": 82, 'as': 80, 'So': 79, 'do': 79, 'think': 78, 'em': 77, 'one': 77, 'Golf': 77, 'Wang': 76, 'about': 75, 'tell': 74, 'make': 73, 'take': 72, 'Now': 72, 'Oh': 71, 'say': 70, 'give': 68, "can't": 67, 'are': 67, 'We': 66, 'could': 66, 'Nigga': 66, "I'll": 65, 'good': 65, 'he': 64, 'fuckin': 64, 'him': 63, 'feel': 62, 'call': 61, 'said': 61, 'too': 61, 'need': 60, 'Gang': 60, 'Tyler': 59, 'who': 59, 'getting': 58, 'girl': 58, 'How': 58, 'these': 57, 'let': 57, 'really': 57, 'What': 56, 'here': 55, 'This': 55, 'than': 55, 'baby': 55, "Don't": 54, 'friends': 54, 'la': 53, 'When': 52, 'boy': 52, 'had': 52, 'or': 51, 'his': 50, 'where': 50, "You're": 49, 'been': 48, 'couple': 48, 'bitches': 47, 'No': 47, 'still': 47, 'right': 47, 'even': 46, 'us': 46, 'That': 45, 'only': 44, 'am': 44, 'suck': 44, 'swag': 44, 'leave': 43, 'gone': 43, 'over': 42, 'gotta': 42, 'They': 42, 'come': 42, 'how': 41, 'kids': 41, 'real': 41, 'an': 40, 'life': 40, 'around': 40, 'then': 40, 'more': 39, 'm': 39, 'by': 39, 'new': 39, "y'all": 39, 'day': 38, 'something': 38, 'hope': 38, 't': 38, 'ass': 38, 'gon': 38, 'because': 37, 'Bitch': 37, 'In': 37, 'four': 37, 'look': 36, 'A': 36, 'If': 36, 'To': 36, 'Four': 36, 'mean': 35, 'eat': 35, 'Odd': 35, 'All': 35, 'our': 35, 'little': 35, 's': 34, 'find': 34, 'why': 34, "let's": 34, 'See': 34, 'Find': 34, 'talk': 33, 'ya': 33, 'radical': 33, 'school': 32, 'sorry': 32, "That's": 32, 'would': 32, 'stop': 32, 'again': 32, 'Future': 31, 'black': 31, 'keep': 31, 'made': 31, 'bad': 31, 'Like': 31, 'Who': 31, 'run': 31, 'bout': 31, 'going': 30, 'way': 30, 'mind': 30, 'lot': 30, 'hate': 30, 'motherfucking': 30, 'oh': 30, 'Then': 30, 'Can': 30, 'there': 30, 'ever': 30, "I've": 29, 'start': 29, 'tryna': 29, 'home': 29, 'put': 28, 'much': 28, 'house': 28, 'face': 28, 'money': 28, 'huh': 28, 'sick': 27, 'Your': 27, 'first': 27, 'For': 27, 'answer': 27, 'three': 26, 'She': 26, 'gold': 26, 'Shit': 26, 'name': 26, 'hit': 26, 'into': 26, 'mine': 26, 'okay': 26, 'watch': 26, 'Take': 26, 'light': 26, 'magic': 26, 'gonna': 25, 'With': 25, "I'ma": 25, 'through': 25, 'Boy': 25, 'November': 25, 'na': 25, '48': 25, 'Well': 24, 'fucked': 24, 'roll': 24, 'try': 24, 'faggot': 24, 'should': 24, 'bring': 24, 'being': 24, 'two': 24, 'people': 24, 'head': 24, 'hard': 24, 'another': 24, 'It': 24, 'play': 23, 'kill': 23, 'their': 23, 'show': 23, 'Just': 23, 'God': 23, 'Skate': 23, 'dead': 22, 'white': 22, 'stay': 22, 'seen': 22, 'will': 22, 'Got': 22, 'blow': 22, 'away': 22, 'heart': 22, 'ask': 22, 'until': 22, 'shoot': 22, 'Swag': 22, 'control': 22, 'lose': 22, 'other': 21, 'own': 21, 'always': 21, 'told': 21, "what's": 21, 'skate': 21, 'better': 21, 'left': 21, 'trying': 21, 'started': 21, 'Watch': 21, 'Press': 21, 'Look': 21, "Let's": 21, 'top': 21, 'sunset': 21, 'Yo': 20, 'well': 20, 'Are': 20, 'probably': 20, "didn't": 20, 'buttons': 20, 'Kill': 20, 'fall': 20, 'last': 20, 'thought': 19, 'damn': 19, 'best': 19, 'song': 19, 'making': 19, 'door': 19, "she ...

# %%
vocabulary = [w for w, c in check.most_common()]
# print (vocabulary)
vocabulary_size = len(vocabulary)

reverse_vocab = { w: i for i, w in enumerate(vocabulary) }

reverse_vocab["Yo"]
all_vector = counter_to_vector(check)

# %%
for album in (albumtokens):
#     print 
    # `nonzero` returns a tuple with one element per dimension of the input array
    nzs = numpy.nonzero(albumtokens[album]["Vector"])[0]
#     print (nzs)
    kl_terms = albumtokens[album]["Vector"][nzs] * numpy.log2(albumtokens[album]["Vector"][nzs] / all_vector[nzs])
    
    vocabulary_subset = [vocabulary[i] for i in nzs]

    sorted_words = sorted(zip(kl_terms, vocabulary_subset), reverse=True)
#     print(song_id, song["title"])
    print (album)
    print(", ".join(["{} ({:.3f})".format(w, s) for s, w in sorted_words[:30]]))
    print(", ".join(["{} ({:.3f})".format(w, s) for s, w in sorted_words[-30:]]))
    print()
# Out:
# Bastard
# my (0.010), I'm (0.009), swag (0.007), like (0.007), Press (0.006), buttons (0.006), fucking (0.005), is (0.004), French (0.004), gold (0.004), to (0.004), with (0.004), check (0.004), weave (0.003), perm (0.003), Tina (0.003), her (0.003), Odd (0.003), hook (0.003), Future (0.003), The (0.003), so (0.003), bass (0.003), With (0.003), baby (0.003), ow (0.003), father (0.003), O (0.003), yo (0.003), where's (0.003)
# be (-0.001), think (-0.001), that's (-0.001), cause (-0.001), em (-0.001), love (-0.001), see (-0.001), of (-0.001), Wolf (-0.001), wanna (-0.001), you're (-0.001), But (-0.001), you (-0.001), Yeah (-0.001), when (-0.001), back (-0.001), know (-0.001), was (-0.001), yeah (-0.001), nigga (-0.001), got (-0.001), don't (-0.001), on (-0.002), we (-0.002), time (-0.002), out (-0.002), You (-0.002), that (-0.003), me (-0.005), I (-0.007)
#
# Cherry Bomb
# you (0.011), yeah (0.009), your (0.007), lose (0.006), control (0.006), cherry (0.006), light (0.005), bomb (0.005), Yeah (0.005), And (0.005), young (0.005), that (0.004), like (0.004), wings (0.004), blows (0.004), too (0.004), I (0.004), blow (0.004), you're (0.004), when (0.004), don't (0.004), Two (0.004), Boy (0.004), man (0.004), 2 (0.003), camera (0.003), nigga (0.003), fire (0.003), coach (0.003), To (0.003)
# Golf (-0.001), getting (-0.001), How (-0.001), all (-0.001), call (-0.001), love (-0.001), down (-0.001), I'm (-0.001), that's (-0.001), make (-0.001), So (-0.001), as (-0.001), have (-0.001), dick (-0.001), no (-0.001), not (-0.001), for (-0.001), she (-0.001), with (-0.001), My (-0.001), time (-0.002), in (-0.002), my (-0.002), of (-0.002), bitch (-0.002), some (-0.002), is (-0.003), fuck (-0.003), fucking (-0.003), a (-0.003)
#
# Flower Boy
# time (0.025), some (0.022), me (0.019), back (0.019), I (0.017), Find (0.015), November (0.015), How (0.011), la (0.010), okay (0.010), pothole (0.010), Who (0.009), call (0.009), feel (0.008), Take (0.008), if (0.007), 911 (0.007), find (0.007), Call (0.006), run (0.006), ya (0.006), boredom (0.006), em (0.006), oh (0.006), garden (0.006), bloom (0.006), know (0.005), it (0.005), out (0.005), shed (0.005)
# fucking (-0.001), nigga (-0.001), niggas (-0.001), no (-0.001), now (-0.001), not (-0.001), when (-0.001), you're (-0.001), Fuck (-0.001), at (-0.001), that (-0.002), my (-0.002), And (-0.002), it's (-0.002), bitch (-0.002), up (-0.002), we (-0.002), You (-0.002), just (-0.002), the (-0.002), this (-0.002), shit (-0.002), with (-0.002), like (-0.003), fuck (-0.004), your (-0.004), and (-0.005), you (-0.006), I'm (-0.007), a (-0.008)
#
# Goblin
# fucking (0.011), her (0.009), the (0.008), Wolf (0.008), fuck (0.007), radical (0.006), bitch (0.005), Gang (0.005), dick (0.005), I'm (0.005), shit (0.005), a (0.004), suck (0.004), sunset (0.004), and (0.003), she (0.003), s (0.003), school (0.003), people (0.003), burn (0.003), Kill (0.002), bow (0.002), lake (0.002), of (0.002), gotta (0.002), motherfucking (0.002), punch (0.002), that's (0.002), his (0.002), cock (0.002)
# to (-0.001), feel (-0.001), it's (-0.001), see (-0.001), good (-0.001), Nigga (-0.001), no (-0.001), Cause (-0.001), love (-0.001), know (-0.001), is (-0.001), Yeah (-0.001), out (-0.001), back (-0.001), yeah (-0.001), for (-0.001), You (-0.001), niggas (-0.001), it (-0.002), on (-0.002), time (-0.002), And (-0.002), don't (-0.002), up (-0.002), your (-0.002), me (-0.003), like (-0.003), you (-0.006), my (-0.007), I (-0.008)
#
# Wolf
# Wang (0.008), Golf (0.006), 48 (0.005), my (0.004), that (0.003), hope (0.003), Slater (0.003), being (0.003), answer (0.003), lot (0.003), nigga (0.003), bum (0.003), on (0.003), I (0.002), cowboy (0.002), trip (0.002), Fuck (0.002), Trash (0.002), Squad (0.002), Loiter (0.002), a (0.002), was (0.002), girlfriend (0.002), And (0.002), You're (0.002), lips (0.002), locked (0.002), tamale (0.002), bimmer (0.002), Tamale (0.002)
# This (-0.001), friends (-0.001), back (-0.001), feel (-0.001), How (-0.001), wanna (-0.001), make (-0.001), fuckin (-0.001), if (-0.001), cause (-0.001), fucking (-0.001), never (-0.001), do (-0.001), Cause (-0.001), it's (-0.001), be (-0.001), so (-0.001), want (-0.001), know (-0.001), yeah (-0.001), to (-0.002), can (-0.002), some (-0.002), time (-0.002), her (-0.002), don't (-0.002), your (-0.002), I'm (-0.003), me (-0.004), the (-0.004)
#
# IGOR
# Four (0.034), gone (0.033), magic (0.029), leave (0.029), love (0.024), Skate (0.022), friends (0.022), You (0.020), don't (0.018), Are (0.018), me (0.017), real (0.017), you (0.016), la (0.015), time (0.015), mere (0.014), still (0.014), Don't (0.014), your (0.014), love's (0.013), started (0.013), hello (0.013), we (0.012), now (0.012), shoot (0.011), quake (0.011), need (0.011), time's (0.010), fault (0.010), four (0.010)
# in (-0.001), The (-0.001), was (-0.001), if (-0.001), that's (-0.001), back (-0.001), when (-0.001), they (-0.001), Fuck (-0.002), niggas (-0.002), bitch (-0.002), with (-0.002), at (-0.002), this (-0.002), but (-0.002), her (-0.002), nigga (-0.002), get (-0.002), some (-0.002), of (-0.002), shit (-0.002), fuck (-0.003), a (-0.003), And (-0.004), like (-0.004), to (-0.004), that (-0.006), and (-0.006), I'm (-0.007), the (-0.012)
